# %% [markdown]
# ## Project 4
# ## Submitted by Roshan Lulu

# %% [markdown]
# ### Step 1 - Get the Job Posting data from the website
#
# - Identify the Job titles to scrap
# - Identify the element/child relationships and get the attributes
# - Baby step - Get 1 job posting scraped

# %% [markdown]
# ### A. Import Libraries

# %%
# import libraries
import scrapy
from scrapy.http import Request
from scrapy import Selector
import requests
import pandas as pd

# %% [raw]
# # Define your parse function inside your class
# def parse_each_job_result_page(response, meta, page_num):
#     all_links = []
#     hxs = Selector(response)
#     # Get links in that page
#     links = Selector(text=response.text).xpath("//a[@data-automation='jobTitle']/@href").extract()
#     all_links.append(links)
#     # get the link to the next page
#     next_page_anchor  =  Selector(text=response.text).xpath("//a[@data-automation='page-next']/@href").extract()
#     print(next_page_anchor)
#     if len(next_page_anchor) > 0:
#         page_num += 1
#         get_links_for_job([{'type':meta, 'page':page_num += 1,'url':next_page_anchor}])
#     else:
#         pass

# %% [raw]
# # Define the start request function
# def get_links_for_job(urls = search_urls):
#     for url in urls:
#         print(url['type'], "***************************************************************************", url['type'])
#         print('\n')
#         response = requests.get(url['url'])
#         parse_each_job_link(response, url['type'], url['page'])
#         print('\n')

# %% [markdown]
# ### B. GET THE PAGE LINKS FOR THE JOBS

# %%
# # deinfe the serach urls
# urls = [{'page':1,'type': 'data-analyst', 'url':'https://www.seek.com.au/Data-Analyst-jobs/in-All-Sydney-NSW'},
#                 {'page':1,'type': 'data-science', 'url':'https://www.seek.com.au/Data-Science-jobs/in-All-Sydney-NSW'},
#                  {'page':1, 'type': 'business-intelligence', 'url':'https://www.seek.com.au/Business-Intelligence-jobs/in-All-Sydney-NSW'}]

job_desc_i_want = ['Data-Science', 'Data-Analyst', 'Business-Intelligence']
where_is_the_job = '-jobs/in-All-Sydney-NSW'
search_urls = []

for index in range(0, len(job_desc_i_want)):
    job_dict = {}
    job_dict['type'] = job_desc_i_want[index]
    job_dict['page'] = 1
    job_dict['url'] = 'https://www.seek.com.au/' + job_desc_i_want[index] + where_is_the_job
    search_urls.append(job_dict)

search_urls
# Out:
# [{'page': 1,
#   'type': 'Data-Science',
#   'url': 'https://www.seek.com.au/Data-Science-jobs/in-All-Sydney-NSW'},
#  {'page': 1,
#   'type': 'Data-Analyst',
#   'url': 'https://www.seek.com.au/Data-Analyst-jobs/in-All-Sydney-NSW'},
#  {'page': 1,
#   'type': 'Business-Intelligence',
#   'url': 'https://www.seek.com.au/Business-Intelligence-jobs/in-All-Sydney-NSW'}]

# %%
pagelinks_df = pd.DataFrame(columns = ('Job_Desc', 'Page_Num', 'url_link'))

# %%
# Define the start request function
def get_all_page_links_per_job(url, job_desc, page_num=1):
    # Get the html response from the first page url
    response = requests.get(url)
    # get the link to the next page
    next_page_anchor  =  Selector(text=response.text).xpath("//a[@data-automation='page-next']/@href").extract()
    # check if there is a next page
    if len(next_page_anchor) > 0:
        # Save the current url details before finding the next one
        pagelinks_df.loc[len(pagelinks_df),:] = [job_desc, page_num, url]
        # Start searching for next page link
        # Recursively call to get the links in next anchor page
        page_num += 1
        next_page_anchor = "https://www.seek.com.au" + next_page_anchor[0]
        get_all_page_links_per_job(next_page_anchor, job_desc, page_num)
    else:
        pass

# %%
def parse_all_first_pages(urls=search_urls):
    for url in urls:
        get_all_page_links_per_job(url['url'], url['type']) 

#Parse all the required job search results and get the links to the job postings
parse_all_first_pages()

# %%
# Display the dataframe obtained
pagelinks_df
# Out:
#                  Job_Desc Page_Num  \
# 0            Data-Science        1
# 1            Data-Science        2
# 2            Data-Science        3
# 3            Data-Science        4
# 4            Data-Analyst        1
# 5            Data-Analyst        2
# 6            Data-Analyst        3
# 7            Data-Analyst        4
# 8            Data-Analyst        5
# 9            Data-Analyst        6
# 10           Data-Analyst        7
# 11           Data-Analyst        8
# 12           Data-Analyst        9
# 13           Data-Analyst       10
# 14  Business-Intelligence        1
# 15  Business-Intelligence        2
# 16  Business-Intelligence        3
# 17  Business-Intelligence        4
# 18  Business-Intelligence        5
# 19  Business-Intelligence        6
# 20  Business-Intelligence        7
# 21  Business-Intelligence        8
# 22  Business-Intelligence        9
# 23  Business-Intelligence       10
# 24  Business-Intelligence       11
# 25  Business-Intelligence       12
# 26  Business-Intelligence       13
# 27  Business-Intelligence       14
# 28  Business-Intelligence       15
# 29  Business-Intelligence       16
#
#                                              url_link
# 0   https://www.seek.com.au/Data-Science-jobs/in-A...
# 1   https://www.seek.com.au/Data-Science-jobs/in-A...
# 2   https://www.seek.com.au/Data-Science-jobs/in-A...
# 3   https://www.seek.com.au/Data-Science-jobs/in-A...
# 4   https://www.seek.com.au/Data-Analyst-jobs/in-A...
# 5   https://www.seek.com.au/Data-Analyst-jobs/in-A...
# 6   https://www.seek.com.au/Data-Analyst-jobs/in-A...
# 7   https://www.seek.com.au/Data-Analyst-jobs/in-A...
# 8   https://www.seek.com.au/Data-Analyst-jobs/in-A...
# 9   https://www.seek.com.au/Data-Analyst-jobs/in-A...
# 10  https://www.seek.com.au/Data-Analyst-jobs/in-A...
# 11  https://www.seek.com.au/Data-Analyst-jobs/in-A...
# 12  https://www.seek.com.au/Data-Analyst-jobs/in-A...
# 13  https://www.seek.com.au/Data-Analyst-jobs/in-A...
# 14  https://www.seek.com.au/Business-Intelligence-...
# 15  https://www.seek.com.au/Business-Intelligence-...
# 16  https://www.seek.com.au/Business-Intelligence-...
# 17  https://www.seek.com.au/Business-Intelligence-...
# 18  https://www.seek.com.au/Business-Intelligence-...
# 19  https://www.seek.com.au/Business-Intelligence-...
# 20  https://www.seek.com.au/Business-Intelligence-...
# 21  https://www.seek.com.au/Business-Intelligence-...
# 22  https://www.seek.com.au/Business-Intelligence-...
# 23  https://www.seek.com.au/Business-Intelligence-...
# 24  https://www.seek.com.au/Business-Intelligence-...
# 25  https://www.seek.com.au/Business-Intelligence-...
# 26  https://www.seek.com.au/Business-Intelligence-...
# 27  https://www.seek.com.au/Business-Intelligence-...
# 28  https://www.seek.com.au/Business-Intelligence-...
# 29  https://www.seek.com.au/Business-Intelligence-...
