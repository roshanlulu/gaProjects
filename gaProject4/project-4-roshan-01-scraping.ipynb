# %% [markdown]
# ## Project 4
# #### NoteBook 1 - Scraping
# ## Submitted by Roshan Lulu

# %% [markdown]
# ## Business Case
#
# You're working as a data scientist for a contracting firm that's rapidly expanding. Now that they have their most valuable employee (you!), they need to leverage data to win more contracts. Your firm offers technology and scientific solutions and wants to be competitive in the hiring market. Your principal has two main objectives:
# 1. Determine the industry factors that are most important in predicting the salary amounts for these data.
# 2. Determine the factors that distinguish job categories and titles from each other. For example, can required skills accurately predict job title?
#
# To limit the scope your principal has suggested that you focus on data-related job postings, e.g. data scientist, data analyst, research scientist, business intelligence, etc. You may also want to decrease the scope by selecting a single region.
#
# Aggregators like [Indeed.com](https://www.indeed.com) regularly pool job postings from a variety of markets and industries. You will be scraping data from Indeed.com or other job aggregators to answer these two questions.
#
# ---

# %% [markdown]
# ### Step 1 - Get the Job Posting data from the website
#
# - Identify the Job titles to scrap
# - Identify the element/child relationships and get the attributes
# - Baby step - Get 1 job posting scraped

# %% [markdown]
# ### A. IMPORT LIBRARIES

# %%
# import libraries
import scrapy
from scrapy.http import Request
from scrapy import Selector
import requests
import pandas as pd

# %% [markdown]
# ### B. PARSE SEARCH RESULTS FOR THE JOB POST LINKS

# %%
# # define the search urls
# urls = [{'page':1,'type': 'data-analyst', 'url':'https://www.seek.com.au/Data-Analyst-jobs/in-All-Sydney-NSW'},
#                 {'page':1,'type': 'data-science', 'url':'https://www.seek.com.au/Data-Science-jobs/in-All-Sydney-NSW'},
#                  {'page':1, 'type': 'business-intelligence', 'url':'https://www.seek.com.au/Business-Intelligence-jobs/in-All-Sydney-NSW'}]

job_desc_i_want = ['Data-Science', 'Data-Analyst', 'Business-Intelligence', 'Research-Scientist', 'Business-Analyst']
where_is_the_job = ['-jobs/in-All-Sydney-NSW', '-jobs/in-All-Melbourne-VIC', '-jobs/in-All-Brisbane-QLD']
search_urls = []

for index in range(0, len(job_desc_i_want)):
    for item in range(0, len(where_is_the_job)):
        job_dict = {}
        job_dict['loc'] = where_is_the_job[item].split('/')[1]
        job_dict['type'] = job_desc_i_want[index]
        job_dict['page'] = 1
        job_dict['url'] = 'https://www.seek.com.au/' + job_desc_i_want[index] + where_is_the_job[item]
        search_urls.append(job_dict)

search_urls
# Out:
# [{'loc': 'in-All-Sydney-NSW',
#   'page': 1,
#   'type': 'Data-Science',
#   'url': 'https://www.seek.com.au/Data-Science-jobs/in-All-Sydney-NSW'},
#  {'loc': 'in-All-Melbourne-VIC',
#   'page': 1,
#   'type': 'Data-Science',
#   'url': 'https://www.seek.com.au/Data-Science-jobs/in-All-Melbourne-VIC'},
#  {'loc': 'in-All-Brisbane-QLD',
#   'page': 1,
#   'type': 'Data-Science',
#   'url': 'https://www.seek.com.au/Data-Science-jobs/in-All-Brisbane-QLD'},
#  {'loc': 'in-All-Sydney-NSW',
#   'page': 1,
#   'type': 'Data-Analyst',
#   'url': 'https://www.seek.com.au/Data-Analyst-jobs/in-All-Sydney-NSW'},
#  {'loc': 'in-All-Melbourne-VIC',
#   'page': 1,
#   'type': 'Data-Analyst',
#   'url': 'https://www.seek.com.au/Data-Analyst-jobs/in-All-Melbourne-VIC'},
#  {'loc': 'in-All-Brisbane-QLD',
#   'page': 1,
#   'type': 'Data-Analyst',
#   'url': 'https://www.seek.com.au/Data-Analyst-jobs/in-All-Brisbane-QLD'},
#  {'loc': 'in-All-Sydney-NSW',
#   'page': 1,
#   'type': 'Business-Intelligence',
#   'url': 'https://www.seek.com.au/Business-Intelligence-jobs/in-All-Sydney-NSW'},
#  {'loc': 'in-All-Melbourne-VIC',
#   'page': 1,
#   'type': 'Business-Intelligence',
#   'url': 'https://www.seek.com.au/Business-Intelligence-jobs/in-All-Melbourne-VIC'},
#  {'loc': 'in-All-Brisbane-QLD',
#   'page': 1,
#   'type': 'Business-Intelligence',
#   'url': 'https://www.seek.com.au/Business-Intelligence-jobs/in-All-Brisbane-QLD'},
#  {'loc': 'in-All-Sydney-NSW',
#   'page': 1,
#   'type': 'Research-Scientist',
#   'url': 'https://www.seek.com.au/Research-Scientist-jobs/in-All-Sydney-NSW'},
#  {'loc': 'in-All-Melbourne-VIC',
#   'page': 1,
#   'type': 'Research-Scientist',
#   'url': 'https://www.seek.com.au/Research-Scientist-jobs/in-All-Melbourne-VIC'},
#  {'loc': 'in-All-Brisbane-QLD',
#   'page': 1,
#   'type': 'Research-Scientist',
#   'url': 'https://www.seek.com.au/Research-Scientist-jobs/in-All-Brisbane-QLD'},
#  {'loc': 'in-All-Sydney-NSW',
#   'page': 1,
#   'type': 'Business-Analyst',
#   'url': 'https://www.seek.com.au/Business-Analyst-jobs/in-All-Sydney-NSW'},
#  {'loc': 'in-All-Melbourne-VIC',
#   'page': 1,
#   'type': 'Business-Analyst',
#   'url': 'https://www.seek.com.au/Business-Analyst-jobs/in-All-Melbourne-VIC'},
#  {'loc': 'in-All-Brisbane-QLD',
#   'page': 1,
#   'type': 'Business-Analyst',
#   'url': 'https://www.seek.com.au/Business-Analyst-jobs/in-All-Brisbane-QLD'}]

# %%
pagelinks_df = pd.DataFrame(columns = ('Job_Desc', 'Job_Loc','Page_Num', 'url_link'))

# %%
# Define the start request function
def get_all_page_links_per_job(url, job_desc, job_loc, page_num=1):
    # Get the html response from the first page url
    response = requests.get(url)
    # get the link to the next page
    next_page_anchor  =  Selector(text=response.text).xpath("//a[@data-automation='page-next']/@href").extract()
    # check if there is a next page
    if len(next_page_anchor) > 0:
        # Save the current url details before finding the next one
        pagelinks_df.loc[len(pagelinks_df),:] = [job_desc, job_loc, page_num, url]
        # Start searching for next page link
        # Recursively call to get the links in next anchor page
        page_num += 1
        next_page_anchor = "https://www.seek.com.au" + next_page_anchor[0]
        get_all_page_links_per_job(next_page_anchor, job_desc, job_loc, page_num)
    else:
        pass

# %%
def parse_all_first_pages(urls=search_urls):
    for url in urls:
        get_all_page_links_per_job(url['url'], url['type'], url['loc']) 

#Parse all the required job search results and get the links to the job postings
parse_all_first_pages()

# %%
# Display the dataframe obtained
pagelinks_df.head()
# Out:
#        Job_Desc               Job_Loc Page_Num  \
# 0  Data-Science     in-All-Sydney-NSW        1
# 1  Data-Science     in-All-Sydney-NSW        2
# 2  Data-Science     in-All-Sydney-NSW        3
# 3  Data-Science     in-All-Sydney-NSW        4
# 4  Data-Science  in-All-Melbourne-VIC        1
#
#                                             url_link
# 0  https://www.seek.com.au/Data-Science-jobs/in-A...
# 1  https://www.seek.com.au/Data-Science-jobs/in-A...
# 2  https://www.seek.com.au/Data-Science-jobs/in-A...
# 3  https://www.seek.com.au/Data-Science-jobs/in-A...
# 4  https://www.seek.com.au/Data-Science-jobs/in-A...

# %%
# Get all the job posting links from each page
list_of_posts = []
for index in range(0, len(pagelinks_df)):
    # Get the response text from the url
    url = pagelinks_df.iloc[index, 3]
    response = requests.get(url)
    # Parse the response text
    # parse_job_posting(response)
    post = Selector(text=response.text).xpath('//a[@data-automation="jobTitle"]/@href').extract()
    list_of_posts.append(post)

pagelinks_df['Job_Posts'] = list_of_posts
pagelinks_df
# Out:
#                   Job_Desc               Job_Loc Page_Num  \
# 0             Data-Science     in-All-Sydney-NSW        1
# 1             Data-Science     in-All-Sydney-NSW        2
# 2             Data-Science     in-All-Sydney-NSW        3
# 3             Data-Science     in-All-Sydney-NSW        4
# 4             Data-Science  in-All-Melbourne-VIC        1
# 5             Data-Science  in-All-Melbourne-VIC        2
# 6             Data-Science  in-All-Melbourne-VIC        3
# 7             Data-Science  in-All-Melbourne-VIC        4
# 8             Data-Analyst     in-All-Sydney-NSW        1
# 9             Data-Analyst     in-All-Sydney-NSW        2
# 10            Data-Analyst     in-All-Sydney-NSW        3
# 11            Data-Analyst     in-All-Sydney-NSW        4
# 12            Data-Analyst     in-All-Sydney-NSW        5
# 13            Data-Analyst     in-All-Sydney-NSW        6
# 14            Data-Analyst     in-All-Sydney-NSW        7
# 15            Data-Analyst     in-All-Sydney-NSW        8
# 16            Data-Analyst     in-All-Sydney-NSW        9
# 17            Data-Analyst  in-All-Melbourne-VIC        1
# 18            Data-Analyst  in-All-Melbourne-VIC        2
# 19            Data-Analyst  in-All-Melbourne-VIC        3
# 20            Data-Analyst  in-All-Melbourne-VIC        4
# 21            Data-Analyst   in-All-Brisbane-QLD        1
# 22   Business-Intelligence     in-All-Sydney-NSW        1
# 23   Business-Intelligence     in-All-Sydney-NSW        2
# 24   Business-Intelligence     in-All-Sydney-NSW        3
# 25   Business-Intelligence     in-All-Sydney-NSW        4
# 26   Business-Intelligence     in-All-Sydney-NSW        5
# 27   Business-Intelligence     in-All-Sydney-NSW        6
# 28   Business-Intelligence     in-All-Sydney-NSW        7
# 29   Business-Intelligence     in-All-Sydney-NSW        8
# ..                     ...                   ...      ...
# 113       Business-Analyst  in-All-Melbourne-VIC        7
# 114       Business-Analyst  in-All-Melbourne-VIC        8
# 115       Business-Analyst  in-All-Melbourne-VIC        9
# 116       Business-Analyst  in-All-Melbourne-VIC       10
# 29   [/job/33174292?type=standout&tier=no_tier&pos=...
# ..                                                 ...
# 113  [/job/33324312?type=standout&tier=no_tier&pos=...
# 114  [/job/33303886?type=standout&tier=no_tier&pos=...
# 115  [/job/33277805?type=standard&tier=no_tier&pos=...
# 116  [/job/33268915?type=standard&tier=no_tier&pos=...
# 117  [/job/33168991?type=standard&tier=no_tier&pos=...
# 118  [/job/33313702?type=standout&tier=no_tier&pos=...
# 119  [/job/33243600?type=standout&tier=no_tier&pos=...
# 120  [/job/33226831?type=standard&tier=no_tier&pos=...
# 121  [/job/33224565?type=standout&tier=no_tier&pos=...
# 122  [/job/33366757?type=standout&tier=no_tier&pos=...
# 123  [/job/33378010?type=standard&tier=no_tier&pos=...
# 124  [/job/32806095?type=standout&tier=no_tier&pos=...
# 125  [/job/33365983?type=standout&tier=no_tier&pos=...
# 126  [/job/33323339?type=standard&tier=no_tier&pos=...
# 127  [/job/33292082?type=standard&tier=no_tier&pos=...
# 128  [/job/33220593?type=standout&tier=no_tier&pos=...
# 129  [/job/33363403?type=standard&tier=no_tier&pos=...
# 130  [/job/33344072?type=standard&tier=no_tier&pos=...
# 131  [/job/33313920?type=standout&tier=no_tier&pos=...
# 132  [/job/33272312?type=standout&tier=no_tier&pos=...
# 133  [/job/33392660?type=standout&tier=no_tier&pos=...
# 134  [/job/33353618?type=standout&tier=no_tier&pos=...
# 135  [/job/33296637?type=standard&tier=no_tier&pos=...
# 136  [/job/33261542?type=standard&tier=no_tier&pos=...
# 137  [/job/32777669?type=standard&tier=no_tier&pos=...
# 138  [/job/33209989?type=standard&tier=no_tier&pos=...
# 139  [/job/33224726?type=standard&tier=no_tier&pos=...
# 140  [/job/33267321?type=standard&tier=no_tier&pos=...
# 141  [/job/33386112?type=standard&tier=no_tier&pos=...
# 142  [/job/33315072?type=standout&tier=no_tier&pos=...
#
# [143 rows x 5 columns]

# %% [markdown]
# ### C. PARSE JOB POSTINGS FOR THE TEXT TAGS!

# %%
# Go through each page link and get the job post content:
# Description, Job_Title, Salary, Location, Work_Type, Classification,
# DatePosted, Postedby
# Define the start request function
rows = []

# %%
for index in range(0, len(pagelinks_df)):
    # Get the response text from the url
    print('\nPage', index)
    urls = pagelinks_df.iloc[index, 4]
    keyword = pagelinks_df.iloc[index, 0]
    pagenum = pagelinks_df.iloc[index, 2]
    count = 0
    print('\n No of urls to parse:', len(urls))
    for url in urls:
        count = count + 1
        print("\nParshing url: ", count, '/', len(urls))
        url = 'https://www.seek.com.au' + url
        response = requests.get(url)
        title = Selector(text=response.text).xpath('//div[@data-automation="joblisting-index"]/div[@class="grid_6"]/h1/text()').extract_first()
        adv = Selector(text=response.text).xpath('//div[@data-automation="joblisting-index"]/div[@class="grid_6"]/span/text()').extract_first()
        jd1 = Selector(text=response.text).xpath('//div[@class="templatetext"]/p//text()').extract()
        jd2 = Selector(text=response.text).xpath('//div[@class="templatetext"]/ul/li//text()').extract()
        jd3 = Selector(text=response.text).xpath('//div[@class="templatetext"]/text()').extract()
        salary = Selector(text=response.text).xpath('//div[@data-automation="joblisting-index"]/div/div[@class="mod-job-details"]/ul/li/div[@itemprop="baseSalary"]/text()').extract_first()
        worktype = Selector(text=response.text).xpath('//div[@data-automation="joblisting-index"]/div/div[@class="mod-job-details"]/ul/li/div[@itemprop="employmentType"]/text()').extract_first()
        classif = Selector(text=response.text).xpath('//div[@data-automation="joblisting-index"]/div/div[@class="mod-job-details"]/ul/li/div/span[@itemprop="industry"]/text()').extract_first()
        region = Selector(text=response.text).xpath('//div[@data-automation="joblisting-index"]/div/div[@class="mod-job-details"]/ul/li/div/span[@itemprop="addressRegion"]//text()').extract_first()
        location = Selector(text=response.text).xpath('//div[@data-automation="joblisting-index"]/div/div[@class="mod-job-details"]/ul/li/div/span[@itemprop="addressLocality"]//text()').extract_first()
        # Append the scraped items to the list of rows
        rows.append([keyword, pagenum, title, region, location, salary, worktype, adv, classif, jd1, jd2, jd3, url])
# Out:
# Page 0
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 1
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 2
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 3
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 4
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 5
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 6
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 7
#
#  No of urls to parse: 0
#
# Page 8
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 9
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 10
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 11
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 12
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 13
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 14
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 15
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 16
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 17
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 18
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 19
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 20
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 21
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 22
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 23
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 24
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 25
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 26
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 27
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 28
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 29
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 30
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 31
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 32
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 33
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 34
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 35
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 36
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 37
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 38
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 39
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 40
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 41
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 42
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 43
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 44
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 45
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 46
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 47
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 48
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 49
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 50
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 51
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 52
#
#  No of urls to parse: 11
#
# Parshing url:  1 / 11
#
# Parshing url:  2 / 11
#
# Parshing url:  3 / 11
#
# Parshing url:  4 / 11
#
# Parshing url:  5 / 11
#
# Parshing url:  6 / 11
#
# Parshing url:  7 / 11
#
# Parshing url:  8 / 11
#
# Parshing url:  9 / 11
#
# Parshing url:  10 / 11
#
# Parshing url:  11 / 11
#
# Page 53
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 54
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 55
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 56
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 57
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 58
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 59
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 60
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 61
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 62
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 63
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 64
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 65
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 66
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 67
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 68
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 69
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 70
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 71
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 72
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 73
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 74
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 75
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 76
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 77
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 78
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 79
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 80
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 81
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 82
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 83
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 84
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 85
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 86
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 87
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 88
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 89
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 90
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 91
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 92
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 93
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 94
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 95
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 96
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# ...
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 112
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 113
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 114
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 115
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 116
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 117
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 118
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 119
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 120
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 121
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 122
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 123
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 124
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 125
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 126
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 127
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 128
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 129
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 130
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 131
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 132
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 133
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 134
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 135
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 136
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 137
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 138
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 139
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 140
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 141
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20
#
# Page 142
#
#  No of urls to parse: 20
#
# Parshing url:  1 / 20
#
# Parshing url:  2 / 20
#
# Parshing url:  3 / 20
#
# Parshing url:  4 / 20
#
# Parshing url:  5 / 20
#
# Parshing url:  6 / 20
#
# Parshing url:  7 / 20
#
# Parshing url:  8 / 20
#
# Parshing url:  9 / 20
#
# Parshing url:  10 / 20
#
# Parshing url:  11 / 20
#
# Parshing url:  12 / 20
#
# Parshing url:  13 / 20
#
# Parshing url:  14 / 20
#
# Parshing url:  15 / 20
#
# Parshing url:  16 / 20
#
# Parshing url:  17 / 20
#
# Parshing url:  18 / 20
#
# Parshing url:  19 / 20
#
# Parshing url:  20 / 20

# %%
columns = ('keyword', 'pagenum', 'title', 'region', 'location', 'salary', 'worktype', 'adv', 'classif', 'jd1', 'jd2', 'jd3','url')
job_posts_df = pd.DataFrame(rows, columns = columns)

# %%
print(len(job_posts_df))
job_posts_df.tail(120)
# Out:
# 2831
#                keyword  pagenum  \
# 2711  Business-Analyst        5
# 2712  Business-Analyst        5
# 2713  Business-Analyst        5
# 2714  Business-Analyst        5
# 2715  Business-Analyst        5
# 2716  Business-Analyst        5
# 2717  Business-Analyst        5
# 2718  Business-Analyst        5
# 2719  Business-Analyst        5
# 2720  Business-Analyst        5
# 2721  Business-Analyst        5
# 2722  Business-Analyst        5
# 2723  Business-Analyst        5
# 2724  Business-Analyst        5
# 2725  Business-Analyst        5
# 2726  Business-Analyst        5
# 2727  Business-Analyst        5
# 2728  Business-Analyst        5
# 2729  Business-Analyst        5
# 2730  Business-Analyst        5
# 2731  Business-Analyst        6
# 2732  Business-Analyst        6
# 2733  Business-Analyst        6
# 2734  Business-Analyst        6
# 2735  Business-Analyst        6
# 2736  Business-Analyst        6
# 2737  Business-Analyst        6
# 2738  Business-Analyst        6
# 2739  Business-Analyst        6
# 2740  Business-Analyst        6
# ...                ...      ...
# 2801  Business-Analyst        9
# 2802  Business-Analyst        9
# 2803  Business-Analyst        9
# 2804  Business-Analyst        9
# 2805  Business-Analyst        9
# 2806  Business-Analyst        9
# 2807  Business-Analyst        9
# 2808  Business-Analyst        9
# 2809  Business-Analyst        9
# 2810  Business-Analyst        9
# 2811  Business-Analyst       10
# 2812  Business-Analyst       10
# 2813  Business-Analyst       10
# 2814  Business-Analyst       10
# 2815  Business-Analyst       10
# 2816  Business-Analyst       10
# 2817  Business-Analyst       10
# 2818  Business-Analyst       10
# 2819  Business-Analyst       10
# 2820  Business-Analyst       10
# 2821  Business-Analyst       10
# 2822  Business-Analyst       10
# 2823  Business-Analyst       10
# 2824  Business-Analyst       10
# 2825  Business-Analyst       10
# 2826  Business-Analyst       10
# 2827  Business-Analyst       10
# 2828  Business-Analyst       10
# 2829  Business-Analyst       10
# 2830  Business-Analyst       10
#
#                                                   title  \
# 2711                           Senior Business Analysts
# 2712                           Senior Business Analysts
# 2713      Business Analyst - DAF ITP - 6 month contract
# 2714                                   Business Analyst
# 2715                 Business Analyst - Process Mapping
# 2716         Senior Business Analyst/Financial Services
# 2717                                   Business Analyst
# 2718      Business Analyst (Commercial Enterprise Team)
# 2719  Senior Business Analyst (Commercial Enterprise...
# 2720                                   Business Analyst
# 2721                Business Analyst (3 month contract)
# 2722                                   Business Analyst
# 2723  Management Accountant | Business Partnering | ...
# 2724                                   Business Analyst
# 2725               SAP Functional Business Analyst (PM)
# 2726                 Lead Business Analyst - SharePoint
# 2727                            Senior Business Analyst
# 2728     Senior Business Analyst - Mobile Applications
# 2729             SAP Plant Maintenance Business Analyst
# 2807         CBD & Inner Suburbs  Brisbane
# 2808         CBD & Inner Suburbs  Brisbane
# 2809                        None  Brisbane
# 2810         CBD & Inner Suburbs  Brisbane
# 2811         CBD & Inner Suburbs  Brisbane
# 2812         CBD & Inner Suburbs  Brisbane
# 2813                        None  Brisbane
# 2814         CBD & Inner Suburbs  Brisbane
# 2815         CBD & Inner Suburbs  Brisbane
# 2816         CBD & Inner Suburbs  Brisbane
# 2817         CBD & Inner Suburbs  Brisbane
# 2818         CBD & Inner Suburbs  Brisbane
# 2819         CBD & Inner Suburbs  Brisbane
# 2820         CBD & Inner Suburbs  Brisbane
# 2821         CBD & Inner Suburbs  Brisbane
# 2822         CBD & Inner Suburbs  Brisbane
# 2823         CBD & Inner Suburbs  Brisbane
# 2824         CBD & Inner Suburbs  Brisbane
# 2825         CBD & Inner Suburbs  Brisbane
# 2826         CBD & Inner Suburbs  Brisbane
# 2827         CBD & Inner Suburbs  Brisbane
# 2828         CBD & Inner Suburbs  Brisbane
# 2829         CBD & Inner Suburbs  Brisbane
# 2830         CBD & Inner Suburbs  Brisbane
#
#                                   salary         worktype  \
# 2711             $93 934 - $100 624 p.a.    Contract/Temp
# 2712             $93 934 - $100 624 p.a.    Contract/Temp
# 2713                                None    Contract/Temp
# 2714                                None    Contract/Temp
# 2715                                None    Contract/Temp
# 2716                                None    Contract/Temp
# 2717                                None    Contract/Temp
# 2718                                None        Full Time
# 2719                                None        Full Time
# 2720                                None        Full Time
# 2721                                None    Contract/Temp
# 2722                                None        Full Time
# 2723           $320-$400 per day package    Contract/Temp
# 2724                                None    Contract/Temp
# 2725              $60.00 - 90.00 per day    Contract/Temp
# 2726                                None    Contract/Temp
# 2727                                None        Full Time
# 2728                                None    Contract/Temp
# 2729                                None    Contract/Temp
# 2730                                None        Full Time
# 2731                                None    Contract/Temp
# 2732               $25 - $29.99 per hour        Part Time
# 2733                                None        Full Time
# 2734                      $40 - $50 p.h.    Contract/Temp
# 2735                    $60 p.h. + Super    Contract/Temp
# 2736                                None        Full Time
# 2737                                None    Contract/Temp
# 2738                                None    Contract/Temp
# 2739                                None    Contract/Temp
# 2740                                None    Contract/Temp
# ...                                  ...              ...
# 2801                   $95k - $115k p.a.        Full Time
# 2802                      $65 - $67 p.h.    Contract/Temp
# 2803                                None        Full Time
# 2804                                None    Contract/Temp
# 2805                                None        Full Time
# 2806                      $65 - $67 p.h.    Contract/Temp
# 2807                                None    Contract/Temp
# 2808                   $95k - $115k p.a.        Full Time
# 2809  $42.38 per hour (+ superannuation)  Casual/Vacation
# 2810                   $75,000 - $79,999        Full Time
# 2811                                None    Contract/Temp
# 2812                   $70k - $100k p.a.        Full Time
# 2813                                None        Full Time
# 2814                   $95k - $115k p.a.        Full Time
# 2815                                None        Full Time
# 2816                   $70k - $100k p.a.        Full Time
# 2817                                None    Contract/Temp
# 2818                                None    Contract/Temp
# 2819                   $95k - $115k p.a.        Full Time
# 2820                                None    Contract/Temp
# 2732  https://www.seek.com.au/job/33207700?type=stan...
# 2733  https://www.seek.com.au/job/33205078?type=stan...
# 2734  https://www.seek.com.au/job/33205071?type=stan...
# 2735  https://www.seek.com.au/job/33245834?type=stan...
# 2736  https://www.seek.com.au/job/33094620?type=stan...
# 2737  https://www.seek.com.au/job/33246206?type=stan...
# 2738  https://www.seek.com.au/job/33230527?type=stan...
# 2739  https://www.seek.com.au/job/33240895?type=stan...
# 2740  https://www.seek.com.au/job/33240013?type=stan...
# ...                                                 ...
# 2801  https://www.seek.com.au/job/33359256?type=stan...
# 2802  https://www.seek.com.au/job/33357461?type=stan...
# 2803  https://www.seek.com.au/job/33356490?type=stan...
# 2804  https://www.seek.com.au/job/33354187?type=stan...
# 2805  https://www.seek.com.au/job/33352168?type=stan...
# 2806  https://www.seek.com.au/job/33334767?type=stan...
# 2807  https://www.seek.com.au/job/33333892?type=stan...
# 2808  https://www.seek.com.au/job/33324547?type=stan...
# 2809  https://www.seek.com.au/job/33322444?type=stan...
# 2810  https://www.seek.com.au/job/33317831?type=stan...
# 2811  https://www.seek.com.au/job/33315072?type=stan...
# 2812  https://www.seek.com.au/job/33309611?type=stan...
# 2813  https://www.seek.com.au/job/33304221?type=stan...
# 2814  https://www.seek.com.au/job/33303924?type=stan...
# 2815  https://www.seek.com.au/job/33290027?type=stan...
# 2816  https://www.seek.com.au/job/33286883?type=stan...
# 2817  https://www.seek.com.au/job/33286821?type=stan...
# 2818  https://www.seek.com.au/job/33283902?type=stan...
# 2819  https://www.seek.com.au/job/33277403?type=stan...
# 2820  https://www.seek.com.au/job/33276175?type=stan...
# 2821  https://www.seek.com.au/job/33269107?type=stan...
# 2822  https://www.seek.com.au/job/33262499?type=stan...
# 2823  https://www.seek.com.au/job/33262444?type=stan...
# 2824  https://www.seek.com.au/job/33262082?type=stan...
# 2825  https://www.seek.com.au/job/33261766?type=stan...
# 2826  https://www.seek.com.au/job/33257618?type=stan...
# 2827  https://www.seek.com.au/job/33217591?type=stan...
# 2828  https://www.seek.com.au/job/33217202?type=stan...
# 2829  https://www.seek.com.au/job/33212126?type=stan...
# 2830  https://www.seek.com.au/job/33211545?type=stan...
#
# [120 rows x 13 columns]

# %% [markdown]
# ### D. Create SQL DB

# %%
# Write save it to a csv file
job_posts_df.to_csv('.database/Job_Posts_final.csv', index = False)

pagelinks_df.to_csv('.database/Search_Results_final.csv', index = False)

# %%
import sqlite3

posts = pd.read_csv('.database/Job_Posts_final.csv')
results = pd.read_csv('.database/Search_Results_final.csv')
sqlite_db = './jobSeek_final.sqlite'
conn = sqlite3.connect(sqlite_db) 
c = conn.cursor()

# %%
posts.to_sql('job_posts',                 # Name of the table
            con=conn,                    # The handle to the file that is setup
            if_exists='replace',         # Overwrite, append, or fail
            index=False)                 # Add index as column

# %%
results.to_sql('search_results',         # Name of the table
            con=conn,                    # The handle to the file that is setup
            if_exists='replace',         # Overwrite, append, or fail
            index=False)                 # Add index as column

# %%
c.close()
