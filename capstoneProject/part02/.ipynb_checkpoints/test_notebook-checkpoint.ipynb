# %% [markdown]
# # Capstone - Part 2: Problem Statement + EDA: Week 7

# %% [markdown]
# ## REQUIREMENTS

# %% [markdown]
# ### A. Aim

# %% [markdown]
# Analyse the historical plane crash data
#
# - Is it possible to give a safety score to airline, aircraft based on the accident history

# %% [markdown]
# ### B. Proposed Methods and Models

# %% [markdown]
# Analysis models
# - Since the data spans over almost a century, dividing it as per time periods makes sense.
#     As the aircraft type and providers have changed over the years
# - Triangulate locations that are more accident prone
# - Analyse if weather has any influence. The month of a year along with location would be the factors to check.
# - The Summary has important information about the incident. It wold be good to extract information form this in 2 ways:
#     a. Get tag words about the accident conditions like fog, mountain etc
#     b. Use NLP to understand if
# - Analyse the number of
#
# Impact of ticket prices after an accident is reported.? ( No dataset)

# %% [markdown]
# ### C. Risks and Assumptions

# %% [markdown]
# #### Risks:
# - Since the ratio of accidents to the number of flights per year are  less and it is widespread around the world, there is a risk that the data points are less.
#
# #### Assumptions:
# - The dataset contains only the incident data. Since there is no positive data, it would be challenging to get in any kind of prediction model

# %% [markdown]
# ### D. Goal and Criteria
#     - Initial
#     - Revised

# %% [markdown]
# ### E. Local Database
# - Should I write about how I scraped the data?
# - Saving the local database into csv

# %%
import pandas as pd
import numpy as np

# %%
crashes = pd.read_csv('../datasets/plane_crash_info.csv')

# %%
import sqlite3
sqlite_db = '../database/plane_crash_info.sqlite'
conn = sqlite3.connect(sqlite_db) 
c = conn.cursor()

# %%
crashes.to_sql('crashes',             # Name of the table
            con=conn,                    # The handle to the file that is setup
            if_exists='replace',         # Overwrite, append, or fail
            index=False)                 # Add index as column

# %% [markdown]
# ### F. DATA CLEANING & DATA MUNGING

# %% [markdown]
# ### Examine the data

# %%
# Check the data shape to figure out the number of data samples that are available
print('Shape of data', crashes.shape)

# Since this is accidents in the airline industry and the data varies over almost a century, 
# it would be good to check what the data tells.
print(crashes.head())

# The data seems to have some missing values which are denoted by '?'.
# Replace '?' with null/nan values for easier manipulation later on
crashes.replace("?",np.nan, inplace = True)
crashes.head(2)

# Check out the features in the dataframe
features = crashes.columns
print(features)
# From the available features, what new features can be added?
# 1. Date - The date can be split into Day, Month and Year
# 2. Location - It can be used to get the latitudes and longitudes using the google maps api
#             - Location is currently in City, Country format. It can be split into 2 columns
# 3. Operator - It can be split into Flight category(Military, Commercial etc) and additional information for it 
# 4. AIrcraft Type, can we change it to less specific type
# Out:
# Shape of data (5762, 25)
#                  Date      Time                            Location  \
# 0  September 17, 1908  00:00:00                 Fort Myer, Virginia
# 1  September 07, 1909  00:00:00             Juvisy-sur-Orge, France
# 2       July 12, 1912  00:00:00           Atlantic City, New Jersey
# 3     August 06, 1913  00:00:00  Victoria, British Columbia, Canada
# 4      March 05, 1915  00:00:00                     Tienen, Belgium
#
#                  operator Flight          Route                  AcType  Reg  \
# 0    Military - U.S. Army    NaN  Demonstration        Wright Flyer III  NaN
# 1                     NaN    NaN       Air show          Wright Byplane  SC1
# 2    Military - U.S. Navy    NaN    Test flight               Dirigible  NaN
# 3                 Private    NaN            NaN        Curtiss seaplane  NaN
# 4  Military - German Navy    NaN            NaN  Zeppelin L-8 (airship)  NaN
#
#   CnLn Ground:                                            Summary  IsMilitary  \
# 0    1       0  During a demonstration flight, a U.S. Army fly...           1
# 1  NaN       0  Eugene Lefebvre was the first pilot to ever be...           0
# 2  NaN       0  First U.S. dirigible Akron exploded just offsh...           1
# 3  NaN       0  The first fatal airplane accident in Canada oc...           0
# 4  NaN       0  Crashed into trees while attempting to land af...           1
#
#    Year  Month  Day TotalAboard PassAboard CrewAboard TotalFatal PassFatal  \
# 0  1908      9   17           2          1          1          1         1
# 1  1909      9    7           1          0          1          1         0
# 2  1912      7   12           5          0          5          5         0
# 3  1913      8    6           1          0          1          1         0
# 4  1915      3    5          41       None       None         21      None
#
#   CrewFatal                   Country              State      City  Town
# 0         0  United States of America          Fort Myer      None  None
# 1         0                    France    Juvisy-sur-Orge      None  None
# 2         5  United States of America      Atlantic City      None  None
# 3         1                    Canada   British Columbia  Victoria  None
# 4      None                   Belgium             Tienen      None  None
# Index(['Date', 'Time', 'Location', 'operator', 'Flight', 'Route', 'AcType',
#        'Reg', 'CnLn', 'Ground:', 'Summary', 'IsMilitary', 'Year', 'Month',
#        'Day', 'TotalAboard', 'PassAboard', 'CrewAboard', 'TotalFatal',
#        'PassFatal', 'CrewFatal', 'Country', 'State', 'City', 'Town'],
#       dtype='object')

# %%
# Check the null values in the dataset
# Function to check the null counts in a dataframe
def checknullcount(data):
    info = []
    columns = ('Feature', 'Nullcount')
    for col in data.columns:
        nullcount = data[col].isnull().sum()
        info.append([col, nullcount])
    return (pd.DataFrame(columns=columns, data=info).sort_values('Nullcount', ascending = False))

# %%
print(checknullcount(crashes))

# There seem to be a lot of military flights. I want to check if that is the one with the maximum number of nulls
# Check thenumber of data points in military flights
import re
flights_only_military = crashes[crashes['operator'].str.contains("Military") == True]
print('No of military accidents: ', len(flights_only_military))

flights_wo_military = crashes[crashes['operator'].str.contains("Military") == False]
print('Accidents excluding military flights: ', len(flights_wo_military))

# Check nulls after the military flights have been removed
# Check the null values in the dataset
print(checknullcount(flights_wo_military))

# For now I will not drop them. instead create a dummy column which indicates if the type is military or not
crashes['IsMilitary'] = [1 if 'Military' in str(row) else 0 for row in crashes['operator']]

# Check cases where your route is null
crashes[crashes['Route'].isnull() == True]

#With this I can see that the null counts are very high for flight, I checked flight.unique and it returned XXX unique
#values.  

#len(crashes['Flight'].unique())=881

# This means that the flights are random numbers, so I can substitute any random number that 
# is not in the set crashes['Flight'].unique()
# Out:
#         Feature  Nullcount
# 24         Town       5750
# 23         City       5355
# 4        Flight       4428
# 5         Route       1499
# 8          CnLn       1210
# 20    CrewFatal        562
# 19    PassFatal        554
# 17   CrewAboard        545
# 16   PassAboard        539
# 7           Reg        354
# 10      Summary        232
# 22        State        213
# 15  TotalAboard         40
# 6        AcType         24
# 3      operator         21
# 18   TotalFatal         10
# 2      Location          6
# 21      Country          0
# 0          Date          0
# 14          Day          0
# 13        Month          0
# 1          Time          0
# 11   IsMilitary          0
# 9       Ground:          0
# 12         Year          0
# No of military accidents:  829
# Accidents excluding military flights:  4912
#         Feature  Nullcount
# 24         Town       4903
# 23         City       4532
# 4        Flight       3618
# 5         Route       1066
# 8          CnLn        831
# 20    CrewFatal        300
# 19    PassFatal        296
# 17   CrewAboard        290
# 16   PassAboard        287
# 10      Summary        185
# 7           Reg        159
# 22        State        152
# 15  TotalAboard         32
# 6        AcType         12
# 18   TotalFatal          8
# 2      Location          6
# 21      Country          0
# 0          Date          0
# 14          Day          0
# 13        Month          0
# 1          Time          0
# 11   IsMilitary          0
# 9       Ground:          0
# 3      operator          0
# 12         Year          0
# 881

# %%
# Operator

# %%
# Draw distributions for each feature

# %%
# Describe the data
crashes.describe(include='all')
# Out:
#                      Date   Time        Location  operator Flight     Route  \
# count                5762   3645            5756      5741   1334      4263
# unique               5179   1325            4693      2795    880      3840
# top     February 26, 1960  19:30  Moscow, Russia  Aeroflot      -  Training
# freq                    4     27              18       261     65        95
# mean                  NaN    NaN             NaN       NaN    NaN       NaN
# std                   NaN    NaN             NaN       NaN    NaN       NaN
# min                   NaN    NaN             NaN       NaN    NaN       NaN
# 25%                   NaN    NaN             NaN       NaN    NaN       NaN
# 50%                   NaN    NaN             NaN       NaN    NaN       NaN
# 75%                   NaN    NaN             NaN       NaN    NaN       NaN
# max                   NaN    NaN             NaN       NaN    NaN       NaN
#
#               AcType   Reg  CnLn                      Aboard  \
# count           5738  5408  4552                        5762
# unique          2719  5356  4119                        1035
# top     Douglas DC-3    49   178  2   (passengers:0  crew:2)
# freq             340     3     7                         237
# mean             NaN   NaN   NaN                         NaN
# std              NaN   NaN   NaN                         NaN
# min              NaN   NaN   NaN                         NaN
# 25%              NaN   NaN   NaN                         NaN
# 50%              NaN   NaN   NaN                         NaN
# 75%              NaN   NaN   NaN                         NaN
# max              NaN   NaN   NaN                         NaN
#
#                         Fatalities Ground:              Summary   IsMilitary
# count                         5762    5713                 5530  5762.000000
# unique                         914      53                 5333          NaN
# top     1   (passengers:0  crew:1)       0  Crashed on takeoff.          NaN
# freq                           288    5459                   16          NaN
# mean                           NaN     NaN                  NaN     0.143874
# std                            NaN     NaN                  NaN     0.350992
# min                            NaN     NaN                  NaN     0.000000
# 25%                            NaN     NaN                  NaN     0.000000
# 50%                            NaN     NaN                  NaN     0.000000
# 75%                            NaN     NaN                  NaN     0.000000
# max                            NaN     NaN                  NaN     1.000000

# %%
# Check the data types
# Does anything need to be converted
crashes.dtypes
# Aboard, Fatalities, Ground can be changed to integers
# Out:
# Date          object
# Time          object
# Location      object
# operator      object
# Flight        object
# Route         object
# AcType        object
# Reg           object
# CnLn          object
# Aboard        object
# Fatalities    object
# Ground:       object
# Summary       object
# IsMilitary     int64
# dtype: object

# %%
# Check for null values and find ways to impute it.

# %%
# Check for unique values in each of the features

# %%
# NLP on summary to categorize into a type of accident

# %%
# What variables can be converted to dummy variableS?

# %% [markdown]
# ### Updating/Cleaning Features

# %%
# 1. Date - The date can be split into Day, Month and Year
from datetime import datetime as dt

print(crashes.Date.dtypes)

print('Feature list before date was split:')
print(crashes.columns)

crashes['Year'] = pd.DatetimeIndex(crashes['Date']).year
crashes['Month'] = pd.DatetimeIndex(crashes['Date']).month
crashes['Day'] = pd.DatetimeIndex(crashes['Date']).day
crashes['Time'] = pd.DatetimeIndex(crashes['Date']).time

print('Feature list after date was split:')
print(crashes.columns)
# Out:
# object
# Feature list before date was split:
# Index(['Date', 'Time', 'Location', 'operator', 'Flight', 'Route', 'AcType',
#        'Reg', 'CnLn', 'Aboard', 'Fatalities', 'Ground:', 'Summary',
#        'IsMilitary'],
#       dtype='object')
# Feature list after date was split:
# Index(['Date', 'Time', 'Location', 'operator', 'Flight', 'Route', 'AcType',
#        'Reg', 'CnLn', 'Aboard', 'Fatalities', 'Ground:', 'Summary',
#        'IsMilitary', 'Year', 'Month', 'Day'],
#       dtype='object')

# %%
# 2. Change data for Aboard, Fatalities and Ground
import re
# crashes.Aboard.replace(to_replace='(passengers:', value = '', inplace = True)
# for aboard in crashes.Aboard:
#     print(re.findall(r'\d+', aboard))
# crashes.Aboard
aboard = [re.findall(r'\d+', aboard) for aboard in crashes.Aboard]
fatalities = [re.findall(r'\d+', fatal) for fatal in crashes.Fatalities]

aboard_df = pd.DataFrame(aboard, columns = ['TotalAboard', 'PassAboard', 'CrewAboard'])
aboard_df.head()

fatalities_df = pd.DataFrame(fatalities, columns = ['TotalFatal', 'PassFatal', 'CrewFatal'])
fatalities_df.head()

# Concatenate the aboard and fatalities dataframe
crashes = pd.concat([crashes, aboard_df, fatalities_df], axis = 1)
# Deleted redundant columns
crashes.drop(['Aboard', 'Fatalities'], inplace = True, axis = 1)
crashes.columns

# ground = [re.findall(r'\d+', fatal) for fatal in crashes['Ground:']]
# Change null values in ground to 0
crashes['Ground:'].fillna('0', inplace = True)
crashes['Ground:'].value_counts()
# Out:
# 0       5508
# 1         62
# 2         32
# 3         23
# 4         17
# 5         12
# 8         10
# 7         10
# 6          6
# 10         6
# 11         5
# 14         5
# 44         4
# 13         4
# 22         4
# 24         3
# 19         3
# 12         3
# 20         3
# 15         2
# 25         2
# 2750       2
# 23         2
# 35         2
# 17         2
# 30         2
# 125        2
# 50         1
# 63         1
# 36         1
# 67         1
# 53         1
# 49         1
# 52         1
# 47         1
# 39         1
# 29         1
# 32         1
# 85         1
# 58         1
# 78         1
# 71         1
# 87         1
# 16         1
# 225        1
# 45         1
# 18         1
# 9          1
# 113        1
# 40         1
# 37         1
# 31         1
# 33         1
# Name: Ground:, dtype: int64

# %%
# 3. Location - It can be used to get the latitudes and longitudes using the google maps api
#             - Location is currently in City, Country format. It can be split into 2 columns

# The location parameters range from 1 value to 4 values when split.
# Split the location feature to Country, State, Town and City
# loc = [location.split(',')[::-1] for location in crashes.Location]
# loc = pd.DataFrame(loc, columns = ['Country', 'State', 'City', 'Town'])
# # Check for null values in country
# crashes = pd.concat([crashes, loc], axis = 1)
# crashes.head()
crash_location = [str(row).split(',')[::-1] for row in crashes.Location]
crash_location = pd.DataFrame(crash_location, columns = ['Country', 'State', 'City', 'Town'])
crashes = pd.concat([crashes, crash_location], axis = 1)
crashes.head()
# crashes['Country'] = [c for c in crashes.Country]
# Check for null values in country
# Out:
#                  Date      Time                            Location  \
# 0  September 17, 1908  00:00:00                 Fort Myer, Virginia
# 1  September 07, 1909  00:00:00             Juvisy-sur-Orge, France
# 2       July 12, 1912  00:00:00           Atlantic City, New Jersey
# 3     August 06, 1913  00:00:00  Victoria, British Columbia, Canada
# 4      March 05, 1915  00:00:00                     Tienen, Belgium
#
#                  operator Flight          Route                  AcType  Reg  \
# 0    Military - U.S. Army    NaN  Demonstration        Wright Flyer III  NaN
# 1                     NaN    NaN       Air show          Wright Byplane  SC1
# 2    Military - U.S. Navy    NaN    Test flight               Dirigible  NaN
# 3                 Private    NaN            NaN        Curtiss seaplane  NaN
# 4  Military - German Navy    NaN            NaN  Zeppelin L-8 (airship)  NaN
#
#   CnLn Ground:  ...  TotalAboard  PassAboard  CrewAboard  TotalFatal  \
# 0    1       0  ...            2           1           1           1
# 1  NaN       0  ...            1           0           1           1
# 2  NaN       0  ...            5           0           5           5
# 3  NaN       0  ...            1           0           1           1
# 4  NaN       0  ...           41        None        None          21
#
#    PassFatal CrewFatal      Country              State      City  Town
# 0          1         0     Virginia          Fort Myer      None  None
# 1          0         0       France    Juvisy-sur-Orge      None  None
# 2          0         5   New Jersey      Atlantic City      None  None
# 3          0         1       Canada   British Columbia  Victoria  None
# 4       None      None      Belgium             Tienen      None  None
#
# [5 rows x 25 columns]

# %%
# Check the validity of the country column
from geotext import GeoText

fix = []
for row in crashes.Country:
    if (GeoText(row).countries):
        pass
    elif (GeoText(row).cities):
        pass
    else:
        fix.append(row)

print(len(fix))
pd.Series(fix).value_counts().sort_values(0).head()
# Infer: There are 1649 locations that dont have country/city information
# Out:
# 1691
#  Western Samoa                          1
#  Baangladesh                            1
#  French West Indies                     1
# Off Western Africa                      1
#  off the Philippine island of Elalat    1
# dtype: int64

# %%
# I've pulled out all the US states so as to be able to assign them a country
usNames = ['Virginia','New Jersey','Ohio','Pennsylvania', 'Maryland', 'Indiana', 'Iowa',
          'Illinois','Wyoming', 'Minnisota', 'Wisconsin', 'Nevada', 'NY','California',
          'WY','New York','Oregon', 'Idaho', 'Connecticut','Nebraska', 'Minnesota', 'Kansas',
          'Texas', 'Tennessee', 'West Virginia', 'New Mexico', 'Washington', 'Massachusetts',
          'Utah', 'Ilinois','Florida', 'Michigan', 'Arkansas','Colorado', 'Georgia''Missouri',
          'Montana', 'Mississippi','Alaska','Jersey', 'Cailifornia', 'Oklahoma','North Carolina',
          'Kentucky','Delaware','D.C.','Arazona','Arizona','South Dekota','New Hampshire','Hawaii',
          'Washingon','Massachusett','Washington DC','Tennesee','Deleware','Louisiana',
          'Massachutes', 'Louisana', 'New York (Idlewild)','Oklohoma','North Dakota','Rhode Island',
          'Maine','Alakska','Wisconson','Calilfornia','Virginia','Virginia.','CA','Vermont',
          'HI','AK','IN','GA','Coloado','Airzona','Alabama','Alaksa' 
          ]

# Decided to try and cleanse the country names.
afNames = ['Afghanstan'] #Afghanistan
anNames = ['off Angola'] #Angola
ausNames = ['Qld. Australia','Queensland  Australia','Tasmania','off Australia'] #Australia
argNames = ['Aregntina'] #Argentina
azNames = ['Azores (Portugal)'] #Azores
baNames = ['Baangladesh'] #Bangladesh
bahNames = ['Great Inagua'] #Bahamas
berNames = ['off Bermuda'] #Bermuda
bolNames = ['Boliva','BO'] #Bolivia
bhNames = ['Bosnia-Herzegovina'] #Bosnia Herzegovina
bulNames = ['Bugaria','Bulgeria'] #Bulgaria
canNames = ['British Columbia', 'British Columbia Canada','Canada2',
            'Saskatchewan','Yukon Territory'] #Canada
camNames = ['Cameroons','French Cameroons'] #Cameroon
caNames = ['Cape Verde Islands'] #Cape Verde
chNames = ['Chili'] #Chile
coNames = ['Comoro Islands', 'Comoros Islands'] #Comoros
djNames = ['Djbouti','Republiof Djibouti'] #Djibouti
domNames = ['Domincan Republic', 'Dominica'] #Dominican Republic
drcNames = ['Belgian Congo','Belgian Congo (Zaire)','Belgium Congo'
           'DR Congo','DemocratiRepubliCogo','DemocratiRepubliCongo',
            'DemocratiRepubliof Congo','DemoctratiRepubliCongo','Zaire',
           'Zaïre'] #Democratic Republic of Congo
faNames = ['French Equitorial Africa'] #French Equatorial Africa
gerNames = ['East Germany','West Germany'] #Germany
grNames = ['Crete'] #Greece
haNames = ['Hati'] #Haiti
hunNames = ['Hunary'] #Hungary
inNames = ['Indian'] #India
indNames = ['Inodnesia','Netherlands Indies'] #Indonesia
jamNames = ['Jamacia'] #Jamaica
malNames = ['Malaya'] #Malaysia
manNames = ['Manmar'] #Myanmar
marNames = ['Mauretania'] #Mauritania
morNames = ['Morrocco','Morroco'] #Morocco
nedNames = ['Amsterdam','The Netherlands'] #Netherlands
niNames = ['Niger'] #Nigeria
philNames = ['Philipines','Philippine Sea', 'Phillipines',
            'off the Philippine island of Elalat'] #Philippines
romNames = ['Romainia'] #Romania
rusNames = ['Russian','Soviet Union','USSR'] #Russia
saNames = ['Saint Lucia Island'] #Saint Lucia
samNames = ['Western Samoa'] #Samoa
siNames = ['Sierre Leone'] #Sierra Leone
soNames = ['South Africa (Namibia)'] #South Africa
surNames = ['Suriname'] #Surinam
uaeNames = ['United Arab Emirates', 'UAE'] #UAE
ukNames = ['England', 'UK','Wales','110 miles West of Ireland', 'Scotland'] #United Kingdom
uvNames = ['US Virgin Islands','Virgin Islands','U.S. Virgin Islands'] #U.S. Virgin Islands
vietNames = ['South Vietnam']
wkNames = ['325 miles east of Wake Island']#Wake Island
yuNames = ['Yugosalvia'] #Yugoslavia
zimNames = ['Rhodesia', 'Rhodesia (Zimbabwe)'] #Zimbabwe

clnames = []
for country in crashes['Country'].values:
    country = country.strip()
    if country in afNames:
        clnames.append('Afghanistan')
    elif country in anNames:
        clnames.append('Angola')
    elif country in ausNames:
        clnames.append('Australia')
    elif country in argNames:
        clnames.append('Argentina')
    elif country in azNames:
        clnames.append('Azores')
    elif country in baNames:
        clnames.append('Bangladesh')
    elif country in bahNames:
        clnames.append('Bahamas')
    elif country in berNames:
        clnames.append('Bermuda')
    elif country in bolNames:
        clnames.append('Bolivia')
    elif country in bhNames:
        clnames.append('Bosnia Herzegovina')
    elif country in bulNames:
        clnames.append('Bulgaria')
    elif country in canNames:
        clnames.append('Canada')
    elif country in camNames:
        clnames.append('Cameroon')
    elif country in caNames:
        clnames.append('Cape Verde')
    elif country in chNames:
        clnames.append('Chile')
    elif country in coNames:
        clnames.append('Comoros')
    elif country in djNames:
        clnames.append('Djibouti')
    elif country in domNames:
        clnames.append('Dominican Republic')
    elif country in drcNames:
        clnames.append('Democratic Republic of Congo')
    elif country in faNames:
        clnames.append('French Equatorial Africa')
    elif country in gerNames:
        clnames.append('Germany')
    elif country in grNames:
        clnames.append('Greece')
    elif country in haNames:
        clnames.append('Haiti')
    elif country in hunNames:
        clnames.append('Hungary')
    elif country in inNames:
        clnames.append('India')
    elif country in jamNames:
        clnames.append('Jamaica')
    elif country in malNames:
        clnames.append('Malaysia')
    elif country in manNames:
        clnames.append('Myanmar')
    elif country in marNames:
        clnames.append('Mauritania')
    elif country in morNames:
        clnames.append('Morocco')
    elif country in nedNames:
        clnames.append('Netherlands')
    elif country in niNames:
        clnames.append('Nigeria')
    elif country in philNames:
        clnames.append('Philippines')
    elif country in romNames:
        clnames.append('Romania')
    elif country in rusNames:
        clnames.append('Russia')
    elif country in saNames:
        clnames.append('Saint Lucia')
    elif country in samNames:
        clnames.append('Samoa')
    elif country in siNames:
        clnames.append('Sierra Leone')
    elif country in soNames:
        clnames.append('South Africa')
    elif country in surNames:
        clnames.append('Surinam')
    elif country in uaeNames:
        clnames.append('UAE')
    elif country in ukNames:
        clnames.append('United Kingdom')
    elif country in usNames:
        clnames.append('United States of America')
    elif country in uvNames:
        clnames.append('U.S. Virgin Islands')
    elif country in vietNames:
        clnames.append('Vietnam')
    elif country in wkNames:
        clnames.append('Wake Island')
    elif country in yuNames:
        clnames.append('Yugoslavia')
    elif country in zimNames:
        clnames.append('Zimbabwe')
    else:
        clnames.append(country)
        
crashes['Country'] = clnames

# %%
# Check the validity of the country column
# Set minimum number of rows and columns to be displayed as we are dealing with a large dataset
pd.options.display.max_rows = 500
pd.options.display.max_columns = 100
from geotext import GeoText

fix = []
for row in crashes.Country:
    if (GeoText(row).countries):
        pass
    elif (GeoText(row).country_mentions):
        pass
    elif (GeoText(row).cities):
        pass
    else:
        fix.append(row)


pd.Series(fix).value_counts()
print(len(fix))
pd.Series(fix)
# Infer: There are 1649 locations that dont have country/city information
# Out:
# 415
# 0                        Over the North Sea
# 1                                 North Sea
# 2                      Off Northern Germany
# 3                                 North Sea
# 4                                 North Sea
# 5                    Over the Mediterranean
# 6                             Off Gibraltar
# 7                      North Atlantic Ocean
# 8                Over the Mediterranean Sea
# 9                  Over the English Channel
# 10                          English Channel
# 11                           Czechoslovakia
# 12                          English Channel
# 13                            Unied Kingdom
# 14                           Atlantic Ocean
# 15                                   Ariège
# 16                            Off Gibraltar
# 17                              Off Morocco
# 18                     North Atlantic Ocean
# 19                            East Sardinia
# 20                           Czechoslovakia
# 21                                Off Spain
# 22                                    Burma
# 23                              Off Algiers
# 24                               Aegean Sea
# 25                               Yugoslavia
# 26                          English Channel
# 27                          English Channel
# 28                           Atlantic Ocean
# 29                     South Atlantic Ocean
# 30                          English Channel
# 31                                      nan
# 32                              Near Moscow
# 33                       French West Africa
# 34                               New Guinea
# 35                       Off Western Africa
# 36                       Netherlands Indies
# 37                           Czechoslovakia
# 38                        Mediterranean Sea
# 39                               Tanganyika
# 40                     Near Bogota Colombia
# 41                           East China Sea
# 42                               Mocambique
# 43                                North Sea
# 44                           Off Malta-Luqa
# 45                           Gulf of Tonkin
# 46                        Mediterranean Sea
# 47                        Mediterranean Sea
# 48                           Atlantic Ocean
# 49                                 bulgaria
# 50                                    Timor
# 51                                    Timor
# 52                                      nan
# 53                             Indian Ocean
# 54                                      nan
# 55                          Off West Africa
# 56                             Newfoundland
# 57                             Dutch Guyana
# 58                           Atlantic Ocean
# 59                             Newfoundland
# 60                                North Sea
# 61                               New Guinea
# 62                                North Sea
# 63                            Eastern Libya
# 64                               New Guinea
# 65                               Yugoslavia
# 66                               New Guinea
# 67                               Yugoslavia
# 68                     North Atlantic Ocean
# 69                            Pacific Ocean
# 70                                    Swden
# 71                               Yugoslavia
# 72                                   Bosnia
# 73                           Atlantic Ocean
# 74                          English Channel
# 75                          Washington D.C.
# 76                               New Guinea
# 77                               New Guinea
# 78                           South Carolina
# 79                     North Atlantic Ocean
# 80                           South Carolina
# 81                               New Guinea
# 82                           Atlantic Ocean
# 83                                Himalayas
# 84                               New Guinea
# 85                 French Equatorial Africa
# 86                           Czechoslovakia
# 87                             Indian Ocean
# 88                         Northern Ireland
# 89                               Off Malaya
# 90                                    Burma
# 91                             Newfoundland
# 92     Near Hong Kong International Airport
# 93                             Newfoundland
# 94                      North Pacific Ocean
# 95                           Atlantic Ocean
# 96                            Pacific Ocean
# 97                      Gulf of Karkinitsky
# 98                      North Pacific Ocean
# 99                             Persian Gulf
# 100          800 miles east of Newfoundland
# 101                                     nan
# 102                              Yugoslavia
# 103                                Labrador
# 104                 Territory of New Guinea
# 105                     Near Irkutsk Russia
# 106            Democratic Republic of Congo
# 107                       French Indo-China
# 108                          Atlantic Ocean
# 109                           Belgium Congo
# 110                            Newfoundland
# 111                                Manitoba
# 112            Democratic Republic of Congo
# 113                                  Azores
# 114                          Czechoslovakia
# 115                               North Sea
# 116                                  Azores
# 117                          South Carolina
# 118                             Off Bahrain
# 119                             Off Bahrain
# 120                              Yugoslavia
# 121                French Equatorial Africa
# 122                 Over the North Atlantic
# 123                              Yugoslavia
# 124                              New Guinea
# 125                 Near Tachikawa Air Base
# 126                          North Atlantic
# 127                              Yugoslavia
# 128                              New Guinea
# 129            Democratic Republic of Congo
# 130                      French West Africa
# 131                         English Channel
# 132                              Baltic Sea
# 133                               North Sea
# 134                           West Pakistan
# 135                        Northern Ireland
# 136                            Newfoundland
# 137                              Tanganyika
# 138                       French Indo-China
# 139                             Wake Island
# 140                                     UAE
# 141                         Off Irish coast
# 142                         Mariana Islands
# 143                          Czechoslovakia
# 144                               North Sea
# 145                                   Mexic
# 146                                 Sarawak
# 147                                     HI)
# 148                          South Carolina
# 149                     Over North Carolina
# 150                          Czechoslovakia
# 151                                   Burma
# 152                  Over the Pacific Ocean
# 153              Over the Mediterranean Sea
# 154            Over the North Pacific Ocean
# 155                           Pacific Ocean
# 156                                  Azores
# 157                                Off Guam
# 158              Over the Mediterranean Sea
# 159                    North Atlantic Ocean
# 160                               Uzbekstan
# 161                                 Surinam
# 162                            Newfoundland
# 163            Democratic Republic of Congo
# 164                            Persian Gulf
# 165            Democratic Republic of Congo
# 166                         Mariana Islands
# 167                          Czechoslovakia
# 168         Midway Island Naval Air Station
# 169                                  Azores
# 170                         Off Puerto Rico
# 171                                Sao Tomé
# 172                          Near Hong Kong
# 173                                   Burma
# 174                             West Indies
# 175                          Czechoslovakia
# 176                    North Atlantic Ocean
# 177                          Czechoslovakia
# 178                     Sao Tomé & Principe
# 179                                   Burma
# 180                          Northeast Laos
# 181                   Near Chicago Illinois
# 182                     North Pacific Ocean
# 183                           Saudia Arabia
# 184                              Yugoslavia
# 185        Democratic Republic of the Congo
# 186                     U.S. Virgin Islands
# 187                                 Antigua
# 188                       French Somaliland
# 189                   Southeastern Colombia
# 190                          Canary Islands
# 191                              Yugoslavia
# 192                          Czechoslovakia
# 193                          Atlantic Ocean
# 194                                     UAR
# 195            Northwest Territories Canada
# 196                       Malagasy Republic
# 197                       Off South Vietnam
# 198                           Caribbean Sea
# 199                          Northern India
# 200                             West Indies
# 201                           West Pakistan
# 202                               Off Chili
# 203                      Near Recife Brazil
# 204                             Wake Island
# 205                          Czechoslovakia
# 206                     U.S. Virgin Islands
# 207                          Atlantic Ocean
# 208            Democratic Republic of Congo
# 209                           East Pakistan
# 210                                   Burma
# 211                          Gulf of Tonkin
# 212                      Near Villia Greece
# 213                                   Congo
# 214                              New Guinea
# 215                     U.S. Virgin Islands
# 216                    North Atlantic Ocean
# 217                     U.S. Virgin Islands
# 218                     U.S. Virgin Islands
# 219                              Yugoslavia
# 220                     North Pacific Ocean
# 221                                     UAE
# 222                             South Yemen
# 223                              New Guinea
# 224                                   Burma
# 225                              New Guinea
# 226                    North Atlantic Ocean
# 227                    Off the Alaska coast
# 228                          Canary Islands
# 229                          South Carolina
# 230                          Czechoslovakia
# 231                                  Tahiti
# 232                              Yugoslavia
# 233                     Sainte Lucia Island
# 234                         : Massachusetts
# 235                          Atlantic Ocean
# 236                          Khmer Republic
# 237                             Upper Volta
# 238            Democratic Republic of Congo
# 239                     U.S. Virgin Islands
# 240                          Formosa Strait
# 241                          Czechoslovakia
# 242                     U.S. Virgin Islands
# 243                    Southeastern Bolivia
# 244                     U.S. Virgin Islands
# 245                                   Burma
# 246                          Czechoslovakia
# 247                              Yugoslavia
# 248                          Atlantic Ocean
# 249                                   Congo
# 250                                     nan
# 251                          Canary Islands
# 252                         Off Wake Island
# 253                           Off Hong Kong
# 254                                   Burma
# 255                              Yugoslavia
# 256                          Canary Islands
# 257                     U.S. Virgin Islands
# 258                                   Burma
# 259                              West Samoa
# 260                            Newfoundland
# 261                                   Burma
# 262                          Atlantic Ocean
# 263                          Atlantic Ocean
# 264                             West Indies
# 265                               Caribbean
# 266                      Bosnia Herzegovina
# 267                     U.S. Virgin Islands
# 268                          South Carolina
# 269                 Over the Atlantic Ocean
# 270                                   Burma
# 271                          Canary Islands
# 272            Democratic Republic of Congo
# 273            Democratic Republic of Congo
# 274                              New Guinea
# 275                     U.S. Virgin Islands
# 276                    South Atlantic Ocean
# 277                           Pacific Ocean
# 278                              Off Taiwan
# 279                          Atlantic Ocean
# 280                  Barquisimeto Venezuela
# 281                                     UAE
# 282                             Off  Bimini
# 283                              New Guinea
# 284            Democratic Republic of Congo
# 285            Democratic Republic of Congo
# 286                            Islay Island
# 287                         Leeward Islands
# 288                              New Guinea
# 289                                   Burma
# 290                            Indian Ocean
# 291                    Over the Andaman Sea
# 292                           Pacific Ocean
# 293                           Eugene Island
# 294                      Central Mozambique
# 295                    Northern Afghanistan
# 296            Democratic Republic of Congo
# 297                                 Surinam
# 298                              New Guinea
# 299                           Milford Sound
# 300                                   Congo
# 301            Democratic Republic of Congo
# 302                              New Guinea
# 303                      Grenadines Islands
# 304                                     nan
# 305                                   Congo
# 306                     U.S. Virgin Islands
# 307                                   Congo
# 308               Democratic Republic Congo
# 309               Democratic Republic Congo
# 310                                Near Nag
# 311                           Northern Iraq
# 312               Democratic Republic Congo
# 313                           Pacific Ocean
# 314                              New Guinea
# 315                               Inodnesia
# 316                               Kirghizia
# 317                              New Guinea
# 318            Democratic Republic of Congo
# 319               Democratic Republic Congo
# 320                              New Guinea
# 321                              Yugoslavia
# 322                                   Congo
# 323                         Northern Israel
# 324               Democratic Republic Congo
# 325                                   Congo
# 326                              New Guinea
# 327                                  Africa
# 328            Democratic Republic of Congo
# 329                                     UAE
# 330                  Over the Pacific Ocean
# 331                                     UAE
# 332                                   Congo
# 333               Democratic Republic Congo
# 334                            South Dakota
# 335                                  Azores
# 336               Democratic Republic Congo
# 337                                   Congo
# 338                                   Congo
# 339               Democratic Republic Congo
# 340                                 Surinam
# 341                      French West Indies
# 342               Democratic Republic Congo
# 343                                  Azores
# 344               Democratic Republic Congo
# 345                            South Dakota
# 346                                Manitoba
# 347                                Chechnya
# 348                                   Congo
# 349                Sao Gabriel de Cachoeria
# 350                                   Congo
# 351                                     UAE
# 352                      Bosnia Herzegovina
# 353               Democratic Republic Congo
# 354                              New Guinea
# 355               Democratic Republic Congo
# 356                                   Congo
# 357              Democtratic Republic Congo
# 358                                   Congo
# 359                Democratic Republic Cogo
# 360                             Near Karkov
# 361                     Off São Tomé Island
# 362                                   Napal
# 363               Democratic Republic Congo
# 364               Democratic Republic Congo
# 365                  Turks & Caicos Islands
# 366                                Chechnya
# 367                                   Congo
# 368                                   Congo
# 369               Democratic Republic Congo
# 370               Democratic Republic Congo
# 371                                DR Congo
# 372                                DR Congo
# 373                                 Surinam
# 374                                   Congo
# 375                               Black Sea
# 376                                   Congo
# 377                                     UAE
# 378                          South Carolina
# 379            Off Turks and Caicos Islands
# 380                    Near Houma Louisiana
# 381                            Newfoundland
# 382            Democratic Republic of Congo
# 383               Democratic Republic Congo
# 384                        South Kazakistan
# 385                                   Congo
# 386                          South Carolina
# 387                                     UAE
# 388                              New Guinea
# 389                                 Surinam
# 390               Congo Democratic Republic
# 391                                     UAE
# 392                    Fox Glacier Airstrip
# 393                                   Congo
# 394                                   Congo
# 395                                   Congo
# 396                                   Congo
# 397                            South Dakota
# 398                                   Congo
# 399                                 Antigua
# 400                                   Congo
# 401                                   Congo
# 402                                  Borneo
# 403                        Glasgow Scotland
# 404                                  Nambia
# 405                   Near Petreasa Romania
# 406                      South Indian Ocean
# 407                                   Congo
# 408                                Java Sea
# 409                                Argenina
# 410                                   Papua
# 411                                   Congo
# 412                            Indian Ocean
# 413                                     UAE
# 414             Malta International Airport
# dtype: object

# %%
do_geocode('Democratic Republic of Congo')
# Out:
# Location(République démocratique du Congo, (-2.9814343, 23.8222636, 0.0))

# %%
# (GeoText('Congo').countries)
from geopy.geocoders import Nominatim
from geotext import GeoText
from geopy.exc import GeocoderTimedOut
import time

geolocator = Nominatim()
geoloc_default = geolocator.reverse("0, 0")

def do_geocode(address):
    try:
        return geolocator.geocode(address, addressdetails=True)
    except GeocoderTimedOut:
        return do_geocode(address)
    

geoloc = []
for loc in fix[44:]:
    print(loc)
    location = do_geocode(loc)
    if(location):
        time.sleep(10)
        geoloc.append(location)
    else:
        pass
#             geoloc.append(geoloc_default)
#     else:
#         geoloc.append(geoloc_default)
# Out:
# Off Malta-Luqa
# Gulf of Tonkin
# Mediterranean Sea
# Mediterranean Sea
# Atlantic Ocean
# bulgaria
# Timor
# Timor
# nan
# Indian Ocean
# nan
# Off West Africa
# Newfoundland
# Dutch Guyana
# Atlantic Ocean
# Newfoundland
# North Sea
# New Guinea
# North Sea
# Eastern Libya
# New Guinea
# Yugoslavia
# New Guinea
# Yugoslavia
# North Atlantic Ocean
# Pacific Ocean
# Swden
# Yugoslavia
# Bosnia
# Atlantic Ocean
# English Channel
# Washington D.C.
# New Guinea
# New Guinea
# South Carolina
# North Atlantic Ocean
# South Carolina
# New Guinea
# Atlantic Ocean
# Himalayas
# New Guinea
# French Equatorial Africa
# Czechoslovakia
# Indian Ocean
# Northern Ireland
# Off Malaya
# Burma
# Newfoundland
# Near Hong Kong International Airport
# Newfoundland
# North Pacific Ocean
# Atlantic Ocean
# Pacific Ocean
# Gulf of Karkinitsky
# North Pacific Ocean
# Persian Gulf
# 800 miles east of Newfoundland
# nan
# Yugoslavia
# Labrador
# Territory of New Guinea
# Near Irkutsk Russia
# Democratic Republic of Congo
# French Indo-China
# Atlantic Ocean
# Belgium Congo
# Newfoundland
# Manitoba
# Democratic Republic of Congo
# Azores
# Czechoslovakia
# North Sea
# Azores
# South Carolina
# Off Bahrain
# Off Bahrain
# Yugoslavia
# French Equatorial Africa
# Over the North Atlantic
# Yugoslavia
# New Guinea
# Near Tachikawa Air Base
# North Atlantic
# Yugoslavia
# New Guinea
# Democratic Republic of Congo
# French West Africa
# English Channel
# Baltic Sea
# North Sea
# West Pakistan
# Northern Ireland
# Newfoundland
# Tanganyika
# French Indo-China
# Wake Island
# UAE
# Off Irish coast
# Mariana Islands
# Czechoslovakia
# North Sea
# Mexic
# Sarawak
# HI)
# South Carolina
# Over North Carolina
# Czechoslovakia
# Burma
# Over the Pacific Ocean
# Over the Mediterranean Sea
# Over the North Pacific Ocean
# Pacific Ocean
# Azores
# Off Guam
# Over the Mediterranean Sea
# North Atlantic Ocean
# Uzbekstan
# Surinam
# Newfoundland
# Democratic Republic of Congo
# Persian Gulf
# Democratic Republic of Congo
# Mariana Islands
# Czechoslovakia
# Midway Island Naval Air Station
# Azores
# Off Puerto Rico
# Sao Tomé
# Near Hong Kong
# Burma
# West Indies
# Czechoslovakia
# North Atlantic Ocean
# Czechoslovakia
# Sao Tomé & Principe
# Burma
# Northeast Laos
# Near Chicago Illinois
# North Pacific Ocean
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# /Users/roshanlulu/anaconda3/lib/python3.6/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     142         try:
# --> 143             page = requester(req, timeout=(timeout or self.timeout), **kwargs)
#     144         except Exception as error: # pylint: disable=W0703
#
# /Users/roshanlulu/anaconda3/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#
# /Users/roshanlulu/anaconda3/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     525
# --> 526         response = self._open(req, data)
#     527
#
# /Users/roshanlulu/anaconda3/lib/python3.6/urllib/request.py in _open(self, req, data)
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#
# /Users/roshanlulu/anaconda3/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#
# /Users/roshanlulu/anaconda3/lib/python3.6/urllib/request.py in https_open(self, req)
#    1360             return self.do_open(http.client.HTTPSConnection, req,
# -> 1361                 context=self._context, check_hostname=self._check_hostname)
#    1362
#
# /Users/roshanlulu/anaconda3/lib/python3.6/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1320                 raise URLError(err)
# -> 1321             r = h.getresponse()
#    1322         except:
#
# /Users/roshanlulu/anaconda3/lib/python3.6/http/client.py in getresponse(self)
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#
# /Users/roshanlulu/anaconda3/lib/python3.6/http/client.py in begin(self)
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#
# /Users/roshanlulu/anaconda3/lib/python3.6/http/client.py in _read_status(self)
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#
# /Users/roshanlulu/anaconda3/lib/python3.6/socket.py in readinto(self, b)
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#
# /Users/roshanlulu/anaconda3/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1001                   self.__class__)
# -> 1002             return self.read(nbytes, buffer)
#    1003         else:
#
# /Users/roshanlulu/anaconda3/lib/python3.6/ssl.py in read(self, len, buffer)
#     864         try:
# --> 865             return self._sslobj.read(len, buffer)
#     866         except SSLError as x:
#
# /Users/roshanlulu/anaconda3/lib/python3.6/ssl.py in read(self, len, buffer)
#     624         if buffer is not None:
# --> 625             v = self._sslobj.read(len, buffer)
#     626         else:
#
# timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# GeocoderTimedOut                          Traceback (most recent call last)
# <ipython-input-58-129a53ec6c83> in do_geocode(address)
#      11     try:
# ---> 12         return geolocator.geocode(address, addressdetails=True)
#      13     except GeocoderTimedOut:
#
# /Users/roshanlulu/anaconda3/lib/python3.6/site-packages/geopy/geocoders/osm.py in geocode(self, query, exactly_one, timeout, addressdetails, language, geometry)
#     192         return self._parse_json(
# --> 193             self._call_geocoder(url, timeout=timeout), exactly_one
#     194         )
#
# /Users/roshanlulu/anaconda3/lib/python3.6/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     166             elif isinstance(error, SocketTimeout):
# --> 167                 raise GeocoderTimedOut('Service timed out')
#     168             elif isinstance(error, SSLError):
#
# GeocoderTimedOut: Service timed out
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# /Users/roshanlulu/anaconda3/lib/python3.6/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1317                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
#
# /Users/roshanlulu/anaconda3/lib/python3.6/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# /Users/roshanlulu/anaconda3/lib/python3.6/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#
# /Users/roshanlulu/anaconda3/lib/python3.6/http/client.py in endheaders(self, message_body, encode_chunked)
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#
# /Users/roshanlulu/anaconda3/lib/python3.6/http/client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# /Users/roshanlulu/anaconda3/lib/python3.6/http/client.py in send(self, data)
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#
# /Users/roshanlulu/anaconda3/lib/python3.6/http/client.py in connect(self)
#    1391
# -> 1392             super().connect()
#    1393
#
# /Users/roshanlulu/anaconda3/lib/python3.6/http/client.py in connect(self)
#     935         self.sock = self._create_connection(
# --> 936             (self.host,self.port), self.timeout, self.source_address)
#     937         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# /Users/roshanlulu/anaconda3/lib/python3.6/socket.py in create_connection(address, timeout, source_address)
#     721     if err is not None:
# --> 722         raise err
#     723     else:
#
# /Users/roshanlulu/anaconda3/lib/python3.6/socket.py in create_connection(address, timeout, source_address)
#     712                 sock.bind(source_address)
# --> 713             sock.connect(sa)
#     714             return sock
#
# OSError: [Errno 65] No route to host
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# /Users/roshanlulu/anaconda3/lib/python3.6/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     142         try:
# --> 143             page = requester(req, timeout=(timeout or self.timeout), **kwargs)
#     144         except Exception as error: # pylint: disable=W0703
#
# /Users/roshanlulu/anaconda3/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#
# /Users/roshanlulu/anaconda3/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     525
# --> 526         response = self._open(req, data)
#     527
#
# /Users/roshanlulu/anaconda3/lib/python3.6/urllib/request.py in _open(self, req, data)
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#
# /Users/roshanlulu/anaconda3/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#
# /Users/roshanlulu/anaconda3/lib/python3.6/urllib/request.py in https_open(self, req)
#    1360             return self.do_open(http.client.HTTPSConnection, req,
# -> 1361                 context=self._context, check_hostname=self._check_hostname)
#    1362
#
# /Users/roshanlulu/anaconda3/lib/python3.6/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1319             except OSError as err: # timeout error
# -> 1320                 raise URLError(err)
#    1321             r = h.getresponse()
#
# URLError: <urlopen error [Errno 65] No route to host>
#
# During handling of the above exception, another exception occurred:
#
# GeocoderServiceError                      Traceback (most recent call last)
# <ipython-input-58-129a53ec6c83> in <module>()
#      18 for loc in fix[44:]:
#      19     print(loc)
# ---> 20     location = do_geocode(loc)
#      21     if(location):
#      22         time.sleep(10)
#
# <ipython-input-58-129a53ec6c83> in do_geocode(address)
#      12         return geolocator.geocode(address, addressdetails=True)
#      13     except GeocoderTimedOut:
# ---> 14         return do_geocode(address)
#      15
#      16
#
# <ipython-input-58-129a53ec6c83> in do_geocode(address)
#      10 def do_geocode(address):
#      11     try:
# ---> 12         return geolocator.geocode(address, addressdetails=True)
#      13     except GeocoderTimedOut:
#      14         return do_geocode(address)
#
# /Users/roshanlulu/anaconda3/lib/python3.6/site-packages/geopy/geocoders/osm.py in geocode(self, query, exactly_one, timeout, addressdetails, language, geometry)
#     191         logger.debug("%s.geocode: %s", self.__class__.__name__, url)
#     192         return self._parse_json(
# --> 193             self._call_geocoder(url, timeout=timeout), exactly_one
#     194         )
#     195
#
# /Users/roshanlulu/anaconda3/lib/python3.6/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     169                 if "timed out" in message:
#     170                     raise GeocoderTimedOut('Service timed out')
# --> 171             raise GeocoderServiceError(message)
#     172
#     173         if hasattr(page, 'getcode'):
#
# GeocoderServiceError: [Errno 65] No route to host

# %%
geoloc
# Out:
# [Location(Gulf of Tonkin, (20.0000001, 107.9999999, 0.0)),
#  Location(Mediterranean Sea, (35.0000035, 19.9999957, 0.0)),
#  Location(Mediterranean Sea, (35.0000035, 19.9999957, 0.0)),
#  Location(Atlantic Ocean, (13.581921, -38.3203119, 0.0)),
#  Location(България, (42.6073975, 25.4856617, 0.0)),
#  Location(Timor, Nusa Tenggara Timur, Indonesia, (-9.346017, 124.637279937916, 0.0)),
#  Location(Timor, Nusa Tenggara Timur, Indonesia, (-9.346017, 124.637279937916, 0.0)),
#  Location(Nangarhar ننگرهار, افغانستان, (34.220389, 70.3800314, 0.0)),
#  Location(Indian Ocean, (-9.9999998, 69.9999999, 0.0)),
#  Location(Nangarhar ننگرهار, افغانستان, (34.220389, 70.3800314, 0.0)),
#  Location(Newfoundland, Newfoundland and Labrador, Canada, (49.12120935, -56.696296112741, 0.0)),
#  Location(Atlantic Ocean, (13.581921, -38.3203119, 0.0)),
#  Location(Newfoundland, Newfoundland and Labrador, Canada, (49.12120935, -56.696296112741, 0.0)),
#  Location(North Sea, (55.3333373, 2.9999964, 0.0)),
#  Location(New Guinea, Kiunga District, Western, Papua Region, Papua Niugini, (-5.5227499, 142.073628608765, 0.0)),
#  Location(North Sea, (55.3333373, 2.9999964, 0.0)),
#  Location(Libya Nursery School, Buvulunguti, Kaliro, Eastern Region, Uganda, (1.162372, 33.437975, 0.0)),
#  Location(New Guinea, Kiunga District, Western, Papua Region, Papua Niugini, (-5.5227499, 142.073628608765, 0.0)),
#  Location(Yugoslavia, Morelia, Michoacán de Ocampo, 58210, México, (19.7297308, -101.1732149, 0.0)),
#  Location(New Guinea, Kiunga District, Western, Papua Region, Papua Niugini, (-5.5227499, 142.073628608765, 0.0)),
#  Location(Yugoslavia, Morelia, Michoacán de Ocampo, 58210, México, (19.7297308, -101.1732149, 0.0)),
#  Location(Norda Atlantika Oceano, (40.0, -39.9999999, 0.0)),
#  Location(Pacific Ocean, (-0.7031069, -120.9374999, 0.0)),
#  Location(Swden, Bulevar Ivana Crnojevića, Drač, Podgorica, Opština Podgorica, 81102, Црна Гора / Crna Gora, (42.4436047, 19.2653535, 0.0)),
#  Location(Yugoslavia, Morelia, Michoacán de Ocampo, 58210, México, (19.7297308, -101.1732149, 0.0)),
#  Location(Bośnia, gmina Dydnia, powiat brzozowski, podkarpackie, Polska, (49.6786111, 22.1288889, 0.0)),
#  Location(Atlantic Ocean, (13.581921, -38.3203119, 0.0)),
#  Location(English Channel, France, (50.0222324, -1.0513227, 0.0)),
#  Location(Washington, District of Columbia, United States of America, (38.8949549, -77.0366455, 0.0)),
#  Location(New Guinea, Kiunga District, Western, Papua Region, Papua Niugini, (-5.5227499, 142.073628608765, 0.0)),
#  Location(New Guinea, Kiunga District, Western, Papua Region, Papua Niugini, (-5.5227499, 142.073628608765, 0.0)),
#  Location(South Carolina, United States of America, (33.6874388, -80.4363742, 0.0)),
#  Location(Norda Atlantika Oceano, (40.0, -39.9999999, 0.0)),
#  Location(South Carolina, United States of America, (33.6874388, -80.4363742, 0.0)),
#  Location(New Guinea, Kiunga District, Western, Papua Region, Papua Niugini, (-5.5227499, 142.073628608765, 0.0)),
#  Location(Atlantic Ocean, (13.581921, -38.3203119, 0.0)),
#  Location(Himalayas, Khumjung, सोलुखुम्बु, सगरमाथा अञ्चल, पुर्वाञ्चल विकास क्षेत्र, नेपाल, (27.985688, 86.9163367, 0.0)),
#  Location(New Guinea, Kiunga District, Western, Papua Region, Papua Niugini, (-5.5227499, 142.073628608765, 0.0)),
#  Location(Czechoslovakia Cemetery, South Road, Howard County, Nebraska, 68838, United States of America, (41.2133453, -98.6228518, 0.0)),
#  Location(Indian Ocean, (-9.9999998, 69.9999999, 0.0)),
#  Location(Northern Ireland, UK, (54.6294982, -6.7654415, 0.0)),
#  Location(Tarak Ridge Jump-off, Tarak Trail, Maligaya, Bataan, Central Luzon, 2105, Philippines, (14.4753546, 120.5194083, 0.0)),
#  Location(မြန်မာ, (17.1750495, 95.9999652, 0.0)),
#  Location(Newfoundland, Newfoundland and Labrador, Canada, (49.12120935, -56.696296112741, 0.0)),
#  Location(Newfoundland, Newfoundland and Labrador, Canada, (49.12120935, -56.696296112741, 0.0)),
#  Location(North Pacific Ocean, (30.0, -169.9999999, 0.0)),
#  Location(Atlantic Ocean, (13.581921, -38.3203119, 0.0)),
#  Location(Pacific Ocean, (-0.7031069, -120.9374999, 0.0)),
#  Location(North Pacific Ocean, (30.0, -169.9999999, 0.0)),
#  Location(Persian Gulf, (27.0000001, 50.9999999, 0.0)),
#  Location(Nangarhar ننگرهار, افغانستان, (34.220389, 70.3800314, 0.0)),
#  Location(Yugoslavia, Morelia, Michoacán de Ocampo, 58210, México, (19.7297308, -101.1732149, 0.0)),
#  Location(Labrador, Cantón San Mateo, Provincia Alajuela, 20404, Costa Rica, (9.9434766, -84.6104641, 0.0)),
#  Location(Guinea Creek, Snowy Monaro, NSW, Australia, (-36.1766049, 149.46942, 0.0)),
#  Location(République démocratique du Congo, (-2.9814343, 23.8222636, 0.0)),
#  Location(Atlantic Ocean, (13.581921, -38.3203119, 0.0)),
#  Location(Le Congo, Mons, Hainaut, Wallonie, België - Belgique - Belgien, (50.477898, 4.0380968, 0.0)),
#  Location(Newfoundland, Newfoundland and Labrador, Canada, (49.12120935, -56.696296112741, 0.0)),
#  Location(Manitoba, Canada, (55.0000001, -97.0, 0.0)),
#  Location(République démocratique du Congo, (-2.9814343, 23.8222636, 0.0)),
#  Location(Açores, Portugal (águas territoriais), (37.80852735, -25.4730851864796, 0.0)),
#  Location(Czechoslovakia Cemetery, South Road, Howard County, Nebraska, 68838, United States of America, (41.2133453, -98.6228518, 0.0)),
#  Location(North Sea, (55.3333373, 2.9999964, 0.0)),
#  Location(Açores, Portugal (águas territoriais), (37.80852735, -25.4730851864796, 0.0)),
#  Location(South Carolina, United States of America, (33.6874388, -80.4363742, 0.0)),
#  Location(Isa Town Gate Interchange - Sheikh Salman Highway (South) Off Slip, Zayed Town, عالي, المحافظة الوسطى, 841, ‏البحرين‎, (26.1669862, 50.5432349, 0.0)),
#  Location(Isa Town Gate Interchange - Sheikh Salman Highway (South) Off Slip, Zayed Town, عالي, المحافظة الوسطى, 841, ‏البحرين‎, (26.1669862, 50.5432349, 0.0)),
#  Location(Yugoslavia, Morelia, Michoacán de Ocampo, 58210, México, (19.7297308, -101.1732149, 0.0)),
#  Location(La cathédrale gothique : un chantier de plus de 4 siècles, Place Saint-Pierre, Decré - Cathédrale, Centre Ville, Nantes, Loire-Atlantique, Pays de la Loire, 44000;44100;44200;44300, France, (47.2179484, -1.5509912, 0.0)),
#  Location(Yugoslavia, Morelia, Michoacán de Ocampo, 58210, México, (19.7297308, -101.1732149, 0.0)),
#  Location(New Guinea, Kiunga District, Western, Papua Region, Papua Niugini, (-5.5227499, 142.073628608765, 0.0)),
#  Location(North Atlantic, Thorburn Road, St. John's, Newfoundland and Labrador, A1B3V6, Canada, (47.5644471, -52.7611838, 0.0)),
#  Location(Yugoslavia, Morelia, Michoacán de Ocampo, 58210, México, (19.7297308, -101.1732149, 0.0)),
#  Location(New Guinea, Kiunga District, Western, Papua Region, Papua Niugini, (-5.5227499, 142.073628608765, 0.0)),
#  Location(République démocratique du Congo, (-2.9814343, 23.8222636, 0.0)),
#  Location(Terres australes et antarctiques françaises, Antarctica, (-44.1511784, 63.8604556, 0.0)),
#  Location(English Channel, France, (50.0222324, -1.0513227, 0.0)),
#  Location(Baltic Sea, (56.0, 18.0, 0.0)),
#  Location(North Sea, (55.3333373, 2.9999964, 0.0)),
#  Location(‏پاکستان‎, (30.3308401, 71.247499, 0.0)),
#  Location(Northern Ireland, UK, (54.6294982, -6.7654415, 0.0)),
#  Location(Newfoundland, Newfoundland and Labrador, Canada, (49.12120935, -56.696296112741, 0.0)),
#  Location(Tanganyika, République démocratique du Congo, (-5.9010018, 29.1778624, 0.0)),
#  Location(Wake Island, United States Minor Outlying Islands, United States of America, (19.2969291, 166.625592415155, 0.0)),
#  Location(Україна, (49.4871968, 31.2718321, 0.0)),
#  Location(Mariana Islands, Northern Islands Municipality, Northern Mariana Islands, United States of America, (17.5986111, 145.8386111, 0.0)),
#  Location(Czechoslovakia Cemetery, South Road, Howard County, Nebraska, 68838, United States of America, (41.2133453, -98.6228518, 0.0)),
#  Location(North Sea, (55.3333373, 2.9999964, 0.0)),
#  Location(México, (22.5000485, -100.0000374, 0.0)),
#  Location(Sarawak, Malaysia, (2.3926225, 113.646867, 0.0)),
#  Location(Hawaii, United States of America, (21.2160437, -157.9752029, 0.0)),
#  Location(South Carolina, United States of America, (33.6874388, -80.4363742, 0.0)),
#  Location(Over the Hill Lane, Yadkin County, North Carolina, 27011, United States of America, (36.235331, -80.7307719, 0.0)),
#  Location(Czechoslovakia Cemetery, South Road, Howard County, Nebraska, 68838, United States of America, (41.2133453, -98.6228518, 0.0)),
#  Location(မြန်မာ, (17.1750495, 95.9999652, 0.0)),
#  Location(Pacific Ocean, (-0.7031069, -120.9374999, 0.0)),
#  Location(Açores, Portugal (águas territoriais), (37.80852735, -25.4730851864796, 0.0)),
#  Location(Norda Atlantika Oceano, (40.0, -39.9999999, 0.0)),
#  Location(Oʻzbekiston, (41.32373, 63.9528098, 0.0)),
#  Location(Suriname, (4.1413025, -56.0771186, 0.0)),
#  Location(Newfoundland, Newfoundland and Labrador, Canada, (49.12120935, -56.696296112741, 0.0)),
#  Location(République démocratique du Congo, (-2.9814343, 23.8222636, 0.0)),
#  Location(Persian Gulf, (27.0000001, 50.9999999, 0.0)),
#  Location(République démocratique du Congo, (-2.9814343, 23.8222636, 0.0)),
#  Location(Mariana Islands, Northern Islands Municipality, Northern Mariana Islands, United States of America, (17.5986111, 145.8386111, 0.0)),
#  Location(Czechoslovakia Cemetery, South Road, Howard County, Nebraska, 68838, United States of America, (41.2133453, -98.6228518, 0.0)),
#  Location(Açores, Portugal (águas territoriais), (37.80852735, -25.4730851864796, 0.0)),
#  Location(São Tomé, Água Grande, São Tomé Province, São Tomé e Príncipe, (0.3389242, 6.7313031, 0.0)),
#  Location(SUNNING ROAD 新寧道 - Near Sing Wo Road 在禮頓道附近, 新寧道 Sunning Road, 天后 Tin Hau, 銅鑼灣 Causeway Bay, 灣仔區 Wan Chai District, 香港島 Hong Kong Island, HK, JARDINE CENTRE 2F, 中国, (22.2776422, 114.185636868475, 0.0)),
#  Location(မြန်မာ, (17.1750495, 95.9999652, 0.0)),
#  Location(West Indies, Breedestraat, Kortijn, Otrobanda, Willemstad, Curaçao, 0000NA, Nederland, (12.1100405, -68.9386369912097, 0.0)),
#  Location(Czechoslovakia Cemetery, South Road, Howard County, Nebraska, 68838, United States of America, (41.2133453, -98.6228518, 0.0)),
#  Location(Norda Atlantika Oceano, (40.0, -39.9999999, 0.0)),
#  Location(Czechoslovakia Cemetery, South Road, Howard County, Nebraska, 68838, United States of America, (41.2133453, -98.6228518, 0.0)),
#  Location(São Tomé e Príncipe, (0.8875498, 6.9648718, 0.0)),
#  Location(မြန်မာ, (17.1750495, 95.9999652, 0.0)),
#  Location(ປະເທດລາວ, (20.0171109, 103.378253, 0.0)),
#  Location(Near North Side, Chicago, Cook County, Illinois, 60610, United States of America, (41.9000327, -87.6344974, 0.0))]

# %%
len(crashes[crashes['Country'] =='United States of America'])
# Out:
# 1408

# %% [raw]
# # 2. Split Location
# # Problem: Location dows not seem to be in a consistent format.
# # Some locations have country information and other have maybe only city information
# # Solution: I am planning to use google apis to convert my location to 1 columns Latitude and Longitude columns.
# #         : Then using the latitude longitude I will revert it to Location. Then Split into 2 columns -  Country and City
#
#
# from geopy.geocoders import Nominatim
# from geotext import GeoText
# from geopy.exc import GeocoderTimedOut
# import time
#
# geolocator = Nominatim()
# geoloc_default = geolocator.reverse("0, 0")
#
# def do_geocode(address):
#     try:
#         return geolocator.geocode(address, addressdetails=True)
#     except GeocoderTimedOut:
#         return do_geocode(address)
#
# geoloc = []
# for loc in crashes.Location[0:10]:
#     if ((GeoText(loc).countries) or (GeoText(loc).cities)):
#         location = do_geocode(loc)
#         if(location):
#             time.sleep(10)
#             geoloc.append(location)
#         else:
#             geoloc.append(geoloc_default)
#     else:
#         geoloc.append(geoloc_default)

# %% [raw]
# geoloc

# %% [raw]
# # print(crashes.Location.dtypes)
#
# # print('Feature list before location was split:')
# # print(crashes.columns)
#
#
# # location
# # print('Feature list after location was split:')
# # print(crashes.columns)

# %% [raw]
# from geopy.geocoders import Nominatim
# geolocator = Nominatim()
# location = geolocator.reverse("0, 0")
# print(type(location))
# # print((location.latitude, location.longitude))
# # print(location.raw)

# %%
# from geograpy import places
# c = places.PlaceContext(['Cleveland', 'Ohio', 'United States'])
# from geopy.distance import vincenty
# newport_ri = (48.6904063, 2.373809)
# cleveland_oh = (46.603354, 1.8883335)
# print(vincenty(newport_ri, cleveland_oh).miles)

# %% [markdown]
# ### G. DATA DICTIONARY

# %%
# Database Format

# Date:Date of accident,  in the format - January 01, 2001
# Time:Local time, in 24 hr. format unless otherwise specified
# Airline/Op:Airline or operator of the aircraft
# FlightNo:Flight number assigned by the aircraft operator
# Route:Complete or partial route flown prior to the accident
# AC Type:Aircraft type
# Reg:ICAO registration of the aircraft
# cnln:Construction or serial number / Line or fuselage number
# Aboard:Total aboard (passengers / crew)
# Fatalities:Total fatalities aboard (passengers / crew)
# Ground:Total killed on the ground
# Summary:Brief description of the accident and cause if known

# %% [markdown]
# ### H1. PERFORM EDA

# %%
Analyse the data
Split the columns into meaningful information
No of null values and check how it can be filled.(other datasets or impute?)
Check the datatypes for all columns
Value counts, unique values for every column
Put the data frame into sql

Data points for each year. Check if it is sufficient
Would it be good to analyse data from a particular year?
Can I get the missing information from any other available datasets
# Out:
#   File "<ipython-input-38-e4deba7f0d8a>", line 1
#     Analyse the data
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### H2. SUMMARIZE EDA

# %% [markdown]
# ## BONUS

# %% [markdown]
# ### I. TUNING METRICS AND EVALUATION APPROACHES
# Explain how you intend to evaluate your results. What tuning metric and evaluation approaches do you intend to use?

# %% [markdown]
# ### J. POSSIBLE ADDITIONAL DATASETS
# Identify 1-2 additional datasets that may help you triangulate your findings. How might these relate to your data?
#
# http://www.airfleets.net/home/
#
# http://www.airsafe.com/events/models/airbus.htm

# %% [markdown]
# ### K. BLOG POST ABOUT PART 2
# Create a blog post of at least 500 words (and 1-2 graphics!) that describes your assumptions and processes for EDA.
# Link to it in your Jupyter notebook.
