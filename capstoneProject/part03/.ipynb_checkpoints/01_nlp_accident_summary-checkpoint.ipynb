# %% [markdown]
# #### Input dataset ?
# - I will be using the cleaned dataset after the initial EDA.
#
# #### What is the purpose of this notebook?
# - The number and nature of accidents in the aviation industry do not lean to any obiously particular location or type.
# - When I started with the topic, I was interested in finding patterns in the accidents. The Univariate analysis and bivariate analysis provides very interesting insights about the past accidents. Reading through the accident causes, I realized the accidents could have another angle added to it apart from the provided categorical features. The Narrative field is a textual description of the incident. I am interested in adding another dimension i.e. categorizing based on the words in the description.
#
# #### What is the expected output of this notebook?
# - I plan to achieve the following at the end of this notebook:
#     - Check frequently used words in the summary using NLP/Count Vectorizer
#     - Remove stop words iteratively using NLTK
#     - Categorize words I think are common causes of accidents. eg: pilot error, weather, hijack and many mroe that I hope to find during the course of this project.
#     - Map the frequent words found to the common causes of accidents.
#     - This would help me to classify the incidents or to find clusters based on the results of this notebook.

# %% [markdown]
# ## Import Clean Dataset

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 50)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
path = './dataset/01_aviation_cleaned.csv'

# %%
data = pd.read_csv(path)

# %% [markdown]
# ## Natural Language Processing with the Incident Summary

# %%
# Import library 

from sklearn.feature_extraction.text import CountVectorizer
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords
from gensim import corpora, models, matutils
from collections import defaultdict
import string
from nltk import word_tokenize 
import pycountry

# %% [markdown]
# ### These are the stop words for the Narrative - This is going to be a live list.
# - English stop words
# - Country name stop words
# - Common aviation terms like airplane, airline etc

# %%
# Creating stop words database for all the numbers
stop = stopwords.words('english')
stop += ['00', '000', '01', '02', '03', '04', '04r', '05', '050', '05l', '05r', '06', '06r', '07', '08', '080', '09', '09r', '10', '100', '1000', '10000', '102', '103', '104', '1049', '105', '106', '107', '108', '109', '10deg', '10l', '11', '110', '1100', '111', '111f', '112', '113', '114', '115', '116', '117', '118', '118a', '119', '11f', '11s', '12', '120', '1200', '12000', '121', '361', '376','122', '123', '124', '124c', '125', '128', '129', '12bk', '13', '130', '1300', '130b', '130e', '130h', '130j', '131', '133', '134', '135', '135a', '139', '13l', '14', '140', '1400', '141', '1420', '145', '14500', '146', '148', '15', '150', '1500', '153', '154', '157', '158', '159', '15deg', '16', '160', '1600', '163', '165', '166', '168', '16r', '17', '170', '1700', '172', '175', '1750', '17l', '18', '180', '1800', '180deg', '185', '188', '19', '190', '1900', '1900c', '1900d', '191', '1936', '1938', '1940', '1941', '1942', '1943', '1944', '1945', '1948', '1949', '1950', '1951', '1953', '1954', '1955', '1957', '1963', '1964', '1966', '1968', '1969', '1972', '1973', '1974', '1978', '1979', '1980', '1981', '1982', '1983', '1985', '1986', '1988', '1990', '1991', '1992', '1993', '1994', '1997', '1998', '1999', '19r', '1a', '1a10', '1st', '20', '200', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '200c', '201', '2011', '2013', '2015', '202', '203', '2050', '207', '208', '208b', '20deg', '21', '210', '211', '212', '215', '22', '220', '2200', '222', '225', '227', '228', '22l', '23', '230', '2300', '232', '235', '24', '240', '2400', '241', '242', '24b', '24l', '24r', '24rv', '25', '250', '2500', '25l', '26', '260', '265', '266', '26b', '26l', '27', '270', '2700', '27l', '27r', '28', '280', '2800', '285', '28l', '28r', '29', '290', '29l', '2a', '2r', '2t', '30', '300', '3000', '304', '306', '30deg', '31', '310', '31242', '31243', '314', '315', '31l', '31r', '32', '320', '3200', '320o', '322', '325', '328', '32l', '32r', '33', '330', '3300', '330o', '336', '338', '33l', '34', '340', '340b', '340o', '345', '35', '350', '3500', '350o', '35a', '35l', '36', '360', '3600', '37', '38', '39', '390', '3a', '3c', '3deg', '3m', '3mge', '3t', '40', '400', '4000', '41', '410', '410uvp', '42', '420', '4200', '43', '430', '436', '44', '440', '45', '450', '4500', '45deg', '46', '46d', '47', '470', '4700', '47a', '47b', '47d', '47s', '48', '49', '50', '500', '5000', '501', '504', '50832', '50deg', '51', '52', '525', '53', '54', '5400', '55', '550', '5500', '56', '57', '58', '580', '59', '5a', '5h', '5n', '5nm', '5y', '60', '600', '6000', '601', '61', '610', '62', '620', '63', '631', '64', '640', '65', '650', '6500', '66', '67', '68', '6a', '6e', '70', '700', '7000', '707', '71', '710', '72', '720', '725', '727', '73', '737', '74', '747', '748', '75', '750', '7500', '756', '757', '76', '767', '767s', '76md', '770', '777', '78', '78505', '7nm', '80', '800', '8000', '801', '81', '811', '812', '82', '8235', '8241', '82a', '83', '84', '85', '850', '8500', '86', '87', '88', '8807', '89', '8q', '8th', '90', '900', '9000', '90deg', '91', '910', '92', '93', '931', '94', '95', '96', '97', '98', '99', '990', '9k', '9n', '9q', 'a100', 'a300', 'a310', 'a319', 'a320', 'a321', 'a330', 'a6m2', 'aa', 'aaa', 'aab', 'aaf', 'ab', 'ababa']
stop += ['08r', '1009', '101', '1011', '104b', '144', '21st', '221', '22285', '231', '23l', '300yds', '301', '3100', '318', '319', '31de', '321', '321b', '324', '3277', '33666', '33r', '380', '3800', '395', '39a', '3mce', '400a', '402q', '40563', '40deg', '415', '42e', '42w', '4300', '451', '460', '701', '702', '712', '730', '740', '75a', '76td', '7700', '775', '780', '78270', '78462', '785', '797', '800xp', '823', '841', '8as', '8r', '901', '919', '920', '926', '980', '9j', '9l', '9m']
stop += ['675','680','6800','6b']
stop += ['airport', 'airplane','aircraft', 'approach',
 'crashed','crew','feet','flight','following','main','members','near','one','operated','passenger','passengers','plane','runway','struck','substantial','sustained','three','took','two','boeing','dc','due','beyond',
 'damaged','b200','repair', 'miles', 'km', 'air', 'lines', 'departed', 'abort', 'takeoff', 'landing', 'reported', 'airline', 'captain'
 ]

# %%
# Add all countries as stop words
for c in list(pycountry.countries):
    stop.append(c.name.lower())

# %% [markdown]
# ### Stemmer - I dont think I will use it though

# %%
stemmer = PorterStemmer()

# %%
def stem_tokens(tokens, stemmer):
    stemmed = []
    for item in tokens:
        stemmed.append(stemmer.stem(item))
    return stemmed

def tokenize(text):
    text = "".join([ch for ch in text if ch not in string.punctuation])
    tokens = word_tokenize(text)
    stems = stem_tokens(tokens, stemmer)
    print(stems)
    return stems

# %% [markdown]
# ### Count Vectorizer to get the most commonly used vocabulary

# %%
# vectorizer = CountVectorizer(analyzer = "word",tokenizer = None, lowercase=True, strip_accents="unicode",
#                              preprocessor = None,stop_words = stop,max_features = 1000, ngram_range = (1,1)) 

vectorizer = CountVectorizer(stop_words = stop) 
X = vectorizer.fit_transform(data['Narrative'])

# %%
X.shape
# Out:
# (8172, 16166)

# %%
vectorizer.vocabulary_
vectorizer.get_feature_names()
# Out:
# ['000ft',
#  '001',
#  '0014',
#  '002',
#  '003',
#  '006',
#  '010',
#  '010º',
#  '0127',
#  '015',
#  '017',
#  '0171',
#  '0173',
#  '0195',
#  '01l',
#  '01r',
#  '020',
#  '020deg',
#  '0218',
#  '022',
#  '024',
#  '0256',
#  '02801',
#  '02r',
#  '030',
#  '030º',
#  '0326',
#  '0328',
#  '040',
#  '040b',
#  '040deg',
#  '044',
#  '045',
#  '0450',
#  '0462',
#  '0463',
#  '049',
#  '04l',
#  '053',
#  '0597',
#  '060',
#  '0602',
#  '060deg',
#  '061',
#  '064',
#  '069',
#  '06l',
#  '070',
#  '0703',
#  '0705',
#  '0719',
#  '072',
#  '0730',
#  '07308',
#  '075deg',
#  '076',
#  '07l',
#  '07r',
#  '0839',
#  '085',
#  '0850',
#  '08l',
#  '090',
#  '0900',
#  '090deg',
#  '092',
#  '094',
#  '0970',
#  '0972',
#  '0981',
#  '09l',
#  '1002',
#  '1006',
#  '1007',
#  '1008',
#  '100912',
#  '100deg',
#  '100e',
#  '100er',
#  '100nm',
#  '100yds',
#  '10100',
#  '1015',
#  '1018',
#  '1020',
#  '10200',
#  '1024',
#  '1025',
#  '1027',
#  '10350',
#  '1036',
#  '1040',
#  '1041k',
#  '104g',
#  '1050',
#  '10500',
#  '1054',
#  '10554',
#  '1058',
#  '1060',
#  '10687',
#  '1069',
#  '1070',
#  '10737',
#  '1074',
#  '1075',
#  '1081',
#  '1086',
#  '10884',
#  '10942',
#  '109770',
#  '10a',
#  '10f',
#  '10nm',
#  '11000',
#  '110c',
#  '110p1',
#  '1114',
#  '1120',
#  '11200',
#  '1121',
#  '1123',
#  '1124',
#  '1124a',
#  '1132',
#  '1140',
#  '11500',
#  '1154',
#  '1159',
#  '11600',
#  '11620',
#  '1169',
#  '1170',
#  '1171',
#  '1173',
#  '117d',
#  '11800',
#  '11900',
#  '1198',
#  '119b',
#  '119c',
#  '119cf',
#  '119f',
#  '119k',
#  '11a',
#  '11deg',
#  '11dme',
#  '1200yds',
#  '120er',
#  '1212',
#  '1215',
#  '121d',
#  '121g',
#  '121k',
#  '121m',
#  '122443',
#  '1229',
#  '1230',
#  '12328',
#  '12364',
#  '123k',
#  '12435',
#  '12467',
#  '124a',
#  '1250',
#  '12500',
#  '1255',
#  '125kts',
#  '126',
#  '1260',
#  '12600',
#  '127',
#  '1276',
#  '1277',
#  '127723',
#  '1279',
#  '1281',
#  '1296',
#  '12a',
#  '12b',
#  '12bp',
#  '12deg',
#  '12l',
#  '12n',
#  '12p',
#  '12th',
#  '12w',
#  '13000',
#  '1300k',
#  '1301',
#  '1307',
#  '130a',
#  '130f',
#  '130kias',
#  '130m',
#  '130p',
#  '130r',
#  '1310',
#  '131582',
#  '131639',
#  '131e',
#  '131f',
#  '132',
#  '1320',
#  '13200',
#  '1322',
#  '1325gal',
#  '1329',
#  '1338',
#  '133b',
#  '133deg',
#  '1340',
#  '13400',
#  '1342',
#  '1347',
#  '134a',
#  '134ak',
#  '13500',
#  '135350',
#  '1355',
#  '135deg',
#  '135j',
#  '135kl',
#  '135lr',
#  '135n',
#  '135r',
#  '135s',
#  '135t',
#  '135v',
#  '136',
#  '1360',
#  '137',
#  '1370',
#  '137e',
#  '138',
#  '13807',
#  '1390',
#  '13e',
#  '13r',
#  '14000',
#  '1400z',
#  '140a',
#  '141b',
#  '142',
#  '143',
#  '1436',
#  '1440',
#  '1449',
#  '144a',
#  '1450',
#  '1455',
#  '1457',
#  '145kts',
#  '145li',
#  '145lr',
#  '145lu',
#  '146deg',
#  '147',
#  '1486',
#  '149',
#  '1490',
#  '1493',
#  '1495',
#  '14970',
#  '149813',
#  '149d',
#  '14b',
#  '14fkm',
#  '14p',
#  '14th',
#  '15000',
#  '1500yds',
#  '1500z',
#  '1502',
#  '1509',
#  '150deg',
#  '150f',
#  '150ft',
#  '150h',
#  '150m',
#  '151',
#  '151890',
#  '152',
#  '15200',
#  '152608',
#  '1533',
#  '1535',
#  '1539',
#  '1541',
#  '1545',
#  '1549',
#  '154a',
#  '154b',
#  '154m',
#  '155',
#  '1550',
#  '155130',
#  '1553',
#  '15585',
#  '155deg',
#  '156',
#  '15652',
#  '15677',
#  '1568',
#  '1570',
#  '15721',
#  '157332',
#  '15800',
#  '158761',
#  '1588',
#  '158930',
#  '159325',
#  '15f',
#  '15l',
#  '15r',
#  '15s',
#  '15th',
#  '15tm',
#  '16000',
#  '1602',
#  '160r',
#  '161',
#  '1610',
#  '16100',
#  '162',
#  '164',
#  '1640',
#  '1645',
#  '16481',
#  '1649a',
#  '16500',
#  '165522',
#  '165525',
#  '1669',
#  '167',
#  '16720',
#  '1687',
#  '1690',
#  '16a',
#  '16b',
#  '16d',
#  '16f',
#  '16l',
#  '16th',
#  '17000',
#  '17010',
#  '1707',
#  '1709',
#  '1716',
#  '171st',
#  '1720',
#  '1721',
#  '1723',
#  '172n',
#  '173',
#  '1730',
#  '1733',
#  '1736',
#  '17388',
#  '174',
#  '1763',
#  '1768',
#  '178',
#  '178deg',
#  '179',
#  '1790',
#  '17c',
#  '17f',
#  '17g',
#  '17r',
#  '17th',
#  '18000',
#  '1801',
#  '181',
#  '1810',
#  '1814',
#  '182',
#  '18255',
#  '1828',
#  '182l',
#  '1833',
#  '1840',
#  '18440',
#  '1850',
#  '1851',
#  '18591',
#  '18598',
#  '186',
#  '1860',
#  '187',
#  '1870',
#  '1880',
#  '1885',
#  '189',
#  '18930l',
#  '18a',
#  '18b',
#  '18d',
#  '18r',
#  '18th',
#  '18v',
#  '19000',
#  '1902',
#  '1908',
#  '1909',
#  '190deg',
#  '1910',
#  '1918',
#  '192',
#  '1920',
#  '1921',
#  '1922p',
#  '1923',
#  '1925',
#  '1929',
#  '193',
#  '1930',
#  '1933',
#  '1934',
#  '1935',
#  '1937',
#  '1939',
#  '194',
#  '1946',
#  '1947',
#  '195',
#  '1952',
#  '1956',
#  '1958',
#  '1959',
#  '1960',
#  '1961',
#  '1962',
#  '1967',
#  '197',
#  '1970',
#  '1971',
#  '1975',
#  '1976',
#  '1977',
#  '198',
#  '1984',
#  '1987',
#  '1989',
#  '1990s',
#  '1995',
#  '1996',
#  '199deg',
#  '19a',
#  '19l',
#  '1b',
#  '1g167',
#  '1h',
#  '1h18',
#  '1hour',
#  '1l',
#  '1r',
#  '20000',
#  '2000ft',
#  '2008',
#  '2009',
#  '200b',
#  '200deg',
#  '200er',
#  '200ft',
#  '200x100',
#  '200yds',
#  '2010',
#  '2012',
#  '2014',
#  '2016',
#  '2025',
#  '204',
#  '204b',
#  '205',
#  '206',
#  '206b',
#  '2086',
#  '209b',
#  '20c',
#  '20f',
#  '20gmt',
#  '20l',
#  '20r',
#  '20th',
#  '2100',
#  '2104',
#  '2110',
#  '212667',
#  '212a',
#  '213',
#  '214',
#  '21504',
#  '216',
#  '2165',
#  '218',
#  '21b',
#  '21l',
#  '21mf',
#  '21r',
#  '21u',
#  '2200m',
#  '220º',
#  '2215',
#  '2219',
#  '221f',
#  '2230',
#  '224',
#  '2250rpm',
#  '226',
#  '227ac',
#  '227b',
#  '227bc',
#  '2280',
#  '2284',
#  '2286',
#  '229',
#  '2295',
#  '22c',
#  '22r',
#  '2300yds',
#  '2303',
#  '2311',
#  '2318',
#  '233',
#  '23310',
#  '23488',
#  '2350',
#  '235m',
#  '236',
#  '2370',
#  '238',
#  '238b',
#  '23f',
#  '23r',
#  '24000',
#  '2400rpm',
#  '2406',
#  '240deg',
#  '2422x',
#  '243',
#  '245',
#  '2450',
#  '246',
#  '2460',
#  '246er',
#  '246tg',
#  '247',
#  '247d',
#  '248',
#  '2487',
#  '24a',
#  '24bi',
#  '24kay',
#  '24ko',
#  '24th',
#  '25000',
#  '2501f',
#  '250deg',
#  '250yds',
#  '250º',
#  '251',
#  '2523',
#  '255',
#  '2560',
#  '258',
#  '25b',
#  '25d',
#  '25deg',
#  '25g',
#  '25nm',
#  '25pd',
#  '25r',
#  '25th',
#  '2600',
#  '2600rpm',
#  '260deg',
#  '261',
#  '2615',
#  '2620',
#  '263',
#  '2638',
#  '26492',
#  '2650',
#  '2652',
#  '26r',
#  '27097',
#  '270deg',
#  '271',
#  '2710',
#  '2720',
#  '2733',
#  '2734',
#  '274',
#  '2740',
#  '2747',
#  '275',
#  '2750',
#  '277',
#  '2771',
#  '2790',
#  '27deg',
#  '27th',
#  '280c',
#  '280º',
#  '2813',
#  '2823',
#  '283er',
#  '284',
#  '2841',
#  '2850',
#  '2850rpm',
#  '286',
#  '287',
#  '2873',
#  '288',
#  '2885',
#  '28d',
#  '28nm',
#  '28p',
#  '28th',
#  '2900',
#  '291',
#  '2925',
#  '295m',
#  '296',
#  '297',
#  '298',
#  '29nm',
#  '29r',
#  '2a8',
#  '2b',
#  '2deg',
#  '2e',
#  '2f',
#  '2h',
#  '2nd',
#  '2nm',
#  '2p',
#  '2sq',
#  '2t5',
#  '2tp',
#  '2u3b',
#  '3002',
#  '300er',
#  '300s',
#  '300º',
#  '302ftu',
#  '303',
#  '3050',
#  '3068',
#  '306m',
#  '307',
#  '3079',
#  '307b',
#  '308',
#  '30862',
#  '30a',
#  '30b',
#  '30cf',
#  '30f',
#  '30l',
#  '30psi',
#  '30r',
#  '30th',
#  '3102',
#  '3108',
#  '310deg',
#  '310º',
#  '311',
#  '311q',
#  '312',
#  '3120',
#  '3130',
#  '3132',
#  '3137',
#  '3150',
#  '317',
#  '3183',
#  '31fi',
#  '3205',
#  '320º',
#  '3232',
#  '3233',
#  '3244lb',
#  '3252',
#  '3260',
#  '3263',
#  '3281',
#  '328jet',
#  '329c',
#  '32a',
#  '32tons',
#  '32z',
#  '330yds',
#  '330º',
#  '331',
#  '3316',
#  '334',
#  '335',
#  '3380',
#  '339',
#  '33a',
#  '33rc',
#  '3400',
#  '34037',
#  '340a',
#  '340er',
#  '340º',
#  '3416',
#  '342',
#  '343',
#  '343rd',
#  '344',
#  '344c',
#  '3476',
#  '34deg',
#  '34l',
#  '34r',
#  '3506',
#  '350º',
#  '352nd',
#  '353',
#  '354',
#  '3540',
#  '355',
#  '357',
#  '3587',
#  '35deg',
#  '35r',
#  '360deg',
#  '3628',
#  '365',
#  '366',
#  '3666',
#  '366er',
#  '3679',
#  '3680',
#  '368lb',
#  '369',
#  '3698',
#  '36a',
#  '36l',
#  '36n',
#  '36r',
#  '370',
#  '3700',
#  '3700rpm',
#  '371',
#  '3720',
#  '375',
#  '377',
#  '378',
#  '379c',
#  '379th',
#  '381er',
#  '3839x',
#  '384th',
#  '385',
#  '38658',
#  '38667',
#  '387',
#  '389',
#  '38th',
#  '3900',
#  '392',
#  '3930',
#  '39323',
#  '39325',
#  '3960',
#  '398',
#  '39939',
#  '39980',
#  '39n',
#  '3b',
#  '3b4c',
#  '3h4',
#  '3k1c',
#  '3l',
#  '3mfe',
#  '3mg4e',
#  '3mlu',
#  '3mte',
#  '3nm',
#  '3rd',
#  '400b',
#  '400bcf',
#  '400yds',
#  '402',
#  '403',
#  '40312',
#  '404',
#  '4042',
#  '405',
#  '406',
#  '4064',
#  '40641',
#  '4069',
#  '407',
#  '408',
#  '40a',
#  '40cm',
#  '40gmt',
#  '40in',
#  '40k',
#  '40nm',
#  '40s2',
#  '40z',
#  '4100',
#  '411',
#  '412f',
#  '413th',
#  '4146',
#  '418',
#  '41834',
#  '419',
#  '4192',
#  '41deg',
#  '41st',
#  '4204',
#  '422',
#  '42444',
#  '425',
#  '4250',
#  '4265',
#  '42a',
#  '42b',
#  '431',
#  '4317',
#  '4340',
#  '435',
#  '4350',
#  '436th',
#  '4374',
#  '439',
#  '43b',
#  '43s',
#  '4400',
#  '441',
#  '44166',
#  '4422',
#  '444',
#  '4458',
#  '44648',
#  '4479',
#  '4525',
#  '4536',
#  '4539',
#  '455',
#  '457',
#  '45g',
#  '4600',
#  '462',
#  '46327',
#  '465',
#  '467',
#  '46807',
#  '46deg',
#  '46e',
#  '46f',
#  '471',
#  '4723',
#  '47302',
#  '47360',
#  '474',
#  '475',
#  '4750',
#  '477',
#  '47deg',
#  '47e',
#  '47j',
#  '47nm',
#  '47p',
#  '47q',
#  '480',
#  '4805',
#  '481',
#  '484',
#  '4860',
#  '4896',
#  '490',
#  '4900',
#  '4904',
#  '491',
#  '4915',
#  '492',
#  '495',
#  '496',
#  '499',
#  '4a',
#  '4c',
#  '4f',
#  '4g',
#  '4h6',
#  '4k',
#  '4l',
#  '4nm',
#  '4y0',
#  '500ft',
#  '500m',
#  '500sq',
#  '500yds',
#  '501sp',
#  '502',
#  '5049',
#  '505',
#  '506',
#  '507',
#  '508',
#  '509',
#  '50c',
#  '50feet',
#  '50psi',
#  '50s',
#  '50th',
#  '510',
#  '5100',
#  '512',
#  '5120',
#  '5160',
#  '518',
#  '520',
#  '52002',
#  '524',
#  '5250',
#  '525c',
#  '527',
#  '529',
#  '52g',
#  '530',
#  '5300',
#  '530yds',
#  '5315',
#  '5323',
#  '5340',
#  '537',
#  '53d',
#  '540',
#  '5401',
#  '5407',
#  '541',
#  '542ct',
#  '543',
#  '545',
#  '5452',
#  '546',
#  '54a',
#  '54b',
#  '550b',
#  '5513',
#  '553',
#  '5539',
#  '557',
#  '558',
#  '55deg',
#  '55kts',
#  '55th',
#  '560',
#  '5600',
#  '560xl',
#  '561',
#  '5615',
#  '5669',
#  '5675',
#  '56g',
#  '56pst',
#  '56th',
#  '570',
#  '5700',
#  '5711',
#  '572',
#  '5733',
#  '57752',
#  '57760',
#  '5800',
#  '580a',
#  '580as',
#  '5811',
#  '583',
#  '585',
#  '588',
#  '589',
#  '590',
#  '5900',
#  '592',
#  '594',
#  '595',
#  '599',
#  '59d',
#  '5b',
#  '5d',
#  '5deg',
#  '5e',
#  '5f',
#  '5g',
#  '5th',
#  '5v',
#  '5x',
#  '5x61',
#  '600f',
#  ...]

# %%
docs = pd.DataFrame(X.todense(), columns=vectorizer.get_feature_names())
docs.sum().nlargest(100)
# Out:
# engine           1479
# pilot            1398
# fire             1148
# left             1055
# right             903
# accident          885
# gear              804
# ground            762
# damage            634
# landed            622
# wing              580
# control           567
# destroyed         545
# lost              519
# weather           494
# power             469
# altitude          451
# first             414
# nose              413
# forced            407
# time              399
# cargo             369
# killed            360
# area              352
# fuel              348
#                  ...
# visibility        237
# speed             236
# demanded          234
# height            233
# force             232
# back              231
# de                228
# trees             226
# training          225
# attempted         220
# stop              220
# airlines          219
# hand              212
# taken             212
# water             212
# approximately     209
# day               208
# ran               208
# terrain           206
# base              205
# touched           205
# visual            203
# around            201
# caused            200
# pilots            200
# dtype: int64

# %%
# This is the fastest way to swap a dictionary key / value order.  
# This is the format gensim LDA expects it's vocabulary.
vocab = {v: k for k, v in vectorizer.vocabulary_.items()}
vocab
# Out:
# {11352: 'peruvian',
#  9498: 'metro',
#  2018: 'apparently',
#  7706: 'involved',
#  1394: 'accident',
#  15908: 'wreck',
#  13046: 'seen',
#  6913: 'hangar',
#  8745: 'lima',
#  13103: 'september',
#  8557: 'last',
#  1452: 'active',
#  7976: 'july',
#  12341: 'reportedly',
#  2895: 'blown',
#  7299: 'hurricane',
#  12094: 'ran',
#  2956: 'bomb',
#  4413: 'crater',
#  6202: 'forced',
#  3075: 'brazilian',
#  14485: 'territory',
#  12544: 'rió',
#  11949: 'puritú',
#  4013: 'colombian',
#  2988: 'border',
#  5481: 'engine',
#  5794: 'failure',
#  3545: 'caucaya',
#  15880: 'wooded',
#  9823: 'mountainside',
#  8227: 'killing',
#  11306: 'people',
#  1353: 'aboard',
#  4161: 'confirmed',
#  5565: 'escaped',
#  15070: 'uk',
#  4842: 'destroyed',
#  9559: 'military',
#  15280: 'use',
#  13270: 'shot',
#  11157: 'paris',
#  316: '15th',
#  7985: 'june',
#  1332: 'abandoned',
#  3435: 'captured',
#  6505: 'germans',
#  3958: 'co',
#  11462: 'pilot',
#  8225: 'killed',
#  13546: 'snow',
#  13917: 'storm',
#  4649: 'date',
#  8318: 'known',
#  5072: 'dobrolet',
#  13651: 'spare',
#  11183: 'parts',
#  2285: 'aug',
#  416: '1930',
#  6725: 'ground',
#  14749: 'toussus',
#  8602: 'le',
#  10524: 'noble',
#  1832: 'also',
#  8952: 'lucien',
#  12651: 'rougerie',
#  5836: 'farman',
#  5451: 'employees',
#  12781: 'said',
#  5988: 'first',
#  9145: 'man',
#  7695: 'invent',
#  13359: 'simulator',
#  2680: 'beech',
#  10556: 'north',
#  15913: 'wright',
#  1712: 'airways',
#  4148: 'conducting',
#  10658: 'nwl125',
#  10551: 'norman',
#  15721: 'wells',
#  14962: 'tulita',
#  14925: 'trying',
#  7566: 'initiate',
#  12508: 'right',
#  6897: 'hand',
#  14989: 'turn',
#  12092: 'ramp',
#  11158: 'park',
#  9184: 'manoeuvre',
#  5901: 'felt',
#  13829: 'started',
#  13489: 'slip',
#  13491: 'slippery',
#  14135: 'surface',
#  14870: 'tried',
#  12211: 'recovery',
#  2029: 'applying',
#  4918: 'differential',
#  11686: 'power',
#  12443: 'reverse',
#  3061: 'braking',
#  7243: 'however',
#  9186: 'manoeuvres',
#  15218: 'unsuccessful',
#  8636: 'left',
#  15828: 'wing',
#  3370: 'came',
#  4217: 'contact',
#  3191: 'building',
#  13216: 'sheering',
#  15829: 'winglet',
#  14625: 'tip',
#  12475: 'rib',
#  8835: 'located',
#  5904: 'fence',
#  4242: 'continued',
#  11197: 'past',
#  4040: 'coming',
#  12396: 'rest',
#  4690: 'debris',
#  12402: 'resting',
#  2693: 'behind',
#  4976: 'disembarked',
#  15853: 'without',
#  7576: 'injury',
#  13269: 'shorts',
#  3465: 'cargo',
#  7451: 'impacted',
#  14482: 'terrain',
#  2262: 'attempted',
#  3694: 'charleston',
#  15995: 'yeager',
#  15728: 'west',
#  15502: 'virginia',
#  15272: 'usa',
#  14053: 'suffered',
#  5851: 'fatal',
#  7574: 'injuries',
#  3626: 'cessna',
#  6674: 'grand',
#  3443: 'caravan',
#  3758: 'chignik',
#  1757: 'alaska',
#  7991: 'junkers',
#  7960: 'ju',
#  10290: 'named',
#  7264: 'huanuni',
#  13614: 'sorata',
#  2437: 'bad',
#  15701: 'weather',
#  9008: 'lyon',
#  9274: 'marseille',
#  12028: 'quito',
#  4347: 'cotocollao',
#  11004: 'overturned',
#  15757: 'whilst',
#  14397: 'taxiing',
#  5792: 'failed',
#  8919: 'low',
#  1844: 'altitude',
#  9625: 'mishandling',
#  5371: 'ekster',
#  5128: 'dove',
#  10454: 'next',
#  5835: 'farm',
#  5257: 'dyke',
#  3546: 'caught',
#  5975: 'fire',
#  10279: 'nakajima',
#  2190: 'assembled',
#  6342: 'fuji',
#  5288: 'east',
#  12989: 'sea',
#  8161: 'kerama',
#  7752: 'islands',
#  14166: 'survivors',
#  12366: 'rescued',
#  13858: 'steam',
#  13246: 'ship',
#  9668: 'miyake',
#  9292: 'maru',
#  6175: 'focke',
#  15923: 'wulf',
#  6371: 'fw',
#  1687: 'airliner',
#  4869: 'deutsche',
#  8959: 'lufthansa',
#  5027: 'ditched',
#  3555: 'cavite',
#  2626: 'bay',
#  9173: 'manila',
#  14098: 'super',
#  5380: 'electra',
#  874: '480',
#  1779: 'alexandria',
#  13400: 'six',
#  12848: 'sanjurjo',
#  7341: 'iberia',
#  3119: 'british',
#  1977: 'anti',
#  13629: 'south',
#  5607: 'europa',
#  11583: 'point',
#  13143: 'seven',
#  7772: 'italian',
#  781: '3mlu',
#  7113: 'hillside',
#  9492: 'meters',
#  5959: 'final',
#  8638: 'leg',
#  12608: 'rome',
#  9888: 'munich',
#  2753: 'berlin',
#  14307: 'taken',
#  7232: 'hours',
#  15386: 'veered',
#  4006: 'collided',
#  1042: '6354',
#  12327: 'repaired',
#  3527: 'casualties',
#  6907: 'handley',
#  11053: 'page',
#  7245: 'hp',
#  7203: 'horatius',
#  15910: 'wrecked',
#  14639: 'tiverton',
#  6795: 'gulf',
#  4371: 'course',
#  6240: 'four',
#  2465: 'bailed',
#  1751: 'ala',
#  8795: 'littoria',
#  14883: 'trimotor',
#  10803: 'olías',
#  6893: 'hampered',
#  6179: 'fog',
#  13155: 'sevilla',
#  4820: 'descended',
#  6510: 'get',
#  3936: 'clouds',
#  7110: 'hill',
#  3240: 'burst',
#  6080: 'flames',
#  14086: 'sunderland',
#  6201: 'force',
#  8522: 'landed',
#  7755: 'isles',
#  12949: 'scilly',
#  6404: 'gale',
#  11011: 'owing',
#  8476: 'lack',
#  6333: 'fuel',
#  8904: 'lost',
#  11641: 'port',
#  6119: 'float',
#  10382: 'nearby',
#  13965: 'stricken',
#  12849: 'sank',
#  12022: 'quickly',
#  6908: 'handling',
#  5554: 'error',
#  10697: 'oblt',
#  6841: 'günther',
#  7401: 'ii',
#  387: '186',
#  7572: 'injured',
#  11299: 'pengana',
#  10992: 'overrun',
#  4285: 'cooks',
#  12536: 'river',
#  12436: 'returning',
#  10477: 'night',
#  14020: 'submarine',
#  11215: 'patrol',
#  2672: 'became',
#  12356: 'requested',
#  2662: 'bearings',
#  14612: 'time',
#  6236: 'found',
#  13779: 'st',
#  1943: 'ann',
#  8733: 'lighthouse',
#  5689: 'exhausted',
#  5147: 'downwind',
#  14717: 'tore',
#  15831: 'wingtip',
#  6124: 'floats',
#  12809: 'salvage',
#  3428: 'capsized',
#  2654: 'beached',
#  10301: 'nanking',
#  5436: 'emergency',
#  12828: 'sandbar',
#  14907: 'trouble',
#  7129: 'hiram',
#  3122: 'broiles',
#  12209: 'recovered',
#  6143: 'flown',
#  5653: 'ex',
#  11098: 'pan',
#  10361: 'nc14297',
#  13907: 'stop',
#  9607: 'mirabellou',
#  4426: 'crete',
#  7320: 'hydroplane',
#  4618: 'damage',
#  6367: 'fuselage',
#  5487: 'engines',
#  12652: 'rough',
#  13000: 'seas',
#  14250: 'szechwan',
#  3734: 'chengtu',
#  3235: 'burned',
#  14853: 'trees',
#  4839: 'destination',
#  10442: 'newark',
#  8740: 'lijster',
#  8291: 'klm',
#  13122: 'service',
#  4469: 'croydon',
#  1899: 'amsterdam',
#  15508: 'visibility',
#  4793: 'departure',
#  8753: 'limited',
#  12702: 'running',
#  1823: 'along',
#  15759: 'white',
#  6783: 'guidance',
#  8763: 'line',
#  14210: 'swerved',
#  2677: 'becoming',
#  1669: 'airborne',
#  5315: 'edge',
#  1682: 'airfield',
#  15118: 'undercarriage',
#  15840: 'wire',
#  10431: 'netting',
#  14156: 'surrounding',
#  14463: 'tennis',
#  4373: 'court',
#  898: '500ft',
#  899: '500m',
#  12614: 'roof',
#  7233: 'house',
#  11543: 'ploughed',
#  1962: 'another',
#  13072: 'semi',
#  4848: 'detached',
#  12685: 'rudolf',
#  15810: 'windisch',
#  6286: 'french',
#  1830: 'alps',
#  7098: 'high',
#  15818: 'winds',
#  9273: 'marschall',
#  2801: 'bieberstein',
#  6922: 'hannover',
#  9758: 'month',
#  10790: 'old',
#  6925: 'hans',
#  2760: 'berr',
#  14081: 'summit',
#  12265: 'region',
#  9783: 'moritzberg',
#  1009: '603m',
#  9819: 'mountain',
#  3924: 'close',
#  14756: 'town',
#  8572: 'lauf',
#  4814: 'der',
#  11275: 'pegnitz',
#  10883: 'orientation',
#  7028: 'heavy',
#  6222: 'former',
#  10671: 'nürnberg',
#  9235: 'marienberg',
#  7037: 'heinrich',
#  8392: 'kroll',
#  9822: 'mountains',
#  5456: 'en',
#  12658: 'route',
#  6105: 'flew',
#  13309: 'side',
#  5916: 'ferry',
#  9313: 'mast',
#  2261: 'attempt',
#  8520: 'land',
#  14089: 'sunk',
#  12053: 'radio',
#  10841: 'operator',
#  4679: 'de',
#  6981: 'havilland',
#  4892: 'dh',
#  1216: '86a',
#  5730: 'express',
#  10837: 'operating',
#  9086: 'mail',
#  13268: 'shortly',
#  14991: 'turned',
#  4741: 'degrees',
#  7035: 'height',
#  7136: 'hit',
#  14851: 'tree',
#  779: '3mfe',
#  7065: 'hermann',
#  6606: 'goering',
#  6266: 'frankfurt',
#  13265: 'short',
#  8154: 'kent',
#  6163: 'flying',
#  2923: 'boat',
#  12950: 'scipio',
#  13971: 'string',
#  5131: 'downdraft',
#  4141: 'conditions',
#  4066: 'communications',
#  4920: 'difficulties',
#  12365: 'rescue',
#  4749: 'delayed',
#  4910: 'died',
#  14832: 'trapped',
#  15909: 'wreckage',
#  4011: 'cologne',
#  8873: 'london',
#  13828: 'start',
#  15012: 'twelve',
#  5615: 'evacuated',
#  12777: 'safety',
#  14421: 'technical',
#  13640: 'soviet',
#  11599: 'polikarpov',
#  5938: 'fighter',
#  13648: 'spanish',
#  3856: 'civil',
#  15645: 'war',
#  7133: 'hisma',
#  8961: 'luftwaffe',
#  10604: 'november',
#  1887: 'among',
#  2138: 'arthur',
#  3094: 'bressler',
#  12271: 'regular',
#  2750: 'bergen',
#  14899: 'tromsø',
#  4846: 'det',
#  10554: 'norske',
#  8958: 'luftfartselskap',
#  15284: 'using',
#  5534: 'equipped',
#  6982: 'havørn',
#  15668: 'water',
#  1538: 'aerodrome',
#  12838: 'sandviken',
#  2919: 'board',
#  8818: 'load',
#  2451: 'bags',
#  8229: 'kilograms',
#  8589: 'lb',
#  11662: 'post',
#  9531: 'mid',
#  4009: 'collision',
#  2048: 'aput',
#  6879: 'half',
#  9556: 'mile',
#  13978: 'strong',
#  6819: 'gusts',
#  15487: 'ville',
#  10472: 'nice',
#  9423: 'mediterranean',
#  10722: 'occupants',
#  5124: 'douglas',
#  11719: 'praha',
#  5930: 'field',
#  5115: 'doornspijk',
#  12935: 'scheduled',
#  11718: 'prague',
#  5690: 'exhaustion',
#  8079: 'karl',
#  2485: 'balik',
#  9550: 'mika',
#  9406: 'mechanic',
#  13990: 'strunk',
#  10488: 'nine',
#  8628: 'lechfeld',
#  10902: 'orvin',
#  13340: 'sikorsky',
#  14884: 'trinidad',
#  10889: 'originated',
#  9523: 'miami',
#  6012: 'fl',
#  3022: 'bound',
#  3181: 'buenos',
#  1681: 'aires',
#  3743: 'chestnut',
#  12495: 'ridge',
#  5800: 'fairchance',
#  3369: 'camden',
#  10507: 'nj',
#  11497: 'pittsburgh',
#  1806: 'allegheny',
#  4363: 'county',
#  11032: 'pa',
#  3430: 'capt',
#  10937: 'otto',
#  5909: 'ferguson',
#  6960: 'harry',
#  8678: 'lewis',
#  7219: 'hostess',
#  10416: 'nelly',
#  6677: 'granger',
#  5396: 'eleven',
#  9844: 'mrs',
#  5405: 'ellenstein',
#  14163: 'survived',
#  6919: 'hankou',
#  15922: 'wuhan',
#  13188: 'shanghai',
#  11189: 'pass',
#  7799: 'iztaccíhuatl',
#  11625: 'popocatépetl',
#  15549: 'volcanos',
#  3813: 'chungking',
#  8448: 'kweiyang',
#  3954: 'cnac',
#  14860: 'tri',
#  9808: 'motor',
#  13474: 'sleet',
#  2072: 'area',
#  16070: 'yunnanfu',
#  1862: 'amazingly',
#  1841: 'although',
#  6205: 'ford',
#  4771: 'demolished',
#  14719: 'torn',
#  3796: 'chorolque',
#  14353: 'tapacarí',
#  14196: 'swamps',
#  10381: 'ne',
#  3974: 'cochabamba',
#  6122: 'floatplane',
#  9407: 'mechanical',
#  14195: 'swampland',
#  6631: 'goodwin',
#  2052: 'ar',
#  9278: 'marshall',
#  13885: 'stewardess',
#  3519: 'casparini',
#  3123: 'broke',
#  553: '24kay',
#  5266: 'düsseldorf',
#  6583: 'glindow',
#  11465: 'pilots',
#  11890: 'provided',
#  835: '43b',
#  7665: 'international',
#  12520: 'rio',
#  7844: 'janeiro',
#  13911: 'stops',
#  1983: 'antilla',
#  2279: 'au',
#  11804: 'prince',
#  12819: 'san',
#  11271: 'pedro',
#  9049: 'macorís',
#  7962: 'juan',
#  6502: 'georgetown',
#  11142: 'paramaribo',
#  3558: 'cayenne',
#  3287: 'bélem',
#  14253: 'são',
#  8988: 'luís',
#  6227: 'fortaleza',
#  10326: 'natal',
#  7954: 'joão',
#  11361: 'pessoa',
#  12193: 'recife',
#  9040: 'maceió',
#  2057: 'aracaju',
#  12806: 'salvador',
#  3445: 'caravelas',
#  15518: 'vitória',
#  8622: 'leased',
#  16148: 'zurich',
#  2595: 'basel',
#  7457: 'imperial',
#  3116: 'britain',
#  4472: 'cruising',
#  5709: 'experienced',
#  15088: 'unable',
#  9094: 'maintain',
#  15751: 'wheels',
#  3488: 'carried',
#  12783: 'saint',
#  12900: 'sauveur',
#  8985: 'luxeuil',
#  8661: 'les',
#  2469: 'bains',
#  3998: 'collapsed',
#  12304: 'remained',
#  15246: 'upright',
#  2729: 'ben',
#  11903: 'prowse',
#  10750: 'officer',
#  15807: 'wincop',
#  1349: 'able',
#  5696: 'exit',
#  3977: 'cockpit',
#  14173: 'sustaining',
#  3237: 'burns',
#  12291: 'release',
#  5114: 'door',
#  5458: 'enabling',
#  4214: 'consumed',
#  782: '3mte',
#  15723: 'wende',
#  8806: 'llaberia',
#  8854: 'loeb',
#  8257: 'kirby',
#  6360: 'furness',
#  9772: 'moor',
#  2706: 'belfast',
#  13021: 'secretary',
#  13835: 'state',
#  13377: 'sir',
#  8245: 'kingsley',
#  15878: 'wood',
#  15685: 'way',
#  6947: 'harland',
#  5783: 'factory',
#  7595: 'inspection',
#  10754: 'officials',
#  12249: 'refuelling',
#  2561: 'barge',
#  7326: 'hythe',
#  13736: 'spread',
#  5485: 'engineers',
#  6816: 'gust',
#  7193: 'hooghly',
#  10260: 'nachtegaal',
#  13368: 'single',
#  14793: 'training',
#  7137: 'hitting',
#  13842: 'station',
#  7575: 'injuring',
#  6004: 'five',
#  12178: 'rebuilt',
#  6504: 'german',
#  12069: 'raid',
#  12937: 'schiphol',
#  5032: 'dived',
#  4256: 'control',
#  11820: 'problems',
#  4989: 'dismantled',
#  4620: 'damaging',
#  13650: 'spar',
#  7847: 'japanese',
#  3810: 'chung',
#  9429: 'mei',
#  14306: 'take',
#  6345: 'fukuoka',
#  8519: 'lanchow',
#  13927: 'strafed',
#  5939: 'fighters',
#  8889: 'looped',
#  5466: 'encountering',
#  14051: 'sudden',
#  7363: 'icing',
#  4610: 'dakar',
#  3510: 'casablanca',
#  8559: 'late',
#  12934: 'schedule',
#  10986: 'overnight',
#  4633: 'dar',
#  5560: 'es',
#  12787: 'salaam',
#  9724: 'mombassa',
#  13017: 'second',
#  11640: 'porpoising',
#  7890: 'jetty',
#  14695: 'tom',
#  15706: 'webb',
#  1604: 'aged',
#  6501: 'george',
#  8306: 'knight',
#  3904: 'clerk',
#  6689: 'graves',
#  3595: 'cemetery',
#  7412: 'ilha',
#  4593: 'da',
#  9691: 'mocambique',
#  6182: 'fokker',
#  15473: 'viii',
#  5220: 'duif',
#  13581: 'sold',
#  15400: 'venezuelan',
#  6656: 'government',
#  9220: 'march',
#  421: '1939',
#  2042: 'april',
#  6672: 'gran',
#  12756: 'sabana',
#  14924: 'try',
#  5963: 'find',
#  3424: 'capitan',
#  3459: 'cardona',
#  11931: 'puig',
#  1409: 'accosted',
#  11287: 'pemones',
#  7516: 'indians',
#  8041: 'kamarata',
#  14288: 'tail',
#  15808: 'wind',
#  5026: 'ditch',
#  11961: 'put',
#  2576: 'barranquilla',
#  5372: 'el',
#  14374: 'tarra',
#  15437: 'via',
#  4266: 'convención',
#  9718: 'mola',
#  13320: 'sierra',
#  6697: 'gredos',
#  4566: 'cylinder',
#  2880: 'blew',
#  12433: 'return',
#  3885: 'claude',
#  13007: 'seaton',
#  9638: 'miss',
#  8910: 'louise',
#  16108: 'zarr',
#  13373: 'sint',
#  13883: 'stevens',
#  15874: 'woluwe',
#  14022: 'submerged',
#  10692: 'object',
#  1797: 'alighting',
#  7445: 'immersion',
#  13248: 'shipped',
#  5488: 'england',
#  12434: 'returned',
#  3749: 'chiao',
#  15148: 'ung',
#  6793: 'guiyang',
#  6794: 'guizhou',
#  12140: 'rcaf',
#  6985: 'hawker',
#  9669: 'mk',
#  671: '312',
#  14309: 'taking',
#  7750: 'island',
#  5557: 'erupted',
#  2482: 'balearic',
#  6490: 'genoa',
#  7178: 'home',
#  4143: 'condor',
#  8640: 'legion',
#  6234: 'fought',
#  825: '42a',
#  5100: 'dominican',
#  3917: 'clipper',
#  2703: 'belem',
#  3363: 'camacin',
#  12807: 'salvadore',
#  15455: 'victoria',
#  11673: 'potez',
#  4370: 'courlis',
#  3771: 'chimney',
#  4783: 'dense',
#  8461: 'köln',
#  8300: 'knapsack',
#  3262: 'butzweilerhof',
#  7659: 'intermediate',
#  5449: 'empire',
#  3553: 'cavalier',
#  8560: 'later',
#  4703: 'decided',
#  3910: 'climb',
#  4518: 'cumulus',
#  3934: 'cloud',
#  2686: 'began',
#  5185: 'drop',
#  2421: 'back',
#  14752: 'towards',
#  15663: 'washington',
#  7200: 'hoping',
#  12257: 'regain',
#  3896: 'clear',
#  11204: 'patch',
#  14585: 'thus',
#  4471: 'cruise',
#  5864: 'favourable',
#  9868: 'much',
#  10887: 'original',
#  8353: 'koranga',
#  2558: 'barely',
#  8667: 'leticia',
#  4951: 'disappeared',
#  11415: 'photo',
#  9239: 'marimbá',
#  13118: 'serra',
#  12814: 'sambé',
#  5342: 'egon',
#  6280: 'frei',
#  9446: 'member',
#  7945: 'josie',
#  3129: 'brook',
#  10929: 'others',
#  13115: 'seriously',
#  5353: 'eight',
#  15153: 'unhurt',
#  14587: 'thüna',
#  8018: 'kahlenberg',
#  15167: 'united',
#  14886: 'trip',
#  5029: 'ditching',
#  12458: 'reyes',
#  3296: 'ca',
#  12837: 'sandstorm',
#  4639: 'darkness',
#  10866: 'order',
#  6005: 'fix',
#  11651: 'position',
#  10700: 'observation',
#  3359: 'calpurnia',
#  6347: 'full',
#  11784: 'preussen',
#  11081: 'palm',
#  3493: 'carrying',
#  14905: 'tropical',
#  14862: 'trial',
#  12667: 'royal',
#  5247: 'dutch',
#  1689: 'airlines',
#  9889: 'municipal',
#  1897: 'ams',
#  13801: 'stalled',
#  11343: 'person',
#  1481: 'adelaide',
#  9436: 'melbourne',
#  8455: 'kyeema',
#  15515: 'visual',
#  8834: 'locate',
#  5580: 'essendon',
#  15918: 'wrong',
#  7009: 'heading',
#  5508: 'entering',
#  14710: 'top',
#  9818: 'mount',
#  4627: 'dandenong',
#  2040: 'approximately',
#  13861: 'steen',
#  5421: 'elva',
#  7935: 'jones',
#  3315: 'cadett',
#  11405: 'phillip',
#  11807: 'pring',
#  9757: 'montgomery',
#  10548: 'normal',
#  6468: 'gear',
#  12081: 'raised',
#  15446: 'vibration',
#  13132: 'set',
#  7635: 'intensity',
#  12411: 'result',
#  14563: 'throttled',
#  16041: 'ypiranga',
#  13569: 'soest',
#  7943: 'joseph',
#  15346: 'vanden',
#  5756: 'eynde',
#  1925: 'andré',
#  5320: 'edmond',
#  9815: 'moulin',
#  7953: 'jozef',
#  2623: 'baus',
#  3693: 'charles',
#  4754: 'deleusse',
#  11502: 'piz',
#  3597: 'cengalo',
#  739: '369',
#  3090: 'bregaglia',
#  12100: 'range',
#  11664: 'postal',
#  2443: 'bag',
#  6565: 'glacier',
#  426: '1952',
#  8447: 'kweilin',
#  2254: 'attacked',
#  11259: 'pearl',
#  7276: 'hugh',
#  15882: 'woods',
#  12810: 'salvaged',
#  12242: 'reflown',
#  1936: 'anhangá',
#  6758: 'guanabara',
#  12226: 'reduced',
#  13937: 'strasbourg',
#  11620: 'poor',
#  14542: 'thirteen',
#  9233: 'marie',
#  8383: 'krentnerová',
#  14165: 'survivor',
#  15147: 'unfortunately',
#  4664: 'day',
#  7213: 'hospital',
#  10746: 'offenburg',
#  9166: 'manfréd',
#  15716: 'weiss',
#  15867: 'wm',
#  3194: 'built',
#  15474: 'viiib',
#  4689: 'debrecen',
#  4688: 'deb',
#  9287: 'martin',
#  6983: 'hawaii',
#  1753: 'alameda',
#  1441: 'across',
#  11035: 'pacific',
#  10730: 'ocean',
#  9056: 'made',
#  15656: 'warsaw',
#  8990: 'lviv',
#  4582: 'czerniowce',
#  3738: 'chernovtsy',
#  3173: 'bucharest',
#  14526: 'thessaloniki',
#  14579: 'thunderstorm',
#  12073: 'rain',
#  2273: 'attitude',
#  8828: 'local',
#  10407: 'negrileasa',
#  12988: 'se',
#  14001: 'stulpicani',
#  5754: 'eyewitness',
#  13694: 'spinned',
#  15881: 'wooden',
#  2263: 'attempting',
#  4459: 'cross',
#  9793: 'morón',
#  14054: 'suffering',
#  3529: 'cat',
#  6270: 'fred',
#  10417: 'nelson',
#  9655: 'misti',
#  3764: 'chilligua',
#  12851: 'santa',
#  8950: 'lucia',
#  1916: 'andes',
#  5885: 'february',
#  3751: 'chicago',
#  7407: 'il',
#  3905: 'cleveland',
#  10765: 'oh',
#  6761: 'guaracy',
#  9591: 'minister',
#  7996: 'justice',
#  9333: 'mauricio',
#  3460: 'cardoso',
#  13976: 'stroh',
#  11256: 'peak',
#  9600: 'mint',
#  3415: 'canyon',
#  9603: 'minutes',
#  3224: 'burbank',
#  8552: 'las',
#  15389: 'vegas',
#  11223: 'paul',
#  3063: 'brand',
#  10441: 'new',
#  8845: 'lockheed',
#  4762: 'delivery',
#  11015: 'owners',
#  10565: 'northwest',
#  820: '422',
#  14629: 'tirana',
#  9217: 'maranola',
#  10490: 'nineteen',
#  8246: 'kingston',
#  14220: 'switched',
#  13063: 'selector',
#  7622: 'insufficient',
#  13675: 'speed',
#  13997: 'student',
#  5679: 'executed',
#  7027: 'heavily',
#  12803: 'salt',
#  8716: 'license',
#  11434: 'pic',
#  4818: 'des',
#  3832: 'cinq',
#  4454: 'croix',
#  3179: 'buena',
#  15514: 'vista',
#  4424: 'crest',
#  16035: 'yosemite',
#  10325: 'nat',
#  14976: 'tupolev',
#  3197: 'bukhta',
#  14606: 'tikhaya',
#  ...}

# %%
frequency = defaultdict(int)

for text in data['Narrative']:
    for token in text.split():
        frequency[token] += 1
        
frequency
# Out:
# defaultdict(int,
#             {'The': 8538,
#              'Peruvian': 7,
#              'Metro': 40,
#              '23': 52,
#              'was': 6596,
#              'apparently': 38,
#              'involved': 37,
#              'in': 4039,
#              'an': 1990,
#              'accident': 552,
#              'as': 658,
#              'the': 20744,
#              'wreck': 6,
#              'seen': 60,
#              'a': 7972,
#              'hangar': 87,
#              'at': 4497,
#              'Lima': 13,
#              'Airport': 831,
#              'on': 3923,
#              'September': 15,
#              '6,': 5,
#              '2005.': 3,
#              'aircraft': 3222,
#              'last': 94,
#              'active': 11,
#              'July': 9,
#              '2003.': 3,
#              'Reportedly': 84,
#              'damaged': 491,
#              'beyond': 696,
#              'repair.': 267,
#              'Blown': 10,
#              'over': 437,
#              'hurricane.': 2,
#              'Ran': 24,
#              'into': 1187,
#              'bomb': 30,
#              'crater.': 2,
#              'Forced': 36,
#              'landing': 1617,
#              'Brazilian': 8,
#              'territory': 3,
#              '(Rió': 1,
#              'Puritú)': 1,
#              'near': 564,
#              'Brazil-Colombian': 1,
#              'border': 9,
#              'after': 1282,
#              'engine': 1247,
#              'failure.': 134,
#              'airplane': 1324,
#              'operated': 565,
#              'flight': 2812,
#              'from': 2540,
#              'Caucaya.': 1,
#              'Crashed': 699,
#              'wooded': 63,
#              'mountainside,': 9,
#              'killing': 105,
#              'all': 167,
#              'people': 44,
#              'aboard.': 37,
#              'Confirmed': 1,
#              'escaped': 41,
#              'to': 9256,
#              'UK': 4,
#              '4.9.39': 1,
#              '&': 15,
#              'destroyed': 365,
#              'France': 32,
#              'while': 626,
#              'military': 97,
#              'use.': 8,
#              'shot': 70,
#              'down': 647,
#              'Paris': 22,
#              '15th': 3,
#              'June': 35,
#              '1940': 2,
#              'abandoned': 29,
#              'with': 1704,
#              'and': 7932,
#              'captured': 11,
#              'by': 1590,
#              'Germans.': 1,
#              'two': 462,
#              'takeoff.': 333,
#              'Co-pilot': 1,
#              'killed.': 240,
#              'snow': 170,
#              'storm.': 33,
#              'Crashed;': 4,
#              'date': 26,
#              'not': 705,
#              'known;': 1,
#              'Dobrolet': 1,
#              'for': 1800,
#              'spare': 10,
#              'parts': 14,
#              'Aug': 1,
#              '1930.': 2,
#              'Destroyed': 145,
#              'ground': 508,
#              'Toussus-le-Noble': 1,
#              'during': 982,
#              'This': 144,
#              'storm': 56,
#              'also': 144,
#              'killed': 99,
#              'Lucien': 1,
#              'Rougerie,': 1,
#              'one': 368,
#              'of': 6016,
#              "Farman's": 1,
#              'employees': 6,
#              'who': 155,
#              'said': 73,
#              'be': 568,
#              'first': 364,
#              'man': 57,
#              'invent': 1,
#              'simulator.': 1,
#              'Crashed.': 334,
#              'A': 1422,
#              'Beech': 38,
#              '1900D': 7,
#              'North-Wright': 1,
#              'Airways,': 9,
#              'conducting': 20,
#              'NWL125': 1,
#              'Norman': 5,
#              'Wells,': 2,
#              'Canada': 57,
#              'Tulita,': 1,
#              'Canada.': 38,
#              'crew': 1695,
#              'trying': 41,
#              'initiate': 12,
#              'right': 788,
#              'hand': 176,
#              'turn': 210,
#              'ramp': 27,
#              'park': 4,
#              'manoeuvre,': 5,
#              'they': 251,
#              'felt': 26,
#              'started': 160,
#              'slip': 2,
#              'slippery': 3,
#              'surface.': 13,
#              'captain': 468,
#              'tried': 115,
#              'do': 19,
#              'recovery': 22,
#              'manoeuvre': 14,
#              'applying': 7,
#              'differential': 5,
#              'power,': 32,
#              'reverse,': 5,
#              'braking,': 3,
#              'however': 25,
#              'these': 32,
#              'manoeuvres': 11,
#              'were': 1865,
#              'unsuccessful.': 4,
#              'left': 942,
#              'wing': 459,
#              'came': 296,
#              'contact': 172,
#              'airport': 227,
#              'building,': 4,
#              'sheering': 1,
#              'off': 1071,
#              'winglet': 7,
#              'tip': 27,
#              'rib': 1,
#              'located': 88,
#              'below': 170,
#              'fence.': 26,
#              'continued': 279,
#              'past': 91,
#              'building': 36,
#              'before': 344,
#              'coming': 121,
#              'rest': 245,
#              'debris': 19,
#              'resting': 4,
#              'behind': 34,
#              'it.': 26,
#              '4': 160,
#              'passengers': 530,
#              '2': 405,
#              'members': 295,
#              'disembarked': 5,
#              'without': 103,
#              'any': 52,
#              'injury.': 7,
#              'Shorts': 28,
#              '330': 8,
#              'cargo': 326,
#              'plane': 927,
#              'impacted': 226,
#              'terrain': 151,
#              'attempted': 209,
#              'Charleston-Yeager': 1,
#              'Airport,': 550,
#              'West': 37,
#              'Virginia,': 3,
#              'USA.': 30,
#              'Both': 186,
#              'suffered': 225,
#              'fatal': 35,
#              'injuries.': 157,
#              'pilot': 1038,
#              'Cessna': 188,
#              '208B': 43,
#              'Grand': 57,
#              'Caravan': 72,
#              'when': 1012,
#              'his': 201,
#              'crashed': 1071,
#              'Chignik': 1,
#              'Alaska.': 25,
#              'Junkers': 83,
#              'Ju-52/3mce': 3,
#              'named': 178,
#              '"Huanuni"': 1,
#              'Sorata.': 1,
#              'bad': 96,
#              'weather.': 77,
#              'Flight:': 2,
#              'Paris-Lyon-Marseille.': 1,
#              'Ju-52/3mge': 5,
#              '"Ecuador"': 1,
#              'Quito-Cotocollao': 1,
#              'Airport.': 129,
#              'Overturned': 7,
#              'whilst': 14,
#              'taxiing.': 9,
#              'On': 285,
#              'takeoff': 792,
#              'no.': 537,
#              'failed': 222,
#              'low': 197,
#              'altitude': 362,
#              'due': 287,
#              'mishandling.': 1,
#              '"Ekster"': 1,
#              'dove': 7,
#              'next': 72,
#              'farm,': 2,
#              'struck': 669,
#              'dyke': 3,
#              'caught': 326,
#              'fire.': 452,
#              'DC-2': 17,
#              'Nakajima-assembled': 1,
#              '"Fuji"': 1,
#              'East': 36,
#              'China': 34,
#              'Sea': 26,
#              'Kerama': 1,
#              'Islands': 7,
#              'Two': 165,
#              'survivors': 19,
#              'rescued': 25,
#              'steam': 1,
#              'ship': 16,
#              '"Miyake': 1,
#              'Maru".': 1,
#              'Focke-Wulf': 1,
#              'Fw': 1,
#              '200': 107,
#              'airliner': 7,
#              'Deutsche': 1,
#              'Lufthansa': 7,
#              'ditched': 42,
#              'Cavite': 1,
#              'Bay': 47,
#              'Manila,': 4,
#              'Philippines.': 11,
#              'Super': 80,
#              'Electra': 13,
#              'some': 249,
#              '300': 106,
#              'miles': 222,
#              '(480': 2,
#              'km)': 29,
#              'north-west': 3,
#              'Alexandria,': 4,
#              'Egypt.': 9,
#              'six': 108,
#              'survivors.': 8,
#              'Ju-52/3m': 15,
#              'aircraft,': 183,
#              '"Sanjurjo"': 1,
#              'Iberia,': 2,
#              'British': 28,
#              'anti-aircraft': 8,
#              'fire': 621,
#              'Gibraltar.': 1,
#              'sea': 144,
#              '6': 73,
#              'south': 68,
#              'Europa': 1,
#              'Point.': 3,
#              'three': 273,
#              'seven': 78,
#              'Italian': 8,
#              'Ju-52/3mlu': 1,
#              'hillside': 25,
#              'about': 659,
#              '1000': 50,
#              'meters': 53,
#              'weather': 297,
#              'final': 144,
#              'leg': 104,
#              'Rome-Munich-Berlin': 1,
#              'flight.': 239,
#              'had': 990,
#              'taken': 211,
#              'Munich': 10,
#              '13:00': 1,
#              'hours.': 30,
#              'Veered': 9,
#              'runway': 2219,
#              'collided': 251,
#              'T-168': 1,
#              '(6354)': 1,
#              '.': 28,
#              'repaired.': 11,
#              'No': 64,
#              'casualties.': 3,
#              'Handley': 8,
#              'Page': 11,
#              'HP.42W': 3,
#              '"Horatius"': 1,
#              'wrecked': 6,
#              'forced': 371,
#              'Tiverton': 1,
#              'gulf': 1,
#              'course.': 27,
#              'Four': 42,
#              'bailed': 39,
#              'out.': 124,
#              'An': 444,
#              'Ala': 3,
#              'Littoria': 3,
#              'trimotor': 2,
#              'is': 156,
#              'reported': 438,
#              'have': 188,
#              'Olías': 2,
#              'Spain.': 26,
#              'hampered': 2,
#              'fog': 54,
#              'Sevilla,': 3,
#              'descended': 182,
#              'get': 38,
#              'clouds': 74,
#              'but': 614,
#              'hill': 74,
#              'burst': 74,
#              'flames.': 59,
#              'Sunderland': 26,
#              'force': 43,
#              'landed': 447,
#              'Isles': 2,
#              'Scilly': 1,
#              'gale': 6,
#              'owing': 5,
#              'lack': 8,
#              'fuel.': 37,
#              'It': 514,
#              'lost': 429,
#              'port': 51,
#              'float.': 1,
#              'nearby': 14,
#              'ship,': 2,
#              'which': 423,
#              'stricken': 2,
#              'sank': 59,
#              'it': 960,
#              'quickly.': 1,
#              'handling': 15,
#              'error.': 2,
#              'Pilot': 46,
#              'Oblt.': 1,
#              'Günther': 1,
#              '(II./186)': 1,
#              'injured.': 198,
#              'DC-2,': 5,
#              '"Pengana",': 1,
#              'overrun': 22,
#              'Cooks': 1,
#              'River': 35,
#              'landing.': 315,
#              'Returning': 3,
#              'night': 102,
#              'Anti-Submarine': 1,
#              'Patrol,': 1,
#              'became': 109,
#              'lost,': 5,
#              'requested': 102,
#              'D/F': 1,
#              'bearings': 2,
#              'time': 295,
#              'found': 154,
#              'St.': 30,
#              "Ann's": 1,
#              'Lighthouse,': 1,
#              'fuel': 263,
#              'exhausted': 4,
#              'sea.': 59,
#              'Landed': 29,
#              'downwind': 28,
#              'weather,': 21,
#              'tore': 13,
#              'both': 193,
#              'wingtip': 29,
#              'floats.': 1,
#              'During': 297,
#              'salvage': 6,
#              'capsized': 4,
#              'beached.': 1,
#              '"Nanking"': 1,
#              'emergency': 285,
#              'river': 22,
#              'sandbar': 1,
#              'Nanking': 1,
#              'trouble.': 10,
#              'Hiram': 1,
#              'Broiles': 1,
#              'Aircraft': 27,
#              'recovered': 10,
#              'flown': 153,
#              'again.': 26,
#              'Ex': 4,
#              'Pan': 7,
#              'Am': 5,
#              'NC14297': 1,
#              'stop': 182,
#              'Mirabellou': 1,
#              'Gulf,': 1,
#              'Crete,': 1,
#              'Greece,': 1,
#              'hydroplane': 1,
#              'sustained': 485,
#              'damage': 516,
#              'fuselage': 162,
#              'engines': 252,
#              'rough': 25,
#              'seas.': 5,
#              '"Szechwan"': 1,
#              'Chengtu': 1,
#              'burned': 68,
#              'out': 639,
#              'trees': 159,
#              '60': 49,
#              '(97': 1,
#              'its': 276,
#              'destination': 68,
#              'Newark.': 4,
#              '"Lijster",': 1,
#              'KLM': 12,
#              'passenger': 448,
#              'service': 81,
#              'Croydon': 3,
#              'Amsterdam.': 4,
#              'Visibility': 23,
#              'departure': 123,
#              'limited': 14,
#              'fog.': 53,
#              'After': 387,
#              'running': 22,
#              '600': 39,
#              'm': 431,
#              'along': 68,
#              'white': 1,
#              'guidance': 7,
#              'line,': 10,
#              'swerved': 25,
#              'becoming': 16,
#              'airborne': 71,
#              'edge': 66,
#              'airfield.': 23,
#              'main': 384,
#              'undercarriage': 174,
#              'fence': 33,
#              'wire': 11,
#              'netting': 1,
#              'surrounding': 8,
#              'tennis': 1,
#              'court.': 1,
#              '1,500ft': 1,
#              '(500m)': 1,
#              'roof': 23,
#              'house,': 10,
#              'ploughed': 8,
#              'another': 114,
#              'semi-detached': 1,
#              'house': 30,
#              'Ju-52,': 5,
#              '"Rudolf': 2,
#              'Windisch",': 1,
#              'mountainside': 37,
#              'French': 22,
#              'Alps': 1,
#              'high': 186,
#              'winds.': 29,
#              '"Marschall': 1,
#              'v.': 3,
#              'Bieberstein"': 1,
#              'Hannover,': 1,
#              'Germany.': 30,
#              'only': 67,
#              'month': 2,
#              'old': 21,
#              '"Hans': 3,
#              'Berr",': 1,
#              'summit': 10,
#              'region': 19,
#              'Moritzberg': 1,
#              '(603m),': 1,
#              'mountain': 176,
#              'close': 45,
#              'town': 9,
#              'Lauf': 1,
#              'der': 1,
#              'Pegnitz.': 1,
#              'orientation': 7,
#              'heavy': 152,
#              'visibility': 148,
#              'approach': 883,
#              'former': 14,
#              'Nürnberg': 4,
#              'Marienberg': 1,
#              '15': 111,
#              'km': 172,
#              'west.': 2,
#              '16': 50,
#              'accident.': 283,
#              '"Heinrich': 1,
#              'Kroll"': 1,
#              'mountains': 24,
#              'en': 218,
#              'route': 305,
#              'Flew': 56,
#              'side': 291,
#              'ferry': 48,
#              'Engine': 35,
#              'fire,': 38,
#              'mast': 4,
#              'attempt': 89,
#              'land,': 12,
#              'then': 521,
#              'sunk.': 2,
#              'Only': 10,
#              'radio': 124,
#              'operator': 21,
#              'escaped.': 3,
#              'de': 189,
#              'Havilland': 50,
#              'DH.86A': 1,
#              'Express,': 3,
#              'operating': 135,
#              'mail': 21,
#              'Germany,': 4,
#              'shortly': 180,
#              'turned': 96,
#              'through': 274,
#              '180': 23,
#              'degrees,': 22,
#              'height,': 10,
#              'hit': 220,
#              'tree.': 16,
#              'Ju-52/3mfe': 1,
#              '"Hermann': 1,
#              'Goering"': 1,
#              'Frankfurt.': 8,
#              'Short': 10,
#              'S.17': 1,
#              'Kent': 2,
#              'flying': 285,
#              'boat': 58,
#              "'Scipio'": 1,
#              'string': 2,
#              'downdraft': 7,
#              'conditions.': 91,
#              'Because': 67,
#              'communications': 12,
#              'difficulties,': 1,
#              'rescue': 24,
#              'delayed.': 1,
#              'died': 73,
#              'trapped': 3,
#              'wreckage.': 8,
#              'DH.86': 7,
#              'Express': 28,
#              'Germany': 25,
#              'Hannover': 3,
#              'Cologne.': 1,
#              'Final': 2,
#              'London,': 6,
#              'U.K.': 14,
#              'Caught': 15,
#              'start': 31,
#              'Twelve': 6,
#              'evacuated': 32,
#              'safety.': 9,
#              'technical': 11,
#              'Shot': 37,
#              'Soviet': 28,
#              'Polikarpov': 2,
#              'I-15': 1,
#              'fighter': 26,
#              'Spanish': 15,
#              'Civil': 16,
#              'War': 53,
#              '(7.36-4.37).': 1,
#              'Six': 31,
#              '(of': 1,
#              '20)': 1,
#              'HISMA': 1,
#              '(Luftwaffe)': 1,
#              'November': 20,
#              '1936': 3,
#              'among': 24,
#              '4.': 6,
#              'Among': 6,
#              'those': 21,
#              'Arthur': 2,
#              'Bressler.': 1,
#              'regular': 27,
#              'between': 186,
#              'Bergen': 2,
#              'Tromsø': 4,
#              'Norway': 6,
#              'Det': 2,
#              'Norske': 2,
#              'Luftfartselskap': 2,
#              '7': 44,
#              '1936,': 4,
#              'using': 57,
#              'float-equipped': 14,
#              'Ju-52/3m,': 3,
#              '"Havørn".': 2,
#              '06:30': 5,
#              'departed': 633,
#              'water': 133,
#              'aerodrome': 13,
#              'Sandviken,': 2,
#              'Bergen.': 2,
#              'board': 170,
#              'four': 191,
#              'load': 37,
#              '13': 61,
#              'bags': 7,
#              '50': 65,
#              'kilograms': 5,
#              '(110': 2,
#              'lb)': 2,
#              'post.': 4,
#              'mid-air': 24,
#              'collision': 87,
#              'D-APUT.': 1,
#              'half': 42,
#              'mile': 55,
#              'east': 40,
#              'airfield': 32,
#              '27L': 8,
#              'strong': 46,
#              'gusts': 11,
#              '"Ville': 2,
#              'Nice"': 1,
#              'Mediterranean': 7,
#              'sank.': 39,
#              'All': 247,
#              'occupants': 144,
#              'ship.': 4,
#              'Douglas': 160,
#              '"Praha"': 1,
#              'field': 101,
#              'Doornspijk': 1,
#              'scheduled': 143,
#              'Prague-Amsterdam': 1,
#              'exhaustion.': 14,
#              '(Karl': 1,
#              'Balik,': 1,
#              '32)': 2,
#              '(W.': 1,
#              'Mika,': 1,
#              '29)': 1,
#              'mechanic': 24,
#              '(F.': 1,
#              'Strunk)': 1,
#              'nine': 56,
#              'Lechfeld': 1,
#              'Frankfurt': 12,
#              'Switzerland.': 16,
#              'Orvin.': 1,
#              'Sikorsky': 5,
#              'S-42': 1,
#              'Port': 48,
#              'Spain,': 12,
#              'Trinidad.': 5,
#              'originated': 69,
#              'Miami,': 15,
#              'FL': 31,
#              'bound': 29,
#              'Buenos': 32,
#              'Aires,': 9,
#              'Argentina.': 14,
#              'Chestnut': 1,
#              'Ridge': 3,
#              'south-east': 6,
#              'Fairchance': 1,
#              'Camden,': 1,
#              'NJ': 14,
#              'Pittsburgh-Allegheny': 1,
#              'County': 35,
#              'PA': 10,
#              'Capt': 4,
#              'Otto': 1,
#              'Ferguson,': 1,
#              'co-pilot': 126,
#              'Harry': 1,
#              'C.': 8,
#              'Lewis,': 1,
#              'hostess': 5,
#              'Nelly': 1,
#              'H.': 1,
#              'Granger': 1,
#              'eleven': 15,
#              'board.': 100,
#              '(Mrs': 1,
#              'M.C.': 1,
#              'Ellenstein)': 1,
#              'survived': 65,
#              'Nanking,': 1,
#              'China.': 22,
#              'Hankou': 1,
#              '(now': 31,
#              'Wuhan)': 1,
#              'Shanghai.': 1,
#              'pass': 16,
#              'Iztaccíhuatl': 1,
#              'Popocatépetl': 1,
#              'volcanos.': 1,
#              'While': 215,
#              'Chungking': 1,
#              'Kweiyang': 1,
#              'this': 202,
#              'CNAC': 1,
#              'Tri-Motor': 13,
#              'crashed-landed': 2,
#              'snow,': 13,
#              'sleet': 2,
#              'area': 222,
#              '30': 107,
#              'Yunnanfu.': 1,
#              'Amazingly': 1,
#              'there': 142,
#              'no': 272,
#              'injuries': 79,
#              'although': 28,
#              'Ford': 17,
#              'demolished': 3,
#              'torn.': 1,
#              '"Chorolque"': 2,
#              'Tapacarí': 2,
#              'swamps,': 2,
#              'NE': 9,
#              'Cochabamba.': 2,
#              'floatplane': 10,
#              'mechanical': 25,
#              '10': 130,
#              'swampland': 1,
#              'Goodwin,': 1,
#              'AR.': 1,
#              '(Capt': 5,
#              'Marshall,': 1,
#              'Greenland,': 1,
#              'stewardess': 6,
#              'Casparini)': 1,
#              '14': 59,
#              'died.': 27,
#              'broke': 250,
#              'up': 335,
#              'F.24kay': 2,
#              '"Düsseldorf"': 2,
#              'repair': 372,
#              'Glindow,': 2,
#              'pilots': 171,
#              'Not': 55,
#              'provided': 72,
#              'S-43B': 2,
#              'international': 28,
#              'Rio': 40,
#              'Janeiro,': 7,
#              'Brazil': 7,
#              'stops': 84,
#              'Antilla,': 2,
#              'Port-au-Prince,': 2,
#              'San': 152,
#              'Pedro': 5,
#              'Macorís,': 2,
#              'Juan,': 7,
#              'Georgetown,': 1,
#              'Paramaribo,': 5,
#              'Cayenne,': 1,
#              'Bélem,': 1,
#              'São': 25,
#              'Luís,': 1,
#              'Fortaleza,': 3,
#              'Natal,': 2,
#              'João': 1,
#              'Pessoa,': 1,
#              'Recife,': 3,
#              'Maceió,': 1,
#              'Aracaju,': 1,
#              'Salvador,': 3,
#              'Caravelas': 1,
#              'Vitória.': 1,
#              '(': 1,
#              'leased': 19,
#              'Airways)': 1,
#              'London': 37,
#              'Zurich,': 1,
#              'Basel,': 1,
#              'Imperial': 9,
#              "Airways'": 4,
#              'Britain': 2,
#              'Switzerland': 6,
#              'service.': 5,
#              'cruising': 58,
#              '10,000': 9,
#              'feet': 972,
#              'trouble': 12,
#              "Electra's": 1,
#              'experienced': 85,
#              'unable': 41,
#              'maintain': 60,
#              'height.': 27,
#              'At': 712,
#              '3,000': 29,
#              'wheels': 30,
#              'carried': 316,
#              'Saint-Sauveur,': 1,
#              'Luxeuil-les-Bains.': 1,
#              'collapsed': 169,
#              'remained': 41,
#              'upright,': 1,
#              'Ben': 4,
#              'Prowse': 1,
#              'First-Officer': 1,
#              'A.C.': 2,
#              'Wincop': 1,
#              'able': 89,
#              'exit': 10,
#              'cockpit,': 9,
#              'sustaining': 8,
#              'burns': 3,
#              'flames,': 7,
#              'release': 28,
#              'door': 47,
#              'enabling': 1,
#              'consumed': 19,
#              'Ju-52/3mte': 2,
#              'Wende"': 1,
#              'Llaberia': 1,
#              'mountains,': 5,
#              'Loeb"': 1,
#              'Force': 148,
#              'Kirby-in-Furness': 1,
#              'Moor': 1,
#              'because': 152,
#              'Belfast.': 3,
#              'One': 236,
#              'U.K': 2,
#              'Secretary': 2,
#              'State': 8,
#              'Air,': 47,
#              'Sir': 1,
#              'Kingsley': 1,
#              'Wood.': 2,
#              'He': 249,
#              'way': 60,
#              'Harland': 1,
#              'factory': 10,
#              'Belfast': 2,
#              'inspection': 25,
#              'other': 118,
#              'officials.': 3,
#              'Fire': 26,
#              'refuelling': 4,
#              'barge': 2,
#              'Hythe': 1,
#              'spread': 17,
#              'boat.': 5,
#              'engineers': 6,
#              'Capsized': 1,
#              'gust': 20,
#              'Hooghly': 3,
#              '"Nachtegaal"': 1,
#              'single': 31,
#              'training': 208,
#              'flight,': 91,
#              'hitting': 18,
#              'Military': 9,
#              'Station': 34,
#              'airport,': 52,
#              'injuring': 16,
#              'five.': 3,
#              'rebuilt': 3,
#              'until': 186,
#              'German': 68,
#              'air': 170,
#              'raid': 12,
#              'Schiphol': 2,
#              '10.5.1940': 1,
#              'Dived': 2,
#              'takeoff,': 107,
#              'control': 366,
#              'problems.': 56,
#              'Taken': 1,
#              'dismantled': 4,
#              'Alexandria': 6,
#              'damaging': 15,
#              'spar.': 6,
#              'Japanese': 50,
#              'raid;': 1,
#              'fire-bomb;': 1,
#              '"Chung-Mei";': 1,
#              '1938': 3,
#              'take-off': 10,
#              'Fukuoka': 5,
#              'Japan,': 5,
#              'pilot,': 54,
#              '"Lanchow"': 1,
#              'strafed': 4,
#              'fighters': 13,
#              'ground.': 143,
#              'Water': 10,
#              'looped': 19,
#              'encountering': 11,
#              'sudden': 20,
#              'icing': 53,
#              'conditions': 212,
#              'Dakar': 3,
#              '-': 59,
#              'Casablanca': 3,
#              'Paris.': 7,
#              'late': 18,
#              'schedule': 5,
#              'having': 37,
#              'overnight': 13,
#              'Dar': 10,
#              'es': 5,
#              'Salaam': 5,
#              'or': 177,
#              'Mombassa.': 1,
#              'second': 125,
#              'attempt,': 4,
#              'porpoising': 2,
#              'just': 194,
#              'short': 270,
#              'jetty.': 1,
#              'Tom': 2,
#              'Webb,': 2,
#              'Officer': 9,
#              'aged': 1,
#              '33': 17,
#              'George': 12,
#              'Knight': 1,
#              'clerk': 1,
#              'their': 127,
#              'graves': 1,
#              'are': 38,
#              'cemetery': 3,
#              'Ilha': 3,
#              'da': 6,
#              'Mocambique.': 1,
#              'Fokker': 69,
#              'F.VIII': 2,
#              '"Duif"': 1,
#              'sold': 14,
#              'Venezuelan': 10,
#              'Government': 14,
#              'March': 64,
#              '1939.': 2,
#              'In': 78,
#              'April': 55,
#              '1939,': 1,
#              'flew': 183,
#              'Gran': 1,
#              'Sabana,': 1,
#              'try': 6,
#              'find': 13,
#              ...})

# %%
texts = [[token.lower() for token in text.split() if frequency[token] > 1 and token not in stop]
          for text in data['Narrative']]

len(texts)
# Out:
# 8172

# %%
# Create gensim dictionary object
dictionary = corpora.Dictionary(texts)
dictionary.doc2bow?

# %%
# Create corpus matrix
corpus = [dictionary.doc2bow(text) for text in texts]
len(corpus)
# Out:
# 8172

# %%
len(texts)
len(corpus)
X.shape
# Out:
# (8172, 16166)

# %% [markdown]
# ### Unsupervised Topic Modelling - LDS
# - LDA is a good technique to model topics for each narrative. I am trying to group the accidents based on the nature of the incident!

# %%
lda = models.LdaModel(
    matutils.Sparse2Corpus(X, documents_columns=False),
    num_topics  =  5,
    passes      =  20,
    id2word     =  vocab
)
lda

# %%
lda.print_topics(num_topics=5, num_words=10)
# Out:
# [(0,
#   '0.017*"damage" + 0.012*"accident" + 0.008*"injured" + 0.008*"international" + 0.008*"injuries" + 0.008*"reportedly" + 0.007*"cessna" + 0.006*"dakota" + 0.006*"pilot" + 0.006*"ground"'),
#  (1,
#   '0.045*"engine" + 0.031*"fire" + 0.018*"forced" + 0.015*"landed" + 0.015*"gear" + 0.013*"fuel" + 0.013*"failure" + 0.012*"failed" + 0.011*"caught" + 0.011*"lost"'),
#  (2,
#   '0.023*"accident" + 0.013*"destroyed" + 0.013*"mountain" + 0.011*"dakota" + 0.010*"flew" + 0.009*"transport" + 0.008*"killed" + 0.007*"de" + 0.007*"douglas" + 0.007*"sea"'),
#  (3,
#   '0.012*"pilot" + 0.012*"left" + 0.009*"right" + 0.007*"ground" + 0.007*"weather" + 0.007*"altitude" + 0.006*"control" + 0.005*"cleared" + 0.005*"first" + 0.005*"nose"'),
#  (4,
#   '0.016*"hijacker" + 0.011*"demanded" + 0.011*"taken" + 0.009*"day" + 0.008*"hijackers" + 0.008*"route" + 0.008*"hijacking" + 0.007*"en" + 0.007*"hijacked" + 0.007*"less"')]

# %%
# Label the topics
topics_labels = {
    0: "Weather_Fault",
    1: "Technical_Issue_Engine_Gear",
    2: "Pilot_Control",
    3: "Land_Control",
    4: "Hijack"
}

# %%
doc_topics = [lda.get_document_topics(doc) for doc in corpus]

topic_data = []

for document_id, topics in enumerate(doc_topics):
    
    document_topics = []
    
    for topic, probability in topics:
       
        topic_data.append({
            'document_id':  document_id,
            'topic_id':     topic,
            'topic':        topics_labels[topic],
            'probability':  probability
        })

topics_df = pd.DataFrame(topic_data)
topics_df.pivot_table(values="probability", index=["document_id", "topic"]).T
# Out:
# document_id  topic
# 0            Hijack                         0.050477
#              Land_Control                   0.539197
#              Pilot_Control                  0.152675
#              Technical_Issue_Engine_Gear    0.145484
#              Weather_Fault                  0.112167
# 1            Hijack                         0.066697
#              Land_Control                   0.066677
#              Pilot_Control                  0.066687
#              Technical_Issue_Engine_Gear    0.066683
#              Weather_Fault                  0.733256
# 2            Hijack                         0.421717
#              Land_Control                   0.377938
#              Pilot_Control                  0.066776
#              Technical_Issue_Engine_Gear    0.066748
#              Weather_Fault                  0.066822
# 3            Hijack                         0.050083
#              Land_Control                   0.297267
#              Pilot_Control                  0.050056
#              Technical_Issue_Engine_Gear    0.297078
#              Weather_Fault                  0.305515
# 4            Hijack                         0.149940
#              Land_Control                   0.523105
#              Pilot_Control                  0.276909
#              Technical_Issue_Engine_Gear    0.025016
#              Weather_Fault                  0.025030
#                                               ...
# 8167         Hijack                         0.284051
#              Land_Control                   0.427826
#              Pilot_Control                  0.154993
#              Technical_Issue_Engine_Gear    0.043999
#              Weather_Fault                  0.089131
# 8168         Hijack                         0.022255
#              Land_Control                   0.349981
#              Pilot_Control                  0.357112
#              Technical_Issue_Engine_Gear    0.022239
#              Weather_Fault                  0.248414
# 8169         Hijack                         0.033407
#              Land_Control                   0.347618
#              Pilot_Control                  0.552000
#              Technical_Issue_Engine_Gear    0.033569
#              Weather_Fault                  0.033405
# 8170         Hijack                         0.181631
#              Land_Control                   0.364067
#              Pilot_Control                  0.191106
#              Technical_Issue_Engine_Gear    0.060848
#              Weather_Fault                  0.202348
# 8171         Hijack                         0.305044
#              Land_Control                   0.544787
#              Pilot_Control                  0.050055
#              Technical_Issue_Engine_Gear    0.050040
#              Weather_Fault                  0.050074
# Name: probability, dtype: float64

# %%
# %matplotlib inline

# %%
import seaborn as sns

doc_topics = [lda.get_document_topics(doc) for doc in corpus]

doc_topic_probabilities = []

for document in doc_topics:
    
    single_document = []
    
    for topic, probablity in document:
        
        single_document.append(probablity)
        
    doc_topic_probabilities.append(single_document)
    
docs_topics = pd.DataFrame(doc_topic_probabilities)
sns.heatmap(docs_topics)

# %%
from sklearn.decomposition import LatentDirichletAllocation

lda = LatentDirichletAllocation(n_topics=3)
lda.fit(X)

# %%
lda.components_

# %%
lda.transform(X)

# %% [markdown]
# ## The stop words need to be modified, Is it possible to Stemmatize?

# %% [markdown]
# ## Count Vectorize the Text

# %%
# Import library 

from sklearn.feature_extraction.text import CountVectorizer

# %%
# Join all the Incident Narratives

data_text = [summary for summary in data['Narrative']]

# %%
# Use Count vectorizer to get the  most used names in titles
# Analyzer - I want to analyze by words and not charachter
# Tokenizer - None
# Preprocessor - 
# Stop words - Use basic english stop words initially
# Maximum features - 1000
# Ngram Range 2-3
vectorizer = CountVectorizer(analyzer = "word",tokenizer = None, lowercase=True, strip_accents="unicode",
                             preprocessor = None,stop_words = 'english',max_features = 5000, ngram_range = (1,1))

# %%
# Fit the text to the vectorizer model

data_text_features = vectorizer.fit_transform(data_text)

# Get the words and the count from the model

data_text_words = pd.DataFrame(vectorizer.transform(data_text).todense(), columns=vectorizer.get_feature_names())

# %%
list(data_text_words.columns)
# Out:
# ['00',
#  '000',
#  '01',
#  '02',
#  '03',
#  '04',
#  '04r',
#  '05',
#  '050',
#  '05l',
#  '05r',
#  '06',
#  '06r',
#  '07',
#  '08',
#  '080',
#  '09',
#  '09r',
#  '10',
#  '100',
#  '1000',
#  '10000',
#  '102',
#  '103',
#  '104',
#  '1049',
#  '105',
#  '106',
#  '107',
#  '108',
#  '109',
#  '10deg',
#  '10l',
#  '11',
#  '110',
#  '1100',
#  '111',
#  '111f',
#  '112',
#  '113',
#  '114',
#  '115',
#  '116',
#  '117',
#  '118',
#  '118a',
#  '119',
#  '11f',
#  '11s',
#  '12',
#  '120',
#  '1200',
#  '12000',
#  '121',
#  '122',
#  '123',
#  '124',
#  '124c',
#  '125',
#  '128',
#  '129',
#  '12bk',
#  '13',
#  '130',
#  '1300',
#  '130b',
#  '130e',
#  '130h',
#  '130j',
#  '131',
#  '133',
#  '134',
#  '135',
#  '135a',
#  '139',
#  '13l',
#  '14',
#  '140',
#  '1400',
#  '141',
#  '1420',
#  '145',
#  '14500',
#  '146',
#  '148',
#  '15',
#  '150',
#  '1500',
#  '153',
#  '154',
#  '157',
#  '158',
#  '159',
#  '15deg',
#  '16',
#  '160',
#  '1600',
#  '163',
#  '165',
#  '166',
#  '168',
#  '16r',
#  '17',
#  '170',
#  '1700',
#  '172',
#  '175',
#  '1750',
#  '17l',
#  '18',
#  '180',
#  '1800',
#  '180deg',
#  '185',
#  '188',
#  '19',
#  '190',
#  '1900',
#  '1900c',
#  '1900d',
#  '191',
#  '1936',
#  '1938',
#  '1940',
#  '1941',
#  '1942',
#  '1943',
#  '1944',
#  '1945',
#  '1948',
#  '1949',
#  '1950',
#  '1951',
#  '1953',
#  '1954',
#  '1955',
#  '1957',
#  '1963',
#  '1964',
#  '1966',
#  '1968',
#  '1969',
#  '1972',
#  '1973',
#  '1974',
#  '1978',
#  '1979',
#  '1980',
#  '1981',
#  '1982',
#  '1983',
#  '1985',
#  '1986',
#  '1988',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1997',
#  '1998',
#  '1999',
#  '19r',
#  '1a',
#  '1a10',
#  '1st',
#  '20',
#  '200',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '200c',
#  '201',
#  '2011',
#  '2013',
#  '2015',
#  '202',
#  '203',
#  '2050',
#  '207',
#  '208',
#  '208b',
#  '20deg',
#  '21',
#  '210',
#  '211',
#  '212',
#  '215',
#  '22',
#  '220',
#  '2200',
#  '222',
#  '225',
#  '227',
#  '228',
#  '22l',
#  '23',
#  '230',
#  '2300',
#  '232',
#  '235',
#  '24',
#  '240',
#  '2400',
#  '241',
#  '242',
#  '24b',
#  '24l',
#  '24r',
#  '24rv',
#  '25',
#  '250',
#  '2500',
#  '25l',
#  '26',
#  '260',
#  '265',
#  '266',
#  '26b',
#  '26l',
#  '27',
#  '270',
#  '2700',
#  '27l',
#  '27r',
#  '28',
#  '280',
#  '2800',
#  '285',
#  '28l',
#  '28r',
#  '29',
#  '290',
#  '29l',
#  '2a',
#  '2r',
#  '2t',
#  '30',
#  '300',
#  '3000',
#  '304',
#  '306',
#  '30deg',
#  '31',
#  '310',
#  '31242',
#  '31243',
#  '314',
#  '315',
#  '31l',
#  '31r',
#  '32',
#  '320',
#  '3200',
#  '320o',
#  '322',
#  '325',
#  '328',
#  '32l',
#  '32r',
#  '33',
#  '330',
#  '3300',
#  '330o',
#  '336',
#  '338',
#  '33l',
#  '34',
#  '340',
#  '340b',
#  '340o',
#  '345',
#  '35',
#  '350',
#  '3500',
#  '350o',
#  '35a',
#  '35l',
#  '36',
#  '360',
#  '3600',
#  '37',
#  '38',
#  '39',
#  '390',
#  '3a',
#  '3c',
#  '3deg',
#  '3m',
#  '3mge',
#  '3t',
#  '40',
#  '400',
#  '4000',
#  '41',
#  '410',
#  '410uvp',
#  '42',
#  '420',
#  '4200',
#  '43',
#  '430',
#  '436',
#  '44',
#  '440',
#  '45',
#  '450',
#  '4500',
#  '45deg',
#  '46',
#  '46d',
#  '47',
#  '470',
#  '4700',
#  '47a',
#  '47b',
#  '47d',
#  '47s',
#  '48',
#  '49',
#  '50',
#  '500',
#  '5000',
#  '501',
#  '504',
#  '50832',
#  '50deg',
#  '51',
#  '52',
#  '525',
#  '53',
#  '54',
#  '5400',
#  '55',
#  '550',
#  '5500',
#  '56',
#  '57',
#  '58',
#  '580',
#  '59',
#  '5a',
#  '5h',
#  '5n',
#  '5nm',
#  '5y',
#  '60',
#  '600',
#  '6000',
#  '601',
#  '61',
#  '610',
#  '62',
#  '620',
#  '63',
#  '631',
#  '64',
#  '640',
#  '65',
#  '650',
#  '6500',
#  '66',
#  '67',
#  '68',
#  '6a',
#  '6e',
#  '70',
#  '700',
#  '7000',
#  '707',
#  '71',
#  '710',
#  '72',
#  '720',
#  '725',
#  '727',
#  '73',
#  '737',
#  '74',
#  '747',
#  '748',
#  '75',
#  '750',
#  '7500',
#  '756',
#  '757',
#  '76',
#  '767',
#  '767s',
#  '76md',
#  '770',
#  '777',
#  '78',
#  '78505',
#  '7nm',
#  '80',
#  '800',
#  '8000',
#  '801',
#  '81',
#  '811',
#  '812',
#  '82',
#  '8235',
#  '8241',
#  '82a',
#  '83',
#  '84',
#  '85',
#  '850',
#  '8500',
#  '86',
#  '87',
#  '88',
#  '8807',
#  '89',
#  '8q',
#  '8th',
#  '90',
#  '900',
#  '9000',
#  '90deg',
#  '91',
#  '910',
#  '92',
#  '93',
#  '931',
#  '94',
#  '95',
#  '96',
#  '97',
#  '98',
#  '99',
#  '990',
#  '9k',
#  '9n',
#  '9q',
#  'a100',
#  'a300',
#  'a310',
#  'a319',
#  'a320',
#  'a321',
#  'a330',
#  'a6m2',
#  'aa',
#  'aaa',
#  'aab',
#  'aaf',
#  'ab',
#  'ababa',
#  'abandon',
#  'abandoned',
#  'abdrabbu',
#  'abeam',
#  'abidjan',
#  'able',
#  'abnormal',
#  'aboard',
#  'abort',
#  'aborted',
#  'aborting',
#  'abraham',
#  'abruptly',
#  'absence',
#  'abu',
#  'abuja',
#  'abv',
#  'ac',
#  'acc',
#  'accelerate',
#  'accelerated',
#  'accelerating',
#  'acceleration',
#  'accepted',
#  'access',
#  'accident',
#  'accidentally',
#  'accompanied',
#  'accomplished',
#  'accordance',
#  'according',
#  'accordingly',
#  'accretion',
#  'accumulated',
#  'accumulation',
#  'accumulator',
#  'achieve',
#  'aci',
#  'acknowledged',
#  'acquired',
#  'act',
#  'acting',
#  'action',
#  'actions',
#  'activate',
#  'activated',
#  'active',
#  'activities',
#  'activity',
#  'actual',
#  'actually',
#  'actuator',
#  'adana',
#  'add',
#  'added',
#  'addis',
#  'addition',
#  'additional',
#  'adelaide',
#  'aden',
#  'adequate',
#  'adf',
#  'adi',
#  'adjacent',
#  'administration',
#  'advanced',
#  'adverse',
#  'advise',
#  'advised',
#  'advising',
#  'advisory',
#  'adz',
#  'aer',
#  'aeradio',
#  'aerial',
#  'aero',
#  'aerodrome',
#  'aeroflot',
#  'aeronautical',
#  'aeronautics',
#  'aeroparque',
#  'aeroplane',
#  'aerospace',
#  'afb',
#  'affected',
#  'afghan',
#  'afghanistan',
#  'africa',
#  'africaine',
#  'african',
#  'aft',
#  'afternoon',
#  'agency',
#  'agent',
#  'agents',
#  'agl',
#  'agreed',
#  'agreement',
#  'agricultural',
#  'ah',
#  'ahead',
#  'ahf',
#  'ahg',
#  'aib',
#  'aic',
#  'aid',
#  'aileron',
#  'air',
#  'airborne',
#  'airbus',
#  'aircraft',
#  'aircrew',
#  'aires',
#  'airfield',
#  'airframe',
#  'airlift',
#  'airline',
#  'airliner',
#  'airliners',
#  'airlines',
#  'airman',
#  'airmotive',
#  'airplane',
#  'airplanes',
#  'airport',
#  'airports',
#  'airspace',
#  'airspeed',
#  'airstrip',
#  'airway',
#  'airways',
#  'airworthiness',
#  'ak',
#  'al',
#  'ala',
#  'alabama',
#  'alameda',
#  'alarm',
#  'alaska',
#  'albatross',
#  'albuquerque',
#  'alcohol',
#  'alegre',
#  'alert',
#  'alexandria',
#  'algeria',
#  'algerian',
#  'algiers',
#  'alicante',
#  'alight',
#  'align',
#  'aligned',
#  'alignment',
#  'alitalia',
#  'allegedly',
#  'allegheny',
#  'alliance',
#  'allied',
#  'allow',
#  'allowable',
#  'allowed',
#  'allowing',
#  'alma',
#  'alternate',
#  'altimeter',
#  'altitude',
#  'altitudes',
#  'alto',
#  'alumbre',
#  'amarillo',
#  'amazon',
#  'ambassador',
#  'amber',
#  'ambient',
#  'ambulance',
#  'america',
#  'american',
#  'amman',
#  'ammunition',
#  'amphibian',
#  'amritsar',
#  'ams',
#  'amsl',
#  'amsterdam',
#  'ana',
#  'analysis',
#  'anb',
#  'anchorage',
#  'andes',
#  'andlo',
#  'andres',
#  'angeles',
#  'angle',
#  'angles',
#  'angola',
#  'ankara',
#  'annette',
#  'announced',
#  'annual',
#  'anomalies',
#  'answer',
#  'antarctic',
#  'antarctica',
#  'antenna',
#  'anti',
#  'antonio',
#  'antonov',
#  'anu',
#  'aoa',
#  'ap',
#  'apart',
#  'apparent',
#  'apparently',
#  'appeared',
#  'appears',
#  'application',
#  'applied',
#  'apply',
#  'applying',
#  'approach',
#  'approached',
#  'approaches',
#  'approaching',
#  'appropriate',
#  'approved',
#  'approx',
#  'approximate',
#  'approximately',
#  'april',
#  'apron',
#  'apu',
#  'aquaplaned',
#  'ar',
#  'arab',
#  'arabia',
#  'arabian',
#  'arava',
#  'arc',
#  'arctic',
#  'area',
#  'areas',
#  'arequipa',
#  'arff',
#  'argentina',
#  'argentine',
#  'argonaut',
#  'argosy',
#  'ariana',
#  'arica',
#  'arizona',
#  'arkansas',
#  'arkhangelsk',
#  'arm',
#  'armed',
#  'arms',
#  'army',
#  'array',
#  'arrest',
#  'arrested',
#  'arrival',
#  'arrive',
#  'arrived',
#  'arriving',
#  'arson',
#  'artc',
#  'artcc',
#  'artificial',
#  'aruba',
#  'arzamas',
#  'asheville',
#  'asian',
#  'asked',
#  'asl',
#  'asmara',
#  'asphalt',
#  'assembly',
#  'assigned',
#  'assistance',
#  'associated',
#  'assumed',
#  'asuncion',
#  'asylum',
#  'asymmetric',
#  'asymmetrical',
#  'ataturk',
#  'atc',
#  'atct',
#  'athens',
#  'atl',
#  'atlanta',
#  'atlantic',
#  'atoll',
#  'atp',
#  'atr',
#  'atsugi',
#  'attached',
#  'attachment',
#  'attack',
#  'attacked',
#  'attacking',
#  'attacks',
#  'attained',
#  'attempt',
#  'attempted',
#  'attempting',
#  'attempts',
#  'attendant',
#  'attendants',
#  'attention',
#  'attitude',
#  'au',
#  'auckland',
#  'august',
#  'aural',
#  'aurora',
#  'austin',
#  'australia',
#  'australian',
#  'austria',
#  'authorities',
#  'authorization',
#  'authorized',
#  'auto',
#  'autobrake',
#  'automatic',
#  'automatically',
#  'automobile',
#  'autopilot',
#  'auxiliary',
#  'avail',
#  'available',
#  'avd',
#  'avianca',
#  'aviation',
#  'aviocar',
#  'avoid',
#  'avoidance',
#  'avoiding',
#  'avro',
#  'await',
#  'awaiting',
#  'aware',
#  'awareness',
#  'away',
#  'aweil',
#  'az',
#  'azerbaijan',
#  'azores',
#  'b100',
#  'b200',
#  'b300',
#  'ba',
#  'backfired',
#  'backwards',
#  'bad',
#  'badly',
#  'bae',
#  'bag',
#  'bagdogra',
#  'baggage',
#  'baghdad',
#  'bagram',
#  'bags',
#  'bahamas',
#  'bahar',
#  'bahia',
#  'bahrain',
#  'bail',
#  'bailed',
#  'baku',
#  'balance',
#  'bali',
#  'baltimore',
#  'bandeirante',
#  'bandung',
#  'bang',
#  'bangalore',
#  'bangkok',
#  'bank',
#  'banked',
#  'banking',
#  'banks',
#  'bar',
#  'barbara',
#  'barbed',
#  'barcelona',
#  'barely',
#  'bariloche',
#  'barranquilla',
#  'barrier',
#  'barrow',
#  'barthelemy',
#  'base',
#  'based',
#  'basler',
#  'basra',
#  'batsfjord',
#  'battery',
#  'battle',
#  'baucau',
#  'bay',
#  'bc',
#  'beach',
#  'beached',
#  'beacon',
#  'beam',
#  'bear',
#  'bearing',
#  'beaver',
#  'bed',
#  'bedford',
#  'beech',
#  'beechcraft',
#  'began',
#  'begin',
#  'beginning',
#  'begun',
#  'behalf',
#  'beijing',
#  'beirut',
#  'belem',
#  'belfast',
#  'belgian',
#  'belgium',
#  'belgorod',
#  'belief',
#  'believed',
#  'believing',
#  'belize',
#  'bell',
#  'belly',
#  'belonging',
#  'belt',
#  'ben',
#  'bend',
#  'beneath',
#  'benghazi',
#  'beni',
#  'benina',
#  'bent',
#  'bergen',
#  'berlin',
#  'berm',
#  'berms',
#  'bermuda',
#  'better',
#  'bey',
#  'bhe',
#  'big',
#  'bilbao',
#  'billings',
#  'biplane',
#  'bird',
#  'birds',
#  'birmingham',
#  'bishkek',
#  'bishop',
#  'bit',
#  'bkk',
#  'black',
#  'blackpool',
#  'blade',
#  'blades',
#  'blanc',
#  'blast',
#  'bleed',
#  'blenheim',
#  'blew',
#  'blind',
#  'block',
#  'blocked',
#  'blocking',
#  'blood',
#  'blow',
#  'blowing',
#  'blown',
#  'blue',
#  'bluff',
#  'bn',
#  'boac',
#  'board',
#  'boarded',
#  'boarding',
#  'boat',
#  'boats',
#  'bodies',
#  'body',
#  'bodø',
#  'boeing',
#  'bog',
#  'bogota',
#  'bolivar',
#  'bolivia',
#  'bolt',
#  'bomb',
#  'bombardier',
#  'bombay',
#  'bomber',
#  'bombers',
#  'bombing',
#  'bombs',
#  'boom',
#  'boost',
#  'bordeaux',
#  'border',
#  'borja',
#  'bos',
#  'boston',
#  'bottle',
#  'bottles',
#  'bounce',
#  'bounced',
#  'bound',
#  'boundary',
#  'bourget',
#  'bovingdon',
#  'box',
#  'boxcar',
#  'boxes',
#  'boy',
#  'brace',
#  'bradford',
#  'bradley',
#  'brake',
#  'brakes',
#  'braking',
#  'brandished',
#  'brandishing',
#  'brasilia',
#  'bratislava',
#  'bravo',
#  'brazil',
#  'brazilian',
#  'brazzaville',
#  'break',
#  'breaker',
#  'breaking',
#  'breakup',
#  'bridge',
#  'brief',
#  'briefed',
#  'briefing',
#  'briefly',
#  'brigade',
#  ...]

# %%
from nltk.corpus import stopwords

# %%
# Creating stop words database for all the numbers
stop = stopwords.words('english')
stop += ['00', '000', '01', '02', '03', '04', '04r', '05', '050', '05l', '05r', '06', '06r', '07', '08', '080', '09', '09r', '10', '100', '1000', '10000', '102', '103', '104', '1049', '105', '106', '107', '108', '109', '10deg', '10l', '11', '110', '1100', '111', '111f', '112', '113', '114', '115', '116', '117', '118', '118a', '119', '11f', '11s', '12', '120', '1200', '12000', '121', '361', '376','122', '123', '124', '124c', '125', '128', '129', '12bk', '13', '130', '1300', '130b', '130e', '130h', '130j', '131', '133', '134', '135', '135a', '139', '13l', '14', '140', '1400', '141', '1420', '145', '14500', '146', '148', '15', '150', '1500', '153', '154', '157', '158', '159', '15deg', '16', '160', '1600', '163', '165', '166', '168', '16r', '17', '170', '1700', '172', '175', '1750', '17l', '18', '180', '1800', '180deg', '185', '188', '19', '190', '1900', '1900c', '1900d', '191', '1936', '1938', '1940', '1941', '1942', '1943', '1944', '1945', '1948', '1949', '1950', '1951', '1953', '1954', '1955', '1957', '1963', '1964', '1966', '1968', '1969', '1972', '1973', '1974', '1978', '1979', '1980', '1981', '1982', '1983', '1985', '1986', '1988', '1990', '1991', '1992', '1993', '1994', '1997', '1998', '1999', '19r', '1a', '1a10', '1st', '20', '200', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '200c', '201', '2011', '2013', '2015', '202', '203', '2050', '207', '208', '208b', '20deg', '21', '210', '211', '212', '215', '22', '220', '2200', '222', '225', '227', '228', '22l', '23', '230', '2300', '232', '235', '24', '240', '2400', '241', '242', '24b', '24l', '24r', '24rv', '25', '250', '2500', '25l', '26', '260', '265', '266', '26b', '26l', '27', '270', '2700', '27l', '27r', '28', '280', '2800', '285', '28l', '28r', '29', '290', '29l', '2a', '2r', '2t', '30', '300', '3000', '304', '306', '30deg', '31', '310', '31242', '31243', '314', '315', '31l', '31r', '32', '320', '3200', '320o', '322', '325', '328', '32l', '32r', '33', '330', '3300', '330o', '336', '338', '33l', '34', '340', '340b', '340o', '345', '35', '350', '3500', '350o', '35a', '35l', '36', '360', '3600', '37', '38', '39', '390', '3a', '3c', '3deg', '3m', '3mge', '3t', '40', '400', '4000', '41', '410', '410uvp', '42', '420', '4200', '43', '430', '436', '44', '440', '45', '450', '4500', '45deg', '46', '46d', '47', '470', '4700', '47a', '47b', '47d', '47s', '48', '49', '50', '500', '5000', '501', '504', '50832', '50deg', '51', '52', '525', '53', '54', '5400', '55', '550', '5500', '56', '57', '58', '580', '59', '5a', '5h', '5n', '5nm', '5y', '60', '600', '6000', '601', '61', '610', '62', '620', '63', '631', '64', '640', '65', '650', '6500', '66', '67', '68', '6a', '6e', '70', '700', '7000', '707', '71', '710', '72', '720', '725', '727', '73', '737', '74', '747', '748', '75', '750', '7500', '756', '757', '76', '767', '767s', '76md', '770', '777', '78', '78505', '7nm', '80', '800', '8000', '801', '81', '811', '812', '82', '8235', '8241', '82a', '83', '84', '85', '850', '8500', '86', '87', '88', '8807', '89', '8q', '8th', '90', '900', '9000', '90deg', '91', '910', '92', '93', '931', '94', '95', '96', '97', '98', '99', '990', '9k', '9n', '9q', 'a100', 'a300', 'a310', 'a319', 'a320', 'a321', 'a330', 'a6m2', 'aa', 'aaa', 'aab', 'aaf', 'ab', 'ababa']
stop += ['08r', '1009', '101', '1011', '104b', '144', '21st', '221', '22285', '231', '23l', '300yds', '301', '3100', '318', '319', '31de', '321', '321b', '324', '3277', '33666', '33r', '380', '3800', '395', '39a', '3mce', '400a', '402q', '40563', '40deg', '415', '42e', '42w', '4300', '451', '460', '701', '702', '712', '730', '740', '75a', '76td', '7700', '775', '780', '78270', '78462', '785', '797', '800xp', '823', '841', '8as', '8r', '901', '919', '920', '926', '980', '9j', '9l', '9m']
stop += ['675','680','6800','6b']
# stop.append("need")

# %%
# Use Count vectorizer to get the  most used names in titles
# Analyzer - I want to analyze by words and not charachter
# Tokenizer - None
# Preprocessor - 
# Stop words - Use basic english stop words initially
# Maximum features - 1000
# Ngram Range 2-3
vectorizer = CountVectorizer(analyzer = "word",tokenizer = None, lowercase=True, strip_accents="unicode",
                             preprocessor = None,stop_words = stop,max_features = 1000, ngram_range = (2,3))

# %%
# Fit the text to the vectorizer model

# Fit - Learn the document terms
# Transform - Create the term document array

# A document-term matrix or term-document matrix is a mathematical matrix that describes the frequency of terms that occur in a collection of documents. In a document-term matrix, rows correspond to documents in the collection and columns correspond to terms.

data_text_features = vectorizer.fit_transform(data_text)
data_text_features
# Out:
# <8172x1000 sparse matrix of type '<class 'numpy.int64'>'
# 	with 38726 stored elements in Compressed Sparse Row format>

# %%
data_text_features.shape
# There are 8172 descriptions which are the rows and 1000 columns which are the frequent n-grams
# Out:
# (8172, 1000)

# %%
columns=vectorizer.get_feature_names()

# %%
def get_freq_words(sparse_counts, columns):
    # X_all is a sparse matrix, so sum() returns a 'matrix' datatype ...
    #   which we then convert into a 1-D ndarray for sorting
    word_counts = np.asarray(data_text_features.sum(axis=0)).reshape(-1)

    # argsort() returns smallest first, so we reverse the result
    largest_count_indices = word_counts.argsort()[::-1]

    # pretty-print the results! Remember to always ask whether they make sense ...
    freq_words = pd.Series(word_counts[largest_count_indices], 
                           index=columns[largest_count_indices])

    return freq_words
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-175-85e2d81e0ab9> in <module>()
#      13     return freq_words
#      14
# ---> 15 freq_words = get_freq_words(data_text_features, columns)
#      16 freq_words[:20]
#
# <ipython-input-175-85e2d81e0ab9> in get_freq_words(sparse_counts, columns)
#       9     # pretty-print the results! Remember to always ask whether they make sense ...
#      10     freq_words = pd.Series(word_counts[largest_count_indices],
# ---> 11                            index=columns[largest_count_indices])
#      12
#      13     return freq_words
#
# TypeError: only integer scalar arrays can be converted to a scalar index

# %%
# From the words its clear these are the common words in english and we need to avoid those. Implementing the
# stop word "english"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-174-552a03891be6> in <module>()
# ----> 1 freq_words = get_freq_words(data_text_features, columns)
#       2 freq_words[:20]
#       3
#       4
#       5 # From the words its clear these are the common words in english and we need to avoid those. Implementing the
#
# <ipython-input-173-72eaae02336d> in get_freq_words(sparse_counts, columns)
#       9     # pretty-print the results! Remember to always ask whether they make sense ...
#      10     freq_words = pd.Series(word_counts[largest_count_indices],
# ---> 11                            index=columns[largest_count_indices])
#      12
#      13     return freq_words
#
# TypeError: only integer scalar arrays can be converted to a scalar index

# %%
# Fit the text to the vectorizer model

data_text_features = vectorizer.fit_transform(data_text)

# Get the words and the count from the model

data_text_words = pd.DataFrame(vectorizer.transform(data_text).todense(), columns=vectorizer.get_feature_names())

# %%
data_text_words.sum().nlargest(1000)
# Out:
# damaged beyond                         619
# beyond repair                          617
# damaged beyond repair                  616
# substantial damage                     400
# landing gear                           342
# sustained substantial                  337
# sustained substantial damage           333
# crew members                           325
# caught fire                            324
# international airport                  290
# en route                               290
# forced landing                         256
# first officer                          230
# aircraft crashed                       205
# flight crew                            195
# passenger plane                        193
# engine failure                         186
# transport plane                        185
# came rest                              185
# left wing                              184
# landing accident                       182
# short runway                           180
# approach runway                        178
# emergency landing                      169
# shortly takeoff                        161
# main gear                              157
# end runway                             156
# co pilot                               155
# air force                              153
# right wing                             146
# training flight                        132
# side runway                            128
# runway excursion                       127
# duration hijacking                     127
# gear collapsed                         127
# hijacking less day                     125
# duration hijacking less                125
# hijacking less                         125
# less day                               125
# crash landed                           120
# overran runway                         118
# twin otter                             118
# main landing                           115
# main landing gear                      113
# flight departed                        113
# aircraft struck                        112
# right main                             111
# cargo flight                           110
# demanded taken                         109
# struck ground                          109
# final approach                         103
# altitude feet                          103
# go around                              103
# ils approach                           103
# runway aircraft                        102
# engine failed                          100
# substantially damaged                   99
# crashed takeoff                         97
# aircraft landed                         97
# plane operated                          97
# flight plan                             96
# right hand                              96
# left main                               92
# cargo plane                             92
# weather conditions                      92
# bad weather                             92
# lost control                            90
# runway threshold                        90
# air base                                89
# crashed sea                             88
# minutes takeoff                         88
# airlines flight                         87
# left hand                               87
# crashed near                            85
# operated flight                         85
# aircraft lost                           85
# domestic flight                         84
# destroyed fire                          84
# landing carried                         83
# landing runway                          83
# left engine                             83
# hijacker demanded                       82
# fire erupted                            81
# excursion accident                      80
# meteorological conditions               79
# engine fire                             79
# runway excursion accident               79
# one hijacker                            79
# destroyed accident                      79
# runway approach                         78
# nose gear                               78
# coming rest                             78
# damage landing                          77
# airplane crashed                        77
# minutes later                           77
# king air                                77
# new york                                76
# takeoff runway                          76
# engine power                            75
# runway landing                          75
# destroyed crashed                       72
# corporate jet                           72
# repair accident                         72
# right engine                            71
# beyond repair accident                  71
# three crew                              70
# poor weather                            69
# crew reported                           67
# ifr flight                              66
# following engine                        66
# junkers ju                              66
# flying boat                             66
# substantial damage landing              66
# damage landing accident                 66
# engine problems                         66
# time accident                           65
# lost power                              65
# aircraft took                           65
# crashed mountain                        64
# pilot command                           64
# struck trees                            63
# forced crew                             63
# plane crashed                           63
# right main gear                         62
# one hijacker demanded                   62
# accident near                           62
# conditions prevailed                    61
# control lost                            61
# meteorological conditions prevailed     60
# sustained damage                        59
# takeoff aircraft                        59
# test flight                             58
# pilot reported                          58
# three crew members                      58
# aircraft departed                       58
# damage runway                           58
# douglas dc                              57
# passengers crew                         57
# aircraft touched                        57
# flight originated                       56
# flew side                               56
# undercarriage collapsed                 56
# landing gear collapsed                  55
# crew decided                            55
# flight cleared                          55
# landing aircraft                        55
# airplane operated                       55
# plane sustained                         54
# reportedly damaged                      54
# pilot flying                            54
# damage runway excursion                 53
# right side                              53
# hijacker demanded taken                 53
# ran runway                              53
# approximately feet                      53
# burst flames                            52
# super king air                          52
# visual approach                         52
# plane destroyed                         52
# super king                              52
# reportedly damaged beyond               52
# radio contact                           51
# belly landing                           51
# municipal airport                       51
# stalled crashed                         51
# dhc twin otter                          50
# dhc twin                                50
# de havilland                            50
# members killed                          50
# crew members killed                     50
# force landed                            49
# night time                              49
# crashed shortly                         49
# hijackers demanded                      49
# snow covered                            49
# seconds later                           49
# visual meteorological                   48
# feet runway                             48
# visual meteorological conditions        48
# cruising altitude                       48
# aircraft operated                       48
# became airborne                         48
# board killed                            48
# landed safely                           47
# world war                               47
# world war ii                            47
# war ii                                  47
# aircraft damaged                        47
# fire broke                              47
# minor injuries                          46
# aircraft collided                       46
# flight reported                         46
# aircraft came                           46
# landing made                            46
# one passenger                           46
# runway takeoff                          46
# takeoff accident                        46
# aircraft entered                        46
# plane registered                        46
# four crew                               46
# crashed landing                         46
# substantial damage runway               46
# instrument approach                     46
# left side                               46
# passenger plane operated                45
# demanded flown                          45
# crashed burned                          45
# full power                              45
# one engine                              44
# german invasion netherlands             44
# german invasion                         44
# engine caught                           44
# netherlands world war                   44
# netherlands world                       44
# flight attendant                        44
# invasion netherlands                    44
# engine caught fire                      44
# invasion netherlands world              44
# nose landing                            43
# nose landing gear                       43
# crashed shortly takeoff                 43
# ground fire                             43
# ferry flight                            43
# nose wheel                              43
# aircraft sustained                      43
# fuel tank                               42
# hand main                               42
# two passengers                          42
# pilot attempted                         42
# collapsed landing                       42
# wreckage found                          42
# last radio                              42
# directional control                     42
# poor visibility                         41
# repair landing                          41
# left main gear                          41
# left runway                             41
# taken cuba                              41
# demanded taken cuba                     41
# runway right                            41
# approach landing                        41
# aircraft descended                      41
# beyond repair landing                   41
# instrument flight                       41
# hit ground                              41
# engines failed                          41
# runway airplane                         41
# ils approach runway                     40
# trees crashed                           40
# hard landing                            40
#                                       ...
# sustained serious                       19
# plane departed                          19
# destroyed crashed near                  19
# airport flight                          18
# snow bank                               18
# aircraft rolled                         18
# drainage ditch                          18
# failed takeoff                          18
# departure runway                        18
# speed km                                18
# thrust reversers                        18
# kansas city                             18
# rules flight                            18
# along runway                            18
# knots gusting                           18
# manifold pressure                       18
# rising terrain                          18
# lines flight                            18
# low attitude                            18
# collided trees                          18
# amsterdam schiphol                      18
# engine separated                        18
# runway ils approach                     18
# engine feathered                        18
# loss control                            18
# runway following                        18
# sustained minor injuries                18
# leg flight                              18
# approximately minutes                   18
# san jose                                18
# takeoff due                             18
# takeoff pilot                           18
# aircraft struck ground                  18
# saudi arabia                            18
# low level                               18
# sea level                               18
# hijacker taken duration                 18
# strong winds                            18
# plane landed                            18
# carried forced                          18
# carried forced landing                  18
# radio contact flight                    18
# next day                                18
# passengers six                          18
# carry emergency landing                 18
# air lines flight                        18
# poor weather conditions                 18
# causing left                            18
# fire warning                            18
# crew divert                             18
# cessna caravan                          18
# aircraft carrying                       18
# aircraft carried                        18
# past end                                18
# flight level                            18
# wheels landing                          18
# one minute                              18
# persons board                           18
# pilot lost control                      18
# crashed km                              18
# climbed cruising                        18
# turned left                             18
# minute later                            18
# transport plane destroyed               18
# cloud base                              18
# training mission                        18
# hijacker surrendered duration           18
# captain first officer                   18
# transport planes                        18
# feet long                               18
# crashed mountainous                     18
# climbing feet                           18
# reduced power                           18
# broke two                               18
# feet pilot                              18
# boeing operated                         18
# adverse weather                         18
# wreckage located                        17
# wing broke                              17
# wing dropped                            17
# struck hill                             17
# following engine problems               17
# due bad                                 17
# km north                                17
# wing separated                          17
# flight new                              17
# airplane flying                         17
# air france                              17
# weather time                            17
# due bad weather                         17
# flight miami                            17
# aircraft passengers                     17
# flight diverted                         17
# emergency landing carried               17
# touched runway                          17
# failure engine                          17
# aircraft reported                       17
# heavy rainfall                          17
# threshold runway                        17
# aircraft seen                           17
# aircraft flying                         17
# hand seat                               17
# impacted ground                         17
# takeoff crashed                         17
# aircraft encountered                    17
# aircraft en route                       17
# ground looped                           17
# aircraft en                             17
# filed flight                            17
# fire engine                             17
# gear broke                              17
# full power applied                      17
# engine failure takeoff                  17
# end runway aircraft                     17
# visual flight                           17
# aircraft became airborne                17
# forced landing made                     17
# passenger plane destroyed               17
# abort takeoff                           17
# main gear leg                           17
# crashed flames                          17
# crashed wooded                          17
# damaged accident                        17
# approach path                           17
# damage takeoff accident                 17
# approach procedure                      17
# runway engine                           17
# runway edge                             17
# runway damaged                          17
# damage takeoff                          17
# power engine                            17
# damage left                             17
# lost directional                        17
# lost directional control                17
# ran fuel                                17
# light snow                              17
# crashed forest                          17
# runway caught                           17
# made emergency                          17
# past runway end                         17
# received minor                          17
# received minor injuries                 17
# refueling stop                          17
# captain took                            17
# passengers two crew                     17
# past end runway                         17
# mountain elevation                      17
# right runway                            17
# crashed water                           17
# passengers released                     17
# passengers six crew                     17
# flown cuba                              17
# climbed cruising altitude               17
# airport runway                          17
# pilot sole                              17
# airplane took                           17
# shallow water                           17
# pilot made                              17
# control lost aircraft                   17
# check flight                            17
# died accident                           17
# sink rate                               17
# crashed control                         17
# spraying flight                         17
# controller reported                     17
# crashed field                           17
# stop made                               17
# pilot injured                           16
# mountain feet                           16
# air raid                                16
# flight idle                             16
# air traffic control                     16
# aircraft flown                          16
# missing flight                          16
# fire crew                               16
# pilots injured                          16
# new orleans                             16
# causing plane                           16
# flight airplane                         16
# precision approach                      16
# nothing heard                           16
# plan filed flight                       16
# plane crash                             16
# nose high                               16
# port wing                               16
# centre gravity                          16
# non precision                           16
# plane stormed                           16
# causing nose                            16
# feet flight                             16
# demanded money                          16
# military transport plane                16
# short runway threshold                  16
# operated air                            16
# operated cargo                          16
# operated cargo flight                   16
# another aircraft                        16
# leading edge                            16
# super constellation                     16
# airplane destroyed                      16
# suffered landing accident               16
# accident airplane                       16
# approach continued                      16
# contact ground                          16
# knots gusting knots                     16
# skidded runway                          16
# airplane rolled                         16
# struck snow                             16
# dme approach                            16
# airplane substantially                  16
# airplane substantially damaged          16
# dc operated                             16
# runway runway                           16
# boeing passenger                        16
# back runway                             16
# military transport                      16
# crew bailed                             16
# metro iii                               16
# right wingtip                           16
# passengers three                        16
# make emergency                          16
# beechcraft b200                         16
# crew noticed                            16
# explosion occurred                      16
# approach crew                           16
# passengers survived                     16
# runway caught fire                      16
# takeoff weight                          16
# ethiopian airlines                      16
# aircraft suddenly                       16
# escaped unhurt                          16
# injuries among                          16
# tail section                            16
# controller cleared flight               16
# stormed hijacker                        15
# pilot requested                         15
# plane continued                         15
# stormed hijacker arrested               15
# rolled right                            15
# rules flight plan                       15
# ten minutes                             15
# days later                              15
# airlines boeing aircraft                15
# de icing                                15
# degrees knots                           15
# airplane contacted                      15
# later captain                           15
# descending feet                         15
# substantial damage takeoff              15
# beyond repair following                 15
# dtype: int64

# %%
cvt = CountVectorizer(stop_words=stop, lowercase=True, strip_accents="unicode", ngram_range=(1,2))
X_all = cvt.fit_transform(data_scientist_df['jd'])
columns  =  np.array(cvt.get_feature_names())

freq_words = get_freq_words(X_all, columns)
freq_words[:20]

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
CountVectorizer(strip_accents='ascii').build_analyzer()('pilot/error')
# Out:
# ['pilot', 'error']

# %%
# Use Count vectorizer to get the  most used names in titles
# Analyzer - I want to analyze by words and not charachter
# Tokenizer - None
# Preprocessor - 
# Stop words - Use basic english stop words initially
# Maximum features - 1000
# Ngram Range 2-3
vectorizer = CountVectorizer(analyzer = "word",tokenizer = None, lowercase=True, strip_accents="unicode",
                             preprocessor = None,stop_words = stop,max_features = 1000, ngram_range = (2,3)).build_analyzer()('pilot/error')

# %%
# Fit the text to the vectorizer model

data_text_features = vectorizer.fit_transform(data_text)

# Get the words and the count from the model

data_text_words = pd.DataFrame(vectorizer.transform(data_text).todense(), columns=vectorizer.get_feature_names())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-148-9a9125a9e283> in <module>()
#       1 # Fit the text to the vectorizer model
#       2
# ----> 3 data_text_features = vectorizer.fit_transform(data_text)
#       4
#       5 # Get the words and the count from the model
#
# AttributeError: 'list' object has no attribute 'fit_transform'

# %%
data_text_words.sum().nlargest(1000)
# Out:
# damaged beyond                         619
# beyond repair                          617
# damaged beyond repair                  616
# substantial damage                     400
# landing gear                           342
# sustained substantial                  337
# sustained substantial damage           333
# crew members                           325
# caught fire                            324
# international airport                  290
# en route                               290
# forced landing                         256
# first officer                          230
# aircraft crashed                       205
# flight crew                            195
# passenger plane                        193
# engine failure                         186
# transport plane                        185
# came rest                              185
# left wing                              184
# landing accident                       182
# short runway                           180
# approach runway                        178
# emergency landing                      169
# shortly takeoff                        161
# main gear                              157
# end runway                             156
# co pilot                               155
# air force                              153
# right wing                             146
# training flight                        132
# side runway                            128
# runway excursion                       127
# duration hijacking                     127
# gear collapsed                         127
# hijacking less day                     125
# duration hijacking less                125
# hijacking less                         125
# less day                               125
# crash landed                           120
# overran runway                         118
# twin otter                             118
# main landing                           115
# main landing gear                      113
# flight departed                        113
# aircraft struck                        112
# right main                             111
# cargo flight                           110
# demanded taken                         109
# struck ground                          109
# final approach                         103
# altitude feet                          103
# go around                              103
# ils approach                           103
# runway aircraft                        102
# engine failed                          100
# substantially damaged                   99
# crashed takeoff                         97
# aircraft landed                         97
# plane operated                          97
# flight plan                             96
# right hand                              96
# left main                               92
# cargo plane                             92
# weather conditions                      92
# bad weather                             92
# lost control                            90
# runway threshold                        90
# air base                                89
# crashed sea                             88
# minutes takeoff                         88
# airlines flight                         87
# left hand                               87
# crashed near                            85
# operated flight                         85
# aircraft lost                           85
# domestic flight                         84
# destroyed fire                          84
# landing carried                         83
# landing runway                          83
# left engine                             83
# hijacker demanded                       82
# fire erupted                            81
# excursion accident                      80
# meteorological conditions               79
# engine fire                             79
# runway excursion accident               79
# one hijacker                            79
# destroyed accident                      79
# runway approach                         78
# nose gear                               78
# coming rest                             78
# damage landing                          77
# airplane crashed                        77
# minutes later                           77
# king air                                77
# new york                                76
# takeoff runway                          76
# engine power                            75
# runway landing                          75
# destroyed crashed                       72
# corporate jet                           72
# repair accident                         72
# right engine                            71
# beyond repair accident                  71
# three crew                              70
# poor weather                            69
# crew reported                           67
# ifr flight                              66
# following engine                        66
# junkers ju                              66
# flying boat                             66
# substantial damage landing              66
# damage landing accident                 66
# engine problems                         66
# time accident                           65
# lost power                              65
# aircraft took                           65
# crashed mountain                        64
# pilot command                           64
# struck trees                            63
# forced crew                             63
# plane crashed                           63
# right main gear                         62
# one hijacker demanded                   62
# accident near                           62
# conditions prevailed                    61
# control lost                            61
# meteorological conditions prevailed     60
# sustained damage                        59
# takeoff aircraft                        59
# test flight                             58
# pilot reported                          58
# three crew members                      58
# aircraft departed                       58
# damage runway                           58
# douglas dc                              57
# passengers crew                         57
# aircraft touched                        57
# flight originated                       56
# flew side                               56
# undercarriage collapsed                 56
# landing gear collapsed                  55
# crew decided                            55
# flight cleared                          55
# landing aircraft                        55
# airplane operated                       55
# plane sustained                         54
# reportedly damaged                      54
# pilot flying                            54
# damage runway excursion                 53
# right side                              53
# hijacker demanded taken                 53
# ran runway                              53
# approximately feet                      53
# burst flames                            52
# super king air                          52
# visual approach                         52
# plane destroyed                         52
# super king                              52
# reportedly damaged beyond               52
# radio contact                           51
# belly landing                           51
# municipal airport                       51
# stalled crashed                         51
# dhc twin otter                          50
# dhc twin                                50
# de havilland                            50
# members killed                          50
# crew members killed                     50
# force landed                            49
# night time                              49
# crashed shortly                         49
# hijackers demanded                      49
# snow covered                            49
# seconds later                           49
# visual meteorological                   48
# feet runway                             48
# visual meteorological conditions        48
# cruising altitude                       48
# aircraft operated                       48
# became airborne                         48
# board killed                            48
# landed safely                           47
# world war                               47
# world war ii                            47
# war ii                                  47
# aircraft damaged                        47
# fire broke                              47
# minor injuries                          46
# aircraft collided                       46
# flight reported                         46
# aircraft came                           46
# landing made                            46
# one passenger                           46
# runway takeoff                          46
# takeoff accident                        46
# aircraft entered                        46
# plane registered                        46
# four crew                               46
# crashed landing                         46
# substantial damage runway               46
# instrument approach                     46
# left side                               46
# passenger plane operated                45
# demanded flown                          45
# crashed burned                          45
# full power                              45
# one engine                              44
# german invasion netherlands             44
# german invasion                         44
# engine caught                           44
# netherlands world war                   44
# netherlands world                       44
# flight attendant                        44
# invasion netherlands                    44
# engine caught fire                      44
# invasion netherlands world              44
# nose landing                            43
# nose landing gear                       43
# crashed shortly takeoff                 43
# ground fire                             43
# ferry flight                            43
# nose wheel                              43
# aircraft sustained                      43
# fuel tank                               42
# hand main                               42
# two passengers                          42
# pilot attempted                         42
# collapsed landing                       42
# wreckage found                          42
# last radio                              42
# directional control                     42
# poor visibility                         41
# repair landing                          41
# left main gear                          41
# left runway                             41
# taken cuba                              41
# demanded taken cuba                     41
# runway right                            41
# approach landing                        41
# aircraft descended                      41
# beyond repair landing                   41
# instrument flight                       41
# hit ground                              41
# engines failed                          41
# runway airplane                         41
# ils approach runway                     40
# trees crashed                           40
# hard landing                            40
#                                       ...
# sustained serious                       19
# plane departed                          19
# destroyed crashed near                  19
# airport flight                          18
# snow bank                               18
# aircraft rolled                         18
# drainage ditch                          18
# failed takeoff                          18
# departure runway                        18
# speed km                                18
# thrust reversers                        18
# kansas city                             18
# rules flight                            18
# along runway                            18
# knots gusting                           18
# manifold pressure                       18
# rising terrain                          18
# lines flight                            18
# low attitude                            18
# collided trees                          18
# amsterdam schiphol                      18
# engine separated                        18
# runway ils approach                     18
# engine feathered                        18
# loss control                            18
# runway following                        18
# sustained minor injuries                18
# leg flight                              18
# approximately minutes                   18
# san jose                                18
# takeoff due                             18
# takeoff pilot                           18
# aircraft struck ground                  18
# saudi arabia                            18
# low level                               18
# sea level                               18
# hijacker taken duration                 18
# strong winds                            18
# plane landed                            18
# carried forced                          18
# carried forced landing                  18
# radio contact flight                    18
# next day                                18
# passengers six                          18
# carry emergency landing                 18
# air lines flight                        18
# poor weather conditions                 18
# causing left                            18
# fire warning                            18
# crew divert                             18
# cessna caravan                          18
# aircraft carrying                       18
# aircraft carried                        18
# past end                                18
# flight level                            18
# wheels landing                          18
# one minute                              18
# persons board                           18
# pilot lost control                      18
# crashed km                              18
# climbed cruising                        18
# turned left                             18
# minute later                            18
# transport plane destroyed               18
# cloud base                              18
# training mission                        18
# hijacker surrendered duration           18
# captain first officer                   18
# transport planes                        18
# feet long                               18
# crashed mountainous                     18
# climbing feet                           18
# reduced power                           18
# broke two                               18
# feet pilot                              18
# boeing operated                         18
# adverse weather                         18
# wreckage located                        17
# wing broke                              17
# wing dropped                            17
# struck hill                             17
# following engine problems               17
# due bad                                 17
# km north                                17
# wing separated                          17
# flight new                              17
# airplane flying                         17
# air france                              17
# weather time                            17
# due bad weather                         17
# flight miami                            17
# aircraft passengers                     17
# flight diverted                         17
# emergency landing carried               17
# touched runway                          17
# failure engine                          17
# aircraft reported                       17
# heavy rainfall                          17
# threshold runway                        17
# aircraft seen                           17
# aircraft flying                         17
# hand seat                               17
# impacted ground                         17
# takeoff crashed                         17
# aircraft encountered                    17
# aircraft en route                       17
# ground looped                           17
# aircraft en                             17
# filed flight                            17
# fire engine                             17
# gear broke                              17
# full power applied                      17
# engine failure takeoff                  17
# end runway aircraft                     17
# visual flight                           17
# aircraft became airborne                17
# forced landing made                     17
# passenger plane destroyed               17
# abort takeoff                           17
# main gear leg                           17
# crashed flames                          17
# crashed wooded                          17
# damaged accident                        17
# approach path                           17
# damage takeoff accident                 17
# approach procedure                      17
# runway engine                           17
# runway edge                             17
# runway damaged                          17
# damage takeoff                          17
# power engine                            17
# damage left                             17
# lost directional                        17
# lost directional control                17
# ran fuel                                17
# light snow                              17
# crashed forest                          17
# runway caught                           17
# made emergency                          17
# past runway end                         17
# received minor                          17
# received minor injuries                 17
# refueling stop                          17
# captain took                            17
# passengers two crew                     17
# past end runway                         17
# mountain elevation                      17
# right runway                            17
# crashed water                           17
# passengers released                     17
# passengers six crew                     17
# flown cuba                              17
# climbed cruising altitude               17
# airport runway                          17
# pilot sole                              17
# airplane took                           17
# shallow water                           17
# pilot made                              17
# control lost aircraft                   17
# check flight                            17
# died accident                           17
# sink rate                               17
# crashed control                         17
# spraying flight                         17
# controller reported                     17
# crashed field                           17
# stop made                               17
# pilot injured                           16
# mountain feet                           16
# air raid                                16
# flight idle                             16
# air traffic control                     16
# aircraft flown                          16
# missing flight                          16
# fire crew                               16
# pilots injured                          16
# new orleans                             16
# causing plane                           16
# flight airplane                         16
# precision approach                      16
# nothing heard                           16
# plan filed flight                       16
# plane crash                             16
# nose high                               16
# port wing                               16
# centre gravity                          16
# non precision                           16
# plane stormed                           16
# causing nose                            16
# feet flight                             16
# demanded money                          16
# military transport plane                16
# short runway threshold                  16
# operated air                            16
# operated cargo                          16
# operated cargo flight                   16
# another aircraft                        16
# leading edge                            16
# super constellation                     16
# airplane destroyed                      16
# suffered landing accident               16
# accident airplane                       16
# approach continued                      16
# contact ground                          16
# knots gusting knots                     16
# skidded runway                          16
# airplane rolled                         16
# struck snow                             16
# dme approach                            16
# airplane substantially                  16
# airplane substantially damaged          16
# dc operated                             16
# runway runway                           16
# boeing passenger                        16
# back runway                             16
# military transport                      16
# crew bailed                             16
# metro iii                               16
# right wingtip                           16
# passengers three                        16
# make emergency                          16
# beechcraft b200                         16
# crew noticed                            16
# explosion occurred                      16
# approach crew                           16
# passengers survived                     16
# runway caught fire                      16
# takeoff weight                          16
# ethiopian airlines                      16
# aircraft suddenly                       16
# escaped unhurt                          16
# injuries among                          16
# tail section                            16
# controller cleared flight               16
# stormed hijacker                        15
# pilot requested                         15
# plane continued                         15
# stormed hijacker arrested               15
# rolled right                            15
# rules flight plan                       15
# ten minutes                             15
# days later                              15
# airlines boeing aircraft                15
# de icing                                15
# degrees knots                           15
# airplane contacted                      15
# later captain                           15
# descending feet                         15
# substantial damage takeoff              15
# beyond repair following                 15
# dtype: int64
