# %%
import pandas as pd

# %%
file = './aviation_cleaned.csv'

# %%
data = pd.read_csv(file)

# %%
data.Narrative.head()
# Out:
# 0    The Peruvian Metro 23 was apparently involved ...
# 1                    Reportedly damaged beyond repair.
# 2                             Blown over in hurricane.
# 3                              Ran into a bomb crater.
# 4    Forced landing on Brazilian territory (Rió Pur...
# Name: Narrative, dtype: object

# %%
data = data[['Narrative']]

# %%
data.head()
# Out:
#                                            Narrative
# 0  The Peruvian Metro 23 was apparently involved ...
# 1                  Reportedly damaged beyond repair.
# 2                           Blown over in hurricane.
# 3                            Ran into a bomb crater.
# 4  Forced landing on Brazilian territory (Rió Pur...

# %% [raw]
# # Save all the text in different lines
# all_text = ''
# for text in data['Narrative']:
#     # Combine all the text into 1 string
#     all_text += text
#     all_text += '\n'

# %% [raw]
# # Check the text print
# len(all_text)

# %% [raw]
# print(all_text[:1000])

# %%
# Remove all stop words from the text
from nltk.corpus import stopwords

# filtered_words = [word for word in all_text if word not in stopwords.words('english')]

for line in data['Narrative']:
    print(word)
    print('nnnnnnnnn')
# Out:
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# nnnnnnnnn
# h
# ...

# %%
type(filtered_words)

# %%
# Save the text into a text file

# %%
# Run mapper on the text

# %%
# Sort the mapper output

# %%
# Reduce the sorted output

# %%
# Expected output, words with the word count and we can find the most popular words!!

# %%
f = open('narrative_mapreduced.txt', 'r') # open file in read mode
data = f.read()      # copy to a string
f.close()               # close the file
print (data)          # print the data
# Out:
# "	3
# "-3.3"	1
# "-3.3",	1
# "...	3
# "....its	1
# "...We	1
# "...became	1
# "...descend	1
# "...its	1
# "...land	1
# "...looks	1
# "...maintain	1
# "...the	1
# "...to	1
# "...wind,	2
# "..1307	1
# "100	1
# "16th	1
# "200	1
# "25th	1
# "39"	1
# "5	1
# "500	1
# "53"	1
# "72	1
# "ATC	1
# "Additional	1
# "Ah,	1
# "Akaroa",	1
# "Alert",	1
# "Alhambra	1
# "Allegheny	1
# "Andreyevski"	1
# "Anhangá"	1
# "Anthony	1
# "Are	1
# "Autoland"	1
# "Azules"	2
# "BN	1
# "Bank	1
# "Bic"	1
# "Bill"	1
# "Boeing	1
# "Bolshevik"	1
# "Brace	1
# "Brim	1
# "Bulolo	2
# "C".	1
# "CA-1"	1
# "Calpurnia",	1
# "Capital	1
# "Catalina	1
# "Cavalier"	1
# "Certificate	1
# "Charles	2
# "Chateau	1
# "Chiao	1
# "Chiloé".The	1
# "Chorolque"	2
# "Chung-Mei";	1
# "Ciel	1
# "City	10
# "Ciudad	1
# "Cleared	1
# "Clipper	6
# "Coco	1
# "Colorados".The	2
# "Columbus"	1
# "Cormoran",	1
# "Courlis",	1
# "Cuba"	2
# "Cygnus",	1
# "Dan	1
# "Dauphiné".One	1
# "De	1
# "Decisive	3
# "Dentist	1
# "Der	1
# "Deutschland",	3
# "Ditka	1
# ...
